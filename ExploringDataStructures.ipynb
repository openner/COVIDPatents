# %% [markdown]
# This notebook is an exploration of the structure of the CORD-19 data files.

# %% [markdown]
# # Imports

# %%
import csv
import pandas as pd
from pprint import pprint as pp

# %% [markdown]
# # metadata.csv

# %%
metadataFile = open('metadata.csv', 'r')
csvReader = csv.reader(metadataFile, delimiter=',', quotechar='"')

Header = next(csvReader)
pp(Header)
# Out:
# ['cord_uid',
#  'sha',
#  'source_x',
#  'title',
#  'doi',
#  'pmcid',
#  'pubmed_id',
#  'license',
#  'abstract',
#  'publish_time',
#  'authors',
#  'journal',
#  'mag_id',
#  'who_covidence_id',
#  'arxiv_id',
#  'pdf_json_files',
#  'pmc_json_files',
#  'url']

# %% [markdown]
# ## Columns
#
# Starting from the readme provided with the data (metadata.readme) we can outline what each columns should cover and, importantly for databasing it, whether it is single value of potentially multi-valued.
#
# 'cord_uid' - This is a persistent identifier for the article within the CORD-19 ecosystem. __single valued__, __unique__.
#
# 'sha' - The hash of the article's PDF. There may be multiple PDFs associated to one article (supporting materials, ?preprints?). __multi-valued__.
#
# 'source_x' - The source of the article data. Sources covered include CZI (Chan-Zuckerberg Initiative), PMC (pubmed central), bioRxiv and medRxiv. Confirm sources from data. Should be __single valued__.
#
# 'title' - The article's title. __single valued__.
#
# 'doi' - The article's doi. __single valued__.
#
# 'pmcid' - The article's pubmed central id, if it has one. __single valued__, __unique__.
#
#
# 'pubmed_id' - The article's pubmed id. For distinction between this and the previous, see [here](https://publicaccess.nih.gov/include-pmcid-citations.htm#Difference). __single valued__, __unique__.
#
# 'license' - The license under which the data is being shared. Should be __single valued__.
#
# 'abstract' - The article's abstract. __single valued__.
#
# 'publish_time' - The date the article was published. __single valued__.
#
# 'authors' - The article's authors. Coverage questionable. __multi-valued__.
#
# 'journal' - The journal in which the article was published. If it was published in a journal. What happens with preprints? __single valued__.
#
# 'mag_id' - The article's microsoft academic graph id. __single valued__, __unique__.
#
# 'who_covidence_id' - The article's WHO #Covidence id. Should only be populated for CZI source articles. __single valued__, __unique__.
#
# 'arxiv_id' - The article's arXiv id. __single valued__, __unique__.
#
# 'pdf_json_files' - Relative path of the json(s) parsed from pdf file(s). __multi-valued__, __unique__.
#
# 'pmc_json_files' - Relative path of the json(s) parsed from pmc file(s). __multi-valued__, __unique__.
#
# 'url' - The article's URL. Should be __single valued__, __unique__.

# %% [markdown]
# To explore the columns, it is probably easier to work with the csv via pandas.

# %%
metadataFrame = pd.read_csv('metadata.csv', low_memory=False)
metadataFrame
# Out:
#        cord_uid                                                sha  \
# 0      zjufx4fo           b2897e1277f56641193a6db73825f707eed3e4c9
# 1      ymceytj3           e3d0d482ebd9a8ba81c254cc433f314142e72174
# 2      wzj2glte           00b1d99e70f779eb4ede50059db469c65e8c1469
# 3      2sfqsfm1           cf584e00f637cbd8f1bb35f3f09f5ed07b71aeb0
# 4      i0zym7iq           dde02f11923815e6a16a31dd6298c46b109c5dfa
# 5      xqhn0vbp           1e1286db212100993d03cc22374b624f7caee956
# 6      gi6uaa83           8ae137c8da1607b3a8e4c946c07ca8bda67f88ac
# 7      0m32ecnu           23bc55d6f63fab18b02004483888db2b6a0bfa48
# 8      le0ogx1s                                                NaN
# 9      3oxzzxnd           7ff45096210eeb392d51f646f5c7fe011079aaf3
# 10     fy4w7xz8           0104f6ceccf92ae8567a0102f89cbb976969a774
# 11     0qaoam29           5b68a553a7cbbea13472721cd1ad617d42b40c26
# 12     qj4dh6rg           3ed670f60a7be2e3e2a991ea8af1fdd5fa5e2b2c
# 13     1wswi7us           59ffca26c9d1f881e4e37e7c5af626d72d858dc4
# 14     yy96yeu9           c63c4d58d170136b8d3b5a66424b5ac3f73a92d9
# 15     5o38ihe0           dab2d95da5307c840eb4a1e00f0186022541d63d
# 16     1ul8owic           75ebad1e8641e5fe2a51214f4d97742ab59a8dae
# 17     5s6acr7m           6c0dee643345c93436cfa8d58270aa887ad92e3d
# 18     6lvn10f4           14e0cac6e86d62859e6c9f1351ab67466d89e5b3
# 19     tvxpckxo           d09b79026117ec9faebba46a8d13aa9b23ec751e
# 20     mcuixluu           44102e3e69e70ad2a73e753133283334ce1f8736
# 21     ri5v6u4x           06559dd625491d6474ee88f08c12fc17c1830995
# 22     kuybfc1y           d81ae79ebc6462fd3de075e220992f1aae1f06ae
# 23     ng4rrdte           87390d2ae28407b3e03e60a6b24a7fd99ed7229a
# 24     1769ovyk           c5131e5f5c6000ec84139edc64778a6f1d391b83
# 25     tixxm78q           8a7d5de5ea680e784ab2bd877240bf09e4c1c02d
# 26     pwsvhitd           e4b48ce0579f908da6dd3289bb2cc262dbdeae72
# 27     wt8zfqk0           52ce19fe79de46d9bb0fa7e75a0631fed2d3efd2
# 28     5gsbtfag           b499a41ad1d85a0e071b59e60065c874e534911d
# 29     fpj5urao  4a228865af2c19adf9386a5b04cca3ceb3c8683d; e9c7...
# ...         ...                                                ...
# 63541  othckgtm                                                NaN
# 63542  pth2d40p  29d15895b6f3c6472f3bab820d6a99feefae60df; 1f5c...
# 63543  qko8md3w           a68721d234eacc8dd31ff6a97616d8091f61e912
# 63544  aq7amykr           1e23bde4e435cbcb5f23f6b1dc2f6687f1c3b221
# 63545  5wrj838n           66a268ec094c120ea3c4dfeedfeacab4494c50f6
# 63546  ccdj7137           8d1498b4b95b0bf8f6d9577764fffcecd1bae360
# 63547  tjy7f9rk           258ce44a78453f7d28e241962a197995d3e53c04
# 63548  56ehhgmk           9074747aea8d86b85b9594e82ccc2fa44d08772e
# 63549  drxpor44           ba1ab411e62b278e72259c8203b76991c3efbc7d
# 63550  pcnmbd72           3d678ce5b0b21cca48a07226a97055eb96733352
# 63551  jwlwrz8v           b1a4463a80b51e113e68c992b53781869881b73a
# 63552  xl5z5lsk           9fd57e68de682f9cf91b1ec2479868fd7215c0ed
# 63553  0h7s5d7n  e44284f191fc9522ccc675257354cb33cd9c2885; 26de...
# 63554  zfe4lbr0           2e7f047e863ea96cf05fe606a7e8163d3217e1ab
# 63555  iegx2yln                                                NaN
# 63556  vyu0zd6k  a243da5abdf029948b1fa8beb600db0ab124da63; 7df3...
# 63557  2ho8sr1a           613c002da74850a9055fceaabb8a20d27c2c69b7
# 63558  d7n1zy0b           fbd0883af84e01bf3f6c874e9cb863934995a113
# 63559  sllxevf7           d66311a0656685a7a39bd82b24ac3cb16c17ecfa
# 63560  zi8ij7ln                                                NaN
# 63561  54gh3rt4           d0f619ec08f0d63dd120c0acf095493a0d869935
# 63562  m45vm6sf                                                NaN
# 63563  sehhfysa  78c0852bc3566669cb9f7903758a92988362bcf9; 64f2...
# 63564  01plpnzu           f5110e5b6c82b1000b924e550afd1722dac5cda8
# 63565  89t3g9ty           1c2ec5f7aa7133b58659aa5403e03f14da7ba1a1
# 63566  mvq6353a           7d94ed06736e171ba688a2e72a622d6d9884f88c
# 63567  zm82q79t                                                NaN
# 63568  gmgbus9i           45713f9e6085b078e4dc902790cf3e5cdca43151
# 63569  0sdx32cm           4534efb66ced62c3f0bf6490732a97194cf50635
# 63570  vkvls2zp           f616fc58218452c55948631f421b119fda4f60df
#
#                  source_x                                              title  \
# 0                     PMC  Sequence requirements for RNA strand transfer ...
# 1                     PMC  Crystal structure of murine sCEACAM1a[1,4]: a ...
# 2                     PMC  Synthesis of a novel hepatitis C virus protein...
# 3                     PMC  Structure of coronavirus main proteinase revea...
# 4                     PMC  Discontinuous and non-discontinuous subgenomic...
# 5                     PMC  Airborne rhinovirus detection and effect of ul...
# 6                     PMC    Discovering human history from stomach bacteria
# 7                     PMC  Prokaryotic-style frameshifting in a plant tra...
# 8                     PMC     A new recruit for the army of the men of death
# 9                     PMC  SseG, a virulence protein that targets Salmone...
# 10                    PMC  Association of HLA class I with severe acute r...
# 11                    PMC   A double epidemic model for the SARS propagation
# 12                    PMC  Cloaked similarity between HIV-1 and SARS-CoV ...
# 13                    PMC  Relationship of SARS-CoV to other pathogenic R...
# 14                    PMC  Viral Discovery and Sequence Recovery Using DN...
# 15                    PMC  A model of tripeptidyl-peptidase I (CLN2), a u...
# 16                    PMC  Air pollution and case fatality of SARS in the...
# 17                    PMC                    The Virus That Changed My World
# 18                    PMC  Heterogeneous nuclear ribonucleoprotein A1 reg...
# 19                    PMC  A Method to Identify p62's UBA Domain Interact...
# 20                    PMC  Vaccinia virus infection disrupts microtubule ...
# 21                    PMC  Towards evidence-based, GIS-driven national sp...
# 22                    PMC  Descriptive review of geographic mapping of se...
# 23                    PMC  Pro/con clinical debate: Steroids are a key co...
# 24                    PMC  8th Annual Toronto Critical Care Medicine Symp...
# 25                    PMC  Recently published papers: all the usual suspe...
# 26                    PMC  Detection of hepatitis C virus in the nasal se...
# 27                    PMC  Bioinformatics analysis of SARS coronavirus ge...
# 28                    PMC  Coronavirus 3CL(pro )proteinase cleavage sites...
# 29                    PMC  Moderate mutation rate in the SARS coronavirus...
# ...                   ...                                                ...
# 63541       Elsevier; PMC  The Perfect Storm: Climate, Ecosystems and Inf...
# 63542       CZI; Elsevier  Asymptomatic carrier state, acute respiratory ...
# 63543       Elsevier; PMC  Analytical performance of the Alere™ i Influen...
# 63544       Elsevier; PMC  Severe acute respiratory syndrome coronavirus ...
# 63545       Elsevier; PMC  Prevalence of enteropathogens in cats with and...
# 63546       Elsevier; PMC  Direct diagnosis of human respiratory coronavi...
# 63547       Elsevier; PMC  Development of SYBR Green real-time RT-PCR for...
# 63548       Elsevier; PMC  Enfermedades infecciosas. Concepto. Clasificac...
# 63549       Elsevier; PMC  Is anaerobic digestion a reliable barrier for ...
# 63550       Elsevier; PMC        Porcine Transmissible Gastroenteritis Virus
# 63551       Elsevier; PMC  An evolving arsenal: viral RNA detection by RI...
# 63552       Elsevier; PMC  Causes of Emergency Department Overcrowding an...
# 63553       Elsevier; PMC  Recommendations for treatment of childhood non...
# 63554       Elsevier; PMC  Plausible mechanisms of Niclosamide as an anti...
# 63555       Elsevier; PMC  An integrated microfluidic system for rapid di...
# 63556       Elsevier; PMC  Experts’ request to the Spanish Government: mo...
# 63557       Elsevier; PMC  Current perspectives on the phylogeny of Filov...
# 63558  Elsevier; PMC; WHO  Anti-HCV, nucleotide inhibitors, repurposing a...
# 63559       Elsevier; PMC  Replacement Management in Cattle | Breeding St...
# 63560       Elsevier; PMC  Canine corona virus vaccine production by infe...
# 63561       Elsevier; PMC  Biosecurity and biocontainment in alpaca opera...
# 63562       Elsevier; PMC                  Measles returns to the Gaza Strip
# 63563       Elsevier; PMC  The Clinical Presentation and Outcomes of Chil...
# 63564       Elsevier; PMC  Chapter 546 Coronavirus Picornain-like Cystein...
# 63565       Elsevier; PMC                    Alterations in Blood Components
# 63566       Elsevier; PMC  Chapter 4 Epidemiology of Multiple Sclerosis E...
# 63567       Elsevier; PMC                                              Forum
# 63568       Elsevier; PMC  Synthesis of a bacteriophage MB78 late protein...
# 63569       Elsevier; PMC  Chapitre 10 Rhinites, sinusites et rhinosinusites
# 63570       Elsevier; PMC  The moonlighting enzyme CD13: old and new func...
#
#                                       doi       pmcid   pubmed_id  \
# 0                10.1093/emboj/20.24.7220   PMC125340  11742998.0
# 1                 10.1093/emboj/21.9.2076   PMC125375  11980704.0
# 2                10.1093/emboj/20.14.3840   PMC125543  11447125.0
# 3                    10.1093/emboj/cdf327   PMC126080  12093723.0
# 4                    10.1093/emboj/cdf635   PMC136939  12456663.0
# 5                   10.1186/1471-2458-3-5   PMC140314  12525263.0
# 6                 10.1186/gb-2003-4-5-213   PMC156578  12734001.0
# 7                    10.1093/emboj/cdg365   PMC169038  12881428.0
# 8                 10.1186/gb-2003-4-7-113   PMC193621  12844350.0
# 9                    10.1093/emboj/cdg517   PMC204495  14517239.0
# 10                  10.1186/1471-2350-4-9   PMC212558  12969506.0
# 11                 10.1186/1471-2334-3-19   PMC222908  12964944.0
# 12                 10.1186/1471-2180-3-20   PMC222911  14499001.0
# 13                 10.1186/1471-2105-4-43   PMC222961  14499005.0
# 14           10.1371/journal.pbio.0000002   PMC261870  14624234.0
# 15                  10.1186/1472-6807-3-8   PMC280685  14609438.0
# 16                 10.1186/1476-069x-2-15   PMC293432  14629774.0
# 17           10.1371/journal.pbio.0000066   PMC300679  14691538.0
# 18               10.1093/emboj/19.17.4701   PMC302072  10970862.0
# 19                          10.1251/bpo66   PMC302190  14702098.0
# 20               10.1093/emboj/19.15.3932   PMC306617  10921875.0
# 21                  10.1186/1476-072x-3-1   PMC343292  14748927.0
# 22                  10.1186/1476-072x-3-2   PMC343293  14748926.0
# 23                         10.1186/cc2452   PMC420028  15025770.0
# 24                         10.1186/cc2429   PMC420071  14975048.0
# 25                         10.1186/cc2449   PMC420074  14975037.0
# 26                  10.1186/1476-0711-3-6   PMC421742  15132748.0
# 27                 10.1186/1471-2105-5-65   PMC434493  15161495.0
# 28                 10.1186/1471-2105-5-72   PMC442122  15180906.0
# 29                 10.1186/1471-2148-4-21   PMC446188  15222897.0
# ...                                   ...         ...         ...
# 63541  10.1016/b978-0-7020-3935-5.00002-1  PMC7149576         NaN
# 63542          10.1016/j.jmii.2020.02.012         NaN         NaN
# 63543          10.1016/j.eimc.2015.10.006  PMC7103361  26620605.0
# 63544          10.1016/j.bbrc.2006.03.091  PMC7092935  16580632.0
# 63545          10.1016/j.tvjl.2018.04.008  PMC7110508  29871750.0
# 63546       10.1016/s0166-0934(01)00343-3  PMC7119936  11483217.0
# 63547      10.1016/j.jviromet.2009.03.001  PMC7119535  19442847.0
# 63548       10.1016/s0304-5412(10)70027-5  PMC7144102         NaN
# 63549     10.1016/j.scitotenv.2019.03.063  PMC7112049  30870755.0
# 63550  10.1016/b978-0-12-524180-9.50089-3  PMC7149672         NaN
# 63551           10.1016/j.mib.2014.05.004  PMC7108371  24912143.0
# 63552      10.1016/j.jemermed.2018.02.009  PMC7135171  29573904.0
# 63553       10.1016/s1473-3099(09)70044-1  PMC7172451  19246022.0
# 63554          10.1016/j.mehy.2020.109765  PMC7195103  32361588.0
# 63555          10.1016/j.bios.2009.08.020  PMC7125828  19744849.0
# 63556       10.1016/s0140-6736(20)30753-4  PMC7158944  32224297.0
# 63557        10.1016/j.meegid.2011.06.017  PMC7106080  21742058.0
# 63558           10.1016/j.lfs.2020.117477  PMC7089605  32119961.0
# 63559  10.1016/b978-0-12-374407-4.00446-5  PMC7149803         NaN
# 63560        10.1016/0264-410x(89)90217-x  PMC7131078         NaN
# 63561   10.1016/j.smallrumres.2005.07.011  PMC7135564         NaN
# 63562       10.1016/s1473-3099(20)30075-x  PMC7129412  32112765.0
# 63563           10.1016/j.idc.2005.05.009  PMC3351010  16102649.0
# 63564  10.1016/b978-0-12-382219-2.00544-5  PMC7149994         NaN
# 63565  10.1016/b978-0-12-801238-3.64251-4  PMC7152208         NaN
# 63566  10.1016/b978-1-4160-6068-0.00004-8  PMC7173578         NaN
# 63567       10.1016/s1067-991x(03)00005-1  PMC7128336         NaN
# 63568       10.1016/s0378-1119(00)00264-x  PMC7173172  10974552.0
# 63569  10.1016/b978-2-294-74503-4.00010-5  PMC7184226         NaN
# 63570        10.1016/j.molmed.2008.06.003  PMC7106361  18603472.0
#
#            license                                           abstract  \
# 0         green-oa  Nidovirus subgenomic mRNAs contain a leader se...
# 1         green-oa  CEACAM1 is a member of the carcinoembryonic an...
# 2            no-cc  Hepatitis C virus (HCV) is an important human ...
# 3         green-oa  The key enzyme in coronavirus polyprotein proc...
# 4         green-oa  Arteri-, corona-, toro- and roniviruses are ev...
# 5            no-cc  BACKGROUND: Rhinovirus, the most common cause ...
# 6            no-cc  Recent analyses of human pathogens have reveal...
# 7         green-oa  Ribosomal frameshifting signals are found in m...
# 8            no-cc  The army of the men of death, in John Bunyan's...
# 9         green-oa  Intracellular replication of the bacterial pat...
# 10           no-cc  BACKGROUND: The human leukocyte antigen (HLA) ...
# 11           no-cc  BACKGROUND: An epidemic of a Severe Acute Resp...
# 12           no-cc  BACKGROUND: Severe acute respiratory syndrome ...
# 13           no-cc  BACKGROUND: The exact origin of the cause of t...
# 14           cc-by  Because of the constant threat posed by emergi...
# 15           no-cc  BACKGROUND: Tripeptidyl-peptidase I, also know...
# 16           no-cc  BACKGROUND: Severe acute respiratory syndrome ...
# 17           no-cc  Personal account of a young virologist working...
# 18        green-oa  Heterogeneous nuclear ribonucleoprotein (hnRNP...
# 19           no-cc  The UBA domain is a conserved sequence motif a...
# 20        green-oa  We examined the role of the microtubule cytosk...
# 21           no-cc  The term "Geographic Information Systems" (GIS...
# 22           no-cc  From geographic mapping at different scales to...
# 23           no-cc  SARS (severe acute respiratory syndrome) prove...
# 24           no-cc                                                NaN
# 25           no-cc                                                NaN
# 26           no-cc  BACKGROUND: One controversial source of infect...
# 27           no-cc  BACKGROUND: We have compared 38 isolates of th...
# 28           no-cc  BACKGROUND: Despite the passing of more than a...
# 29           no-cc  BACKGROUND: The outbreak of severe acute respi...
# ...            ...                                                ...
# 63541        no-cc                                                NaN
# 63542  cc-by-nc-nd  Since the emergence of coronavirus disease 201...
# 63543        no-cc  The analytical performance of the new Alere™ i...
# 63544    els-covid  Abstract Severe acute respiratory syndrome cor...
# 63545        no-cc  The objective of this study was to determine t...
# 63546    els-covid  Abstract An RT-PCR-hybridization was developed...
# 63547    els-covid  Abstract Unclassified bovine enteric calicivir...
# 63548    els-covid                                                NaN
# 63549        no-cc  As World Health Organization advocates, the gl...
# 63550    els-covid  Publisher Summary This chapter provides an ove...
# 63551    els-covid  RIG-I-like receptors (RLRs) utilize a speciali...
# 63552    els-covid  Abstract Background Emergency department (ED) ...
# 63553        no-cc  WHO recommendations for early antimicrobial tr...
# 63554    els-covid  Abstract Corona virus disease 2019 (COVID-19) ...
# 63555        no-cc  This study reports an integrated microfluidic ...
# 63556        no-cc                                                NaN
# 63557    els-covid  Abstract Sporadic fatal outbreaks of disease i...
# 63558    els-covid  Abstract Aims A newly emerged Human Coronaviru...
# 63559        no-cc  Rearing replacement heifers is part of herd su...
# 63560    els-covid                                                NaN
# 63561    els-covid  Abstract Biosecurity on South American camelid...
# 63562    els-covid                                                NaN
# 63563     green-oa                                                NaN
# 63564    els-covid  The third edition of the Handbook of Proteolyt...
# 63565        no-cc  Cellular blood components include leukocytes, ...
# 63566    els-covid  Publisher Summary This chapter discusses the e...
# 63567    els-covid                                                NaN
# 63568    els-covid  Abstract MB78 is a virulent phage of Salmonell...
# 63569    els-covid  ■. Une douleur faciale unilatérale quotidienne...
# 63570    els-covid  Aminopeptidase N (CD13) is a widely expressed ...
#
#       publish_time                                            authors  \
# 0       2001-12-17  Pasternak, Alexander O.; van den Born, Erwin; ...
# 1       2002-05-01  Tan, Kemin; Zelus, Bruce D.; Meijers, Rob; Liu...
# 2       2001-07-16  Xu, Zhenming; Choi, Jinah; Yen, T.S.Benedict; ...
# 3       2002-07-01  Anand, Kanchan; Palm, Gottfried J.; Mesters, J...
# 4       2002-12-01  van Vliet, A.L.W.; Smits, S.L.; Rottier, P.J.M...
# 5       2003-01-13  Myatt, Theodore A; Johnston, Sebastian L; Rudn...
# 6       2003-04-28                                   Disotell, Todd R
# 7       2003-08-01  Napthine, Sawsan; Vidakovic, Marijana; Girnary...
# 8       2003-06-27                                  Petsko, Gregory A
# 9       2003-10-01               Salcedo, Suzana P.; Holden, David W.
# 10      2003-09-12  Lin, Marie; Tseng, Hsiang-Kuang; Trejaut, Jean...
# 11      2003-09-10  Ng, Tuen Wai; Turinici, Gabriel; Danchin, Antoine
# 12      2003-09-21                    Kliger, Yossef; Levanon, Erez Y
# 13      2003-09-20     Yap, Yee Leng; Zhang, Xue Wu; Danchin, Antoine
# 14      2003-11-17  Wang, David; Urisman, Anatoly; Liu, Yu-Tsueng;...
# 15      2003-11-11  Wlodawer, Alexander; Durell, Stewart R; Li, Mi...
# 16      2003-11-20  Cui, Yan; Zhang, Zuo-Feng; Froines, John; Zhao...
# 17      2003-12-22                                  Poh Ng, Lisa Fong
# 18      2000-09-01  Shi, Stephanie T.; Huang, Peiyong; Li, Hsin-Pa...
# 19      2003-12-12  Pridgeon, Julia W.; Geetha, Thangiah; Wooten, ...
# 20      2000-08-01  Ploubidou, Aspasia; Moreau, Violaine; Ashman, ...
# 21      2004-01-28                              Boulos, Maged N Kamel
# 22      2004-01-28                              Boulos, Maged N Kamel
# 23      2004-01-26  Gomersall, Charles D; Kargel, Marcus J; Lapins...
# 24      2004-01-02                       Granton, Jeff; Granton, John
# 25      2004-01-02                                     Ball, Jonathan
# 26      2004-05-07  McMahon, James M; Simm, Malgorzata; Milano, Da...
# 27      2004-05-25  Pavlović-Lažetić, Gordana M; Mitić, Nenad S; B...
# 28      2004-06-06  Kiemer, Lars; Lund, Ole; Brunak, Søren; Blom, ...
# 29      2004-06-28  Zhao, Zhongming; Li, Haipeng; Wu, Xiaozhuang; ...
# ...            ...                                                ...
# 63541   2011-04-29           Torres-Vélez, Fernando J.; Brown, Corrie
# 63542         2020  Lai, Chih-Cheng; Liu, Yen Hung; Wang, Cheng-Yi...
# 63543   2015-11-25  Riazzo, Cristina; Pérez-Ruiz, Mercedes; Sanbon...
# 63544   2006-05-19  Fielding, Burtram C.; Gunalan, Vithiagaran; Ta...
# 63545   2018-04-16  Andersen, L.A.; Levy, J.K.; McManus, C.M.; McG...
# 63546   2001-09-30  Vabret, Astrid; Mouthon, Franck; Mourez, Thoma...
# 63547   2009-07-31  Park, Sang-Ik; Park, Da-Hae; Saif, Linda J.; J...
# 63548   2010-02-28  García Palomo, J.D.; Agüero Balbín, J.; Parra ...
# 63549   2019-06-10                                Zhao, Qian; Liu, Yu
# 63550   1983-12-31                                 ODEND'HAL, STEWART
# 63551   2014-08-31  Fitzgerald, Megan E; Rawling, David C; Vela, A...
# 63552   2018-05-31  Wang, Zhen; Xiong, Xiaying; Wang, Shuang; Yan,...
# 63553   2009-02-23  Grant, Gavin B; Campbell, Harry; Dowell, Scott...
# 63554   2020-07-31  Pindiprolu, Sai Kiran S.S.; Pindiprolu, Sai Ha...
# 63555   2009-12-15  Lee, Yu-Fang; Lien, Kang-Yi; Lei, Huan-Yao; Le...
# 63556   2020-03-27  Mitjà, Oriol; Arenas, Àlex; Rodó, Xavier; Tobi...
# 63557   2011-10-31  Barrette, Roger W.; Xu, Lizhe; Rowland, Jessic...
# 63558   2020-05-01                                    Elfiky, Abdo A.
# 63559   2011-04-07                    Stevenson, J.S.; Ahmadzadeh, A.
# 63560   1989-08-31                                                NaN
# 63561   2006-02-28  Barrington, G.M.; Allen, A.J.; Parish, S.M.; T...
# 63562   2020-03-31                                   Bagcchi, Sanjeet
# 63563   2005-09-01                                  Williams, John V.
# 63564   2013-12-31          Stobart, Christopher C.; Denison, Mark R.
# 63565   2017-11-27                                       Carter, C.M.
# 63566   2010-12-31            Ascherio, Alberto; Munger, Kassandra L.
# 63567   2003-08-31                                                NaN
# 63568   2000-08-22  Kolla, Venkatadri; Chakravorty, Maharani; Pand...
# 63569   2016-12-31                               Sauvage, Jean-Pierre
# 63570   2008-08-31                                 Mina-Osorio, Paola
#
#                                                  journal        mag_id  \
# 0                                       The EMBO Journal           NaN
# 1                                       The EMBO Journal           NaN
# 2                                                 EMBO J           NaN
# 3                                       The EMBO Journal           NaN
# 4                                       The EMBO Journal           NaN
# 5                                      BMC Public Health           NaN
# 6                                            Genome Biol           NaN
# 7                                       The EMBO Journal           NaN
# 8                                            Genome Biol           NaN
# 9                                       The EMBO Journal           NaN
# 10                                         BMC Med Genet           NaN
# 11                                        BMC Infect Dis           NaN
# 12                                         BMC Microbiol           NaN
# 13                                    BMC Bioinformatics           NaN
# 14                                             PLoS Biol           NaN
# 15                                       BMC Struct Biol           NaN
# 16                                        Environ Health           NaN
# 17                                             PLoS Biol           NaN
# 18                                      The EMBO Journal           NaN
# 19                                    Biol Proced Online           NaN
# 20                                      The EMBO Journal           NaN
# 21                                    Int J Health Geogr           NaN
# 22                                    Int J Health Geogr           NaN
# 23                                             Crit Care           NaN
# 24                                             Crit Care           NaN
# 25                                             Crit Care           NaN
# 26                         Ann Clin Microbiol Antimicrob           NaN
# 27                                    BMC Bioinformatics           NaN
# 28                                    BMC Bioinformatics           NaN
# 29                                         BMC Evol Biol           NaN
# ...                                                  ...           ...
# 63541  Tropical Infectious Diseases: Principles, Path...           NaN
# 63542  Journal of Microbiology, Immunology and Infection  2.029689e+09
# 63543                       Enferm Infecc Microbiol Clin           NaN
# 63544  Biochemical and Biophysical Research Communica...           NaN
# 63545                                              Vet J           NaN
# 63546                     Journal of Virological Methods           NaN
# 63547                     Journal of Virological Methods           NaN
# 63548  Medicine - Programa de Formación Médica Contin...           NaN
# 63549                                  Sci Total Environ           NaN
# 63550  The Geographical Distribution of Animal Viral ...           NaN
# 63551                    Current Opinion in Microbiology           NaN
# 63552                  The Journal of Emergency Medicine           NaN
# 63553                                  Lancet Infect Dis           NaN
# 63554                                 Medical Hypotheses           NaN
# 63555                                Biosens Bioelectron           NaN
# 63556                                             Lancet           NaN
# 63557                  Infection, Genetics and Evolution           NaN
# 63558                                      Life Sciences  1.174154e+09
# 63559                     Encyclopedia of Dairy Sciences           NaN
# 63560                                            Vaccine           NaN
# 63561                            Small Ruminant Research           NaN
# 63562                     The Lancet Infectious Diseases           NaN
# 63563        Infectious Disease Clinics of North America           NaN
# 63564                    Handbook of Proteolytic Enzymes           NaN
# 63565                           Comprehensive Toxicology           NaN
# 63566                            Blue Books of Neurology           NaN
# 63567                                Air Medical Journal           NaN
# 63568                                               Gene           NaN
# 63569                                        Guide D'orl           NaN
# 63570                       Trends in Molecular Medicine           NaN
#
#       who_covidence_id arxiv_id  \
# 0                  NaN      NaN
# 1                  NaN      NaN
# 2                  NaN      NaN
# 3                  NaN      NaN
# 4                  NaN      NaN
# 5                  NaN      NaN
# 6                  NaN      NaN
# 7                  NaN      NaN
# 8                  NaN      NaN
# 9                  NaN      NaN
# 10                 NaN      NaN
# 11                 NaN      NaN
# 12                 NaN      NaN
# 13                 NaN      NaN
# 14                 NaN      NaN
# 15                 NaN      NaN
# 16                 NaN      NaN
# 17                 NaN      NaN
# 18                 NaN      NaN
# 19                 NaN      NaN
# 20                 NaN      NaN
# 21                 NaN      NaN
# 22                 NaN      NaN
# 23                 NaN      NaN
# 24                 NaN      NaN
# 25                 NaN      NaN
# 26                 NaN      NaN
# 27                 NaN      NaN
# 28                 NaN      NaN
# 29                 NaN      NaN
# ...                ...      ...
# 63541              NaN      NaN
# 63542            #4530      NaN
# 63543              NaN      NaN
# 63544              NaN      NaN
# 63545              NaN      NaN
# 63546              NaN      NaN
# 63547              NaN      NaN
# 63548              NaN      NaN
# 63549              NaN      NaN
# 63550              NaN      NaN
# 63551              NaN      NaN
# 63552              NaN      NaN
# 63553              NaN      NaN
# 63554              NaN      NaN
# 63555              NaN      NaN
# 63556              NaN      NaN
# 63557              NaN      NaN
# 63558            #2799      NaN
# 63559              NaN      NaN
# 63560              NaN      NaN
# 63561              NaN      NaN
# 63562              NaN      NaN
# 63563              NaN      NaN
# 63564              NaN      NaN
# 63565              NaN      NaN
# 63566              NaN      NaN
# 63567              NaN      NaN
# 63568              NaN      NaN
# 63569              NaN      NaN
# 63570              NaN      NaN
#
#                                           pdf_json_files  \
# 0      document_parses/pdf_json/b2897e1277f56641193a6...
# 1      document_parses/pdf_json/e3d0d482ebd9a8ba81c25...
# 2      document_parses/pdf_json/00b1d99e70f779eb4ede5...
# 3      document_parses/pdf_json/cf584e00f637cbd8f1bb3...
# 4      document_parses/pdf_json/dde02f11923815e6a16a3...
# 5      document_parses/pdf_json/1e1286db212100993d03c...
# 6      document_parses/pdf_json/8ae137c8da1607b3a8e4c...
# 7      document_parses/pdf_json/23bc55d6f63fab18b0200...
# 8                                                    NaN
# 9      document_parses/pdf_json/7ff45096210eeb392d51f...
# 10     document_parses/pdf_json/0104f6ceccf92ae8567a0...
# 11     document_parses/pdf_json/5b68a553a7cbbea134727...
# 12     document_parses/pdf_json/3ed670f60a7be2e3e2a99...
# 13     document_parses/pdf_json/59ffca26c9d1f881e4e37...
# 14     document_parses/pdf_json/c63c4d58d170136b8d3b5...
# 15     document_parses/pdf_json/dab2d95da5307c840eb4a...
# 16     document_parses/pdf_json/75ebad1e8641e5fe2a512...
# 17     document_parses/pdf_json/6c0dee643345c93436cfa...
# 18     document_parses/pdf_json/14e0cac6e86d62859e6c9...
# 19     document_parses/pdf_json/d09b79026117ec9faebba...
# 20     document_parses/pdf_json/44102e3e69e70ad2a73e7...
# 21     document_parses/pdf_json/06559dd625491d6474ee8...
# 22     document_parses/pdf_json/d81ae79ebc6462fd3de07...
# 23     document_parses/pdf_json/87390d2ae28407b3e03e6...
# 24     document_parses/pdf_json/c5131e5f5c6000ec84139...
# 25     document_parses/pdf_json/8a7d5de5ea680e784ab2b...
# 26     document_parses/pdf_json/e4b48ce0579f908da6dd3...
# 27     document_parses/pdf_json/52ce19fe79de46d9bb0fa...
# 28     document_parses/pdf_json/b499a41ad1d85a0e071b5...
# 29     document_parses/pdf_json/4a228865af2c19adf9386...
# ...                                                  ...
# 63541                                                NaN
# 63542  document_parses/pdf_json/29d15895b6f3c6472f3ba...
# 63543  document_parses/pdf_json/a68721d234eacc8dd31ff...
# 63544  document_parses/pdf_json/1e23bde4e435cbcb5f23f...
# 63545  document_parses/pdf_json/66a268ec094c120ea3c4d...
# 63546  document_parses/pdf_json/8d1498b4b95b0bf8f6d95...
# 63547  document_parses/pdf_json/258ce44a78453f7d28e24...
# 63548  document_parses/pdf_json/9074747aea8d86b85b959...
# 63549  document_parses/pdf_json/ba1ab411e62b278e72259...
# 63550  document_parses/pdf_json/3d678ce5b0b21cca48a07...
# 63551  document_parses/pdf_json/b1a4463a80b51e113e68c...
# 63552  document_parses/pdf_json/9fd57e68de682f9cf91b1...
# 63553  document_parses/pdf_json/e44284f191fc9522ccc67...
# 63554  document_parses/pdf_json/2e7f047e863ea96cf05fe...
# 63555                                                NaN
# 63556  document_parses/pdf_json/a243da5abdf029948b1fa...
# 63557  document_parses/pdf_json/613c002da74850a9055fc...
# 63558  document_parses/pdf_json/fbd0883af84e01bf3f6c8...
# 63559  document_parses/pdf_json/d66311a0656685a7a39bd...
# 63560                                                NaN
# 63561  document_parses/pdf_json/d0f619ec08f0d63dd120c...
# 63562                                                NaN
# 63563  document_parses/pdf_json/78c0852bc3566669cb9f7...
# 63564  document_parses/pdf_json/f5110e5b6c82b1000b924...
# 63565  document_parses/pdf_json/1c2ec5f7aa7133b58659a...
# 63566  document_parses/pdf_json/7d94ed06736e171ba688a...
# 63567                                                NaN
# 63568  document_parses/pdf_json/45713f9e6085b078e4dc9...
# 63569  document_parses/pdf_json/4534efb66ced62c3f0bf6...
# 63570  document_parses/pdf_json/f616fc58218452c559486...
#
#                                      pmc_json_files  \
# 0       document_parses/pmc_json/PMC125340.xml.json
# 1       document_parses/pmc_json/PMC125375.xml.json
# 2       document_parses/pmc_json/PMC125543.xml.json
# 3       document_parses/pmc_json/PMC126080.xml.json
# 4       document_parses/pmc_json/PMC136939.xml.json
# 5       document_parses/pmc_json/PMC140314.xml.json
# 6       document_parses/pmc_json/PMC156578.xml.json
# 7       document_parses/pmc_json/PMC169038.xml.json
# 8                                               NaN
# 9       document_parses/pmc_json/PMC204495.xml.json
# 10      document_parses/pmc_json/PMC212558.xml.json
# 11      document_parses/pmc_json/PMC222908.xml.json
# 12      document_parses/pmc_json/PMC222911.xml.json
# 13      document_parses/pmc_json/PMC222961.xml.json
# 14      document_parses/pmc_json/PMC261870.xml.json
# 15      document_parses/pmc_json/PMC280685.xml.json
# 16      document_parses/pmc_json/PMC293432.xml.json
# 17      document_parses/pmc_json/PMC300679.xml.json
# 18      document_parses/pmc_json/PMC302072.xml.json
# 19      document_parses/pmc_json/PMC302190.xml.json
# 20      document_parses/pmc_json/PMC306617.xml.json
# 21      document_parses/pmc_json/PMC343292.xml.json
# 22      document_parses/pmc_json/PMC343293.xml.json
# 23      document_parses/pmc_json/PMC420028.xml.json
# 24      document_parses/pmc_json/PMC420071.xml.json
# 25      document_parses/pmc_json/PMC420074.xml.json
# 26      document_parses/pmc_json/PMC421742.xml.json
# 27      document_parses/pmc_json/PMC434493.xml.json
# 28      document_parses/pmc_json/PMC442122.xml.json
# 29      document_parses/pmc_json/PMC446188.xml.json
# ...                                             ...
# 63541  document_parses/pmc_json/PMC7149576.xml.json
# 63542                                           NaN
# 63543  document_parses/pmc_json/PMC7103361.xml.json
# 63544  document_parses/pmc_json/PMC7092935.xml.json
# 63545  document_parses/pmc_json/PMC7110508.xml.json
# 63546  document_parses/pmc_json/PMC7119936.xml.json
# 63547  document_parses/pmc_json/PMC7119535.xml.json
# 63548  document_parses/pmc_json/PMC7144102.xml.json
# 63549  document_parses/pmc_json/PMC7112049.xml.json
# 63550  document_parses/pmc_json/PMC7149672.xml.json
# 63551  document_parses/pmc_json/PMC7108371.xml.json
# 63552  document_parses/pmc_json/PMC7135171.xml.json
# 63553  document_parses/pmc_json/PMC7172451.xml.json
# 63554  document_parses/pmc_json/PMC7195103.xml.json
# 63555  document_parses/pmc_json/PMC7125828.xml.json
# 63556  document_parses/pmc_json/PMC7158944.xml.json
# 63557  document_parses/pmc_json/PMC7106080.xml.json
# 63558  document_parses/pmc_json/PMC7089605.xml.json
# 63559  document_parses/pmc_json/PMC7149803.xml.json
# 63560                                           NaN
# 63561  document_parses/pmc_json/PMC7135564.xml.json
# 63562                                           NaN
# 63563  document_parses/pmc_json/PMC3351010.xml.json
# 63564                                           NaN
# 63565  document_parses/pmc_json/PMC7152208.xml.json
# 63566                                           NaN
# 63567                                           NaN
# 63568  document_parses/pmc_json/PMC7173172.xml.json
# 63569                                           NaN
# 63570  document_parses/pmc_json/PMC7106361.xml.json
#
#                                                      url
# 0      http://europepmc.org/articles/pmc125340?pdf=re...
# 1      http://europepmc.org/articles/pmc125375?pdf=re...
# 2      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 3      http://europepmc.org/articles/pmc126080?pdf=re...
# 4      http://europepmc.org/articles/pmc136939?pdf=re...
# 5      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 6      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 7      http://europepmc.org/articles/pmc169038?pdf=re...
# 8      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 9      http://europepmc.org/articles/pmc204495?pdf=re...
# 10     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...
# 11     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...
# 12     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...
# 13     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...
# 14     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...
# 15     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...
# 16     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...
# 17     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 18     http://europepmc.org/articles/pmc302072?pdf=re...
# 19     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 20     http://europepmc.org/articles/pmc306617?pdf=re...
# 21     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 22     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 23     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# 24     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# 25     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# 26     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# 27     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# 28     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# 29     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# ...                                                  ...
# 63541                                                NaN
# 63542                                                NaN
# 63543                                                NaN
# 63544                                                NaN
# 63545                                                NaN
# 63546                                                NaN
# 63547                                                NaN
# 63548                                                NaN
# 63549                                                NaN
# 63550                                                NaN
# 63551                                                NaN
# 63552                                                NaN
# 63553                                                NaN
# 63554                                                NaN
# 63555                                                NaN
# 63556                                                NaN
# 63557                                                NaN
# 63558                                                NaN
# 63559                                                NaN
# 63560                                                NaN
# 63561                                                NaN
# 63562                                                NaN
# 63563  http://europepmc.org/articles/pmc3351010?pdf=r...
# 63564                                                NaN
# 63565                                                NaN
# 63566                                                NaN
# 63567                                                NaN
# 63568                                                NaN
# 63569                                                NaN
# 63570                                                NaN
#
# [63571 rows x 18 columns]

# %% [markdown]
# First start by making sure the columns that are supposed to be single valued and unique are actually so.

# %%
SingleValued_and_Unique = ['cord_uid', 'pmcid', 'pubmed_id', 'mag_id', 'who_covidence_id', 'arxiv_id', 'url']

# %%
for Column in SingleValued_and_Unique:
    print(Column, metadataFrame[Column].dropna().is_unique)
# Out:
# cord_uid False
# pmcid True
# pubmed_id False
# mag_id False
# who_covidence_id True
# arxiv_id True
# url False

# %% [markdown]
# All except who_covidence_id and arxiv_id appear to be non-unique. Isn't that just wonderful...
#
# Start by checking the cord_uid.

# %%
ValueCounts = metadataFrame['cord_uid'].value_counts()
ValueCounts[ValueCounts>1]
# Out:
# fzq71ghi    8
# jsk1oztb    3
# m6q8kbjg    2
# 5kzx5hgg    2
# 4hlvrfeh    2
# adygntbe    2
# c4u0gxp5    2
# 8fwa2c24    2
# e9pwguwm    2
# 4fbr8fx8    2
# xjpev4jw    2
# eich19nx    2
# 3ury4hnv    2
# 5ei7iwu0    2
# j7swau26    2
# hox2xwjg    2
# o4r34pff    2
# vqbreyna    2
# mmls866r    2
# huablvd1    2
# qhftb6d7    2
# j3b964oz    2
# 940au47y    2
# vp5358rr    2
# 21htepa1    2
# 30duqivi    2
# 6hdoap81    2
# 0klupmep    2
# sv9mdgek    2
# 6z5f2gz3    2
# 7y8fd521    2
# 2maferew    2
# brz1fn2h    2
# 21qu87oh    2
# laq5ze8o    2
# 0z5wacxs    2
# 79mzwv1c    2
# Name: cord_uid, dtype: int64

# %% [markdown]
# Ugh. As this supposed to the persistent identifier, looks like some duplicates happening.
#
# So the easiest way to start with this is by checking to see if these are duplicates, and if they are just eliminating the double records.

# %%
metadataFrame[metadataFrame['cord_uid'].duplicated(keep=False)].sort_values(by=['cord_uid'])
# Out:
#        cord_uid                                       sha  source_x  \
# 30977  0klupmep                                       NaN  Elsevier
# 16454  0klupmep                                       NaN       PMC
# 30885  0z5wacxs  7e787fd2ae5b544add6281d3d40ad322de26aa17  Elsevier
# 16452  0z5wacxs  7e787fd2ae5b544add6281d3d40ad322de26aa17       PMC
# 30416  21htepa1  a25e212b03cc65c44dcc336775b101934e30f041  Elsevier
# 16473  21htepa1                                       NaN       PMC
# 30156  21qu87oh  68249d769e1926678af8d52d2484e36787e13525  Elsevier
# 42065  21qu87oh                                       NaN       PMC
# 16467  2maferew                                       NaN       PMC
# 30766  2maferew  6744bc52b1b29d2ab28cbaeef8942eebece5175b  Elsevier
# 30994  30duqivi  4e8306655e7f3c6ae88db9708a400ab78c011700  Elsevier
# 42071  30duqivi                                       NaN       PMC
# 30159  3ury4hnv  5d2ed78357c0c88b4500d644f4a717d0192a0d2d  Elsevier
# 42072  3ury4hnv                                       NaN       PMC
# 30920  4fbr8fx8  bd3945ec343cc4535650c9425aa143f71716de7c  Elsevier
# 15525  4fbr8fx8                                       NaN       PMC
# 30590  4hlvrfeh  e666b6507719561e391f4246a140695b213c8e5b  Elsevier
# 16470  4hlvrfeh                                       NaN       PMC
# 42067  5ei7iwu0                                       NaN       PMC
# 30157  5ei7iwu0  bad208dd9e4c71121ae4160ccf916c9f69eb62a3  Elsevier
# 16472  5kzx5hgg                                       NaN       PMC
# 30417  5kzx5hgg                                       NaN  Elsevier
# 30155  6hdoap81  88a8c34283c82d0f854254d077953980954bd366  Elsevier
# 42066  6hdoap81                                       NaN       PMC
# 30146  6z5f2gz3  7fa6a89af06e588d737c868cdcebceaee14d7532  Elsevier
# 42052  6z5f2gz3                                       NaN       PMC
# 42070  79mzwv1c                                       NaN       PMC
# 30145  79mzwv1c  f3d760db99cfc4224b989b1e53bec59e77823e05  Elsevier
# 31020  7y8fd521  58b578c2c6619df320c9a0bcb4d434edc2300d00  Elsevier
# 6994   7y8fd521                                       NaN       PMC
# ...         ...                                       ...       ...
# 41846  fzq71ghi                                       NaN       WHO
# 42365  hox2xwjg                                       NaN       PMC
# 30917  hox2xwjg  a8dbc77e172c01c4f5c548f2764286b75e618ef5  Elsevier
# 30147  huablvd1  4656f1c7a371893b0b6dcb31007fe89b64ab325f  Elsevier
# 42054  huablvd1                                       NaN       PMC
# 17267  j3b964oz  c1402ba933f4a2a122d5ea706b19fc536568ca53       PMC
# 19619  j3b964oz  346855c8950ef288f1a27e3e1a7281c7e49027c5       PMC
# 30153  j7swau26  01213acdd86020357259f2a1094bc43f9bb79796  Elsevier
# 42064  j7swau26                                       NaN       PMC
# 28796  jsk1oztb                                       NaN       PMC
# 28806  jsk1oztb                                       NaN       PMC
# 28744  jsk1oztb  24cc817d27e43b9e7bdc5537872088710ea2a566       PMC
# 43261  laq5ze8o                                       NaN       PMC
# 45083  laq5ze8o                                       NaN       WHO
# 15968  m6q8kbjg  ea2c56be23c5e3fb8261d9612585433aa12f1cec       PMC
# 45076  m6q8kbjg                                       NaN       WHO
# 16451  mmls866r                                       NaN       PMC
# 30919  mmls866r  151b80cfa218d8a252c1720d3e2f2e7b1effd96c  Elsevier
# 42289  o4r34pff                                       NaN       PMC
# 30781  o4r34pff  9bc29db5852a315d576437636d2398ebf69ac52c  Elsevier
# 42073  qhftb6d7                                       NaN       PMC
# 30993  qhftb6d7  db732b73268d958bf73ae634a13e58df7b698c8f  Elsevier
# 30976  sv9mdgek                                       NaN  Elsevier
# 16453  sv9mdgek                                       NaN       PMC
# 30447  vp5358rr  f3eefad19d628cbe1fc0d65a6322a60d6cc5a3ab  Elsevier
# 42492  vp5358rr                                       NaN       PMC
# 15967  vqbreyna  2513ddf57215cb9297e05db838156d8856c8d6a5       PMC
# 45082  vqbreyna                                       NaN       WHO
# 30154  xjpev4jw  c05522c7132d3162d433c02ade1fc80604625a4f  Elsevier
# 43765  xjpev4jw                                       NaN       PMC
#
#                                                    title  \
# 30977             Infectious disease surveillance update
# 16454             Infectious disease surveillance update
# 30885  Transportation capacity for patients with high...
# 16452  Transportation capacity for patients with high...
# 30416                          Panspermia—true or false?
# 16473                          Panspermia—true or false?
# 30156  Bystander CD8 T-Cell-Mediated Demyelination is...
# 42065  Bystander CD8 T-Cell-Mediated Demyelination is...
# 16467  Virologie : l’apport de la biologie moléculair...
# 30766  Virologie : l’apport de la biologie moléculair...
# 30994  Molecular Diagnosis of Severe Acute Respirator...
# 42071  Molecular Diagnosis of Severe Acute Respirator...
# 30159  Molecular and Functional Analysis of the Human...
# 42072  Molecular and Functional Analysis of the Human...
# 30920  The clinical importance of the nomenclature, e...
# 15525  The clinical importance of the nomenclature, e...
# 30590  Surrogate viruses for testing virucidal effica...
# 16470  Surrogate viruses for testing virucidal effica...
# 42067  Experimental Human Metapneumovirus Infection o...
# 30157  Experimental Human Metapneumovirus Infection o...
# 16472  Prevalence of non-pneumonic infections with SA...
# 30417  Prevalence of non-pneumonic infections with SA...
# 30155  Pneumonitis and Multi-Organ System Disease in ...
# 42066  Pneumonitis and Multi-Organ System Disease in ...
# 30146  The Heritage of Pathogen Pressures and Ancient...
# 42052  The Heritage of Pathogen Pressures and Ancient...
# 42070  Mendelian Inheritance in Man and Its Online Ve...
# 30145  Mendelian Inheritance in Man and Its Online Ve...
# 31020  Gene expression patterns in peripheral blood l...
# 6994   Gene expression patterns in peripheral blood l...
# ...                                                  ...
# 41846  Coronavirus latest: Trump requests $2.5 billio...
# 42365  Medical molecular farming: production of antib...
# 30917  Medical molecular farming: production of antib...
# 30147      Comparative Genetics of Resistance to Viruses
# 42054     Comparative genetics of resistance to viruses.
# 17267  An orally bioavailable broad-spectrum antivira...
# 19619  An orally bioavailable broad-spectrum antivira...
# 30153                 Avian Influenza Virchow's Reminder
# 42064                Avian Influenza: Virchow’s Reminder
# 28796  ‘Promoted by Hong Tao, the Chlamydia Hypothesi...
# 28806  ‘Promoted by Hong Tao, the Chlamydia Hypothesi...
# 28744  ‘Promoted by Hong Tao, the Chlamydia Hypothesi...
# 43261      Medicine’s Challenges: Vaping and Coronavirus
# 45083      Medicine's Challenges: Vaping and Coronavirus
# 15968  Emergent Strategies for the Next Phase of COVI...
# 45076  Emergent Strategies for the Next Phase of COVI...
# 16451                     Clinical virology in real time
# 30919                     Clinical virology in real time
# 42289             A Systems Framework for Vaccine Design
# 30781             A systems framework for vaccine design
# 42073  Scalable Transcriptional Analysis Routine—Mult...
# 30993  Scalable Transcriptional Analysis Routine—Mult...
# 30976             Infectious disease surveillance update
# 16453             Infectious disease surveillance update
# 30447  PARENTAL ORIGIN OF CHROMOSOME 15 DELETION IN P...
# 42492  PARENTAL ORIGIN OF CHROMOSOME 15 DELETION IN P...
# 15967  COVID-19, A Clinical Syndrome Manifesting as H...
# 45082  COVID-19, A Clinical Syndrome Manifesting as H...
# 30154  Virus-Specific Antibody, in the Absence of T C...
# 43765  Virus-Specific Antibody, in the Absence of T C...
#
#                                       doi       pmcid   pubmed_id    license  \
# 30977       10.1016/s1473-3099(19)30075-1         NaN  30833065.0  els-covid
# 16454       10.1016/s1473-3099(19)30075-1  PMC7129894  30833064.0      no-cc
# 30885             10.1111/1469-0691.12290         NaN  24750421.0  els-covid
# 16452             10.1111/1469-0691.12290  PMC7128608  25636943.0      no-cc
# 30416       10.1016/s0140-6736(03)14040-8         NaN  12907025.0  els-covid
# 16473       10.1016/s0140-6736(03)14040-8  PMC7135165  12907026.0      no-cc
# 30156       10.1016/s0002-9440(10)63126-4         NaN  14742242.0  els-covid
# 42065                                 NaN  PMC1602263  14742242.0        unk
# 16467       10.1016/s0929-693x(07)78706-7  PMC7133300  17182229.0      no-cc
# 30766       10.1016/s0929-693x(07)78706-7         NaN  18280911.0  els-covid
# 30994       10.1016/s1525-1578(10)60587-9         NaN  16258152.0  els-covid
# 42071                                 NaN  PMC1867551  16258152.0        unk
# 30159       10.1016/s0002-9440(10)64992-9         NaN  10751347.0  els-covid
# 42072                                 NaN  PMC1876871  10751347.0        unk
# 30920           10.1016/j.jcv.2004.10.021         NaN  15753006.0  els-covid
# 15525           10.1016/j.jcv.2004.10.021  PMC7108213  15571999.0      no-cc
# 30590          10.1016/j.jhin.2003.12.030         NaN  15110123.0  els-covid
# 16470          10.1016/j.jhin.2003.12.030  PMC7134461  14706271.0      no-cc
# 42067                                 NaN  PMC1615765  15161626.0        unk
# 30157       10.1016/s0002-9440(10)63750-9         NaN  15161626.0  els-covid
# 16472       10.1016/s0140-6736(04)16311-3  PMC7134863  15172784.0      no-cc
# 30417       10.1016/s0140-6736(04)16311-3         NaN  15172785.0  els-covid
# 30155       10.1016/s0002-9440(10)62989-6         NaN  16049331.0  els-covid
# 42066                                 NaN  PMC1603565  16049331.0        unk
# 30146                      10.1086/497613         NaN  16252244.0  els-covid
# 42052                                 NaN  PMC1271393  16252244.0        unk
# 42070                                 NaN  PMC1852721  17357067.0        unk
# 30145                      10.1086/514346         NaN  17357067.0  els-covid
# 31020           10.1016/j.hal.2016.03.009         NaN  28918889.0  els-covid
# 6994            10.1016/j.hal.2016.03.009  PMC5008692  27594814.0      no-cc
# ...                                   ...         ...         ...        ...
# 41846          10.1038/d41586-020-00154-w         NaN         NaN        unk
# 42365                                 NaN  PMC5496653  11335175.0        unk
# 30917       10.1016/s1360-1385(01)01922-7         NaN  11335175.0  els-covid
# 30147                      10.1086/301735         NaN   9463342.0  els-covid
# 42054                                 NaN  PMC1376908   9463342.0        unk
# 17267        10.1126/scitranslmed.abb5883  PMC7164393  32253226.0      cc-by
# 19619        10.1126/scitranslmed.abb5883  PMC7199910  32253226.0      cc-by
# 30153          10.2353/ajpath.2006.050979         NaN  16400004.0  els-covid
# 42064                                 NaN  PMC1592674  16400004.0        unk
# 28796  10.1108/s1057-6290(2010)0000011014  PMC7162272         NaN      no-cc
# 28806  10.1108/s1057-6290(2010)0000011014  PMC7162427         NaN      no-cc
# 28744  10.1108/s1057-6290(2010)0000011014  PMC7161675         NaN      no-cc
# 43261                                 NaN  PMC7023952  32158035.0        unk
# 45083                                 NaN         NaN  32158035.0        unk
# 15968            10.3947/ic.2020.52.1.105  PMC7113450  32100487.0   cc-by-nc
# 45076                                 NaN         NaN  32100487.0        unk
# 16451       10.1016/s1386-6532(02)00197-x  PMC7128152  12126716.0      no-cc
# 30919       10.1016/s1386-6532(02)00197-x         NaN  12467772.0  els-covid
# 42289                                 NaN  PMC3983719  24358511.0        unk
# 30781           10.1016/j.coi.2013.09.014         NaN  24358511.0  els-covid
# 42073                                 NaN  PMC1888488  16237214.0        unk
# 30993       10.1016/s1525-1578(10)60575-2         NaN  16237214.0  els-covid
# 30976       10.1016/s1473-3099(18)30088-4         NaN  31787262.0  els-covid
# 16453       10.1016/s1473-3099(18)30088-4  PMC7129039  29485093.0      no-cc
# 30447       10.1016/s0140-6736(83)92745-9         NaN   6134086.0  els-covid
# 42492                                 NaN  PMC5510872   6134086.0        unk
# 15967            10.3947/ic.2020.52.1.110  PMC7113449  32153144.0   cc-by-nc
# 45082                                 NaN         NaN  32153144.0        unk
# 30154       10.1016/s0002-9440(10)62301-2         NaN  15743792.0  els-covid
# 43765                                 NaN  PMC1602352  15743792.0        unk
#
#                                                 abstract publish_time  \
# 30977                                                NaN   2019-03-31
# 16454                                                NaN   2019-02-27
# 30885  Abstract Highly infectious diseases (HIDs) are...   2019-04-30
# 16452  Highly infectious diseases (HIDs) are defined ...   2015-06-22
# 30416                                                NaN   2003-08-02
# 16473                                                NaN   2003-08-02
# 30156  Mice infected with the coronavirus mouse hepat...   2004-02-29
# 42065  Mice infected with the coronavirus mouse hepat...   2004-02-12
# 16467  The conventionnal tools used for virological d...   2008-02-15
# 30766  Résumé Les outils traditionnels du diagnostic ...   2007-12-31
# 30994  Severe acute respiratory syndrome (SARS) first...   2005-11-30
# 42071  Severe acute respiratory syndrome (SARS) first...   2005-11-12
# 30159  In the present studies, we report the cloning ...   2000-04-30
# 42072  In the present studies, we report the cloning ...   2000-04-12
# 30920  Abstract Human papillomaviruses (HPVs) are for...   2005-03-31
# 15525  Human papillomaviruses (HPVs) are formally des...   2005-02-08
# 30590  Abstract Since important agents of viral nosoc...   2004-04-30
# 16470  Since important agents of viral nosocomial inf...   2004-04-09
# 42067  A substantial proportion of hitherto unexplain...   2004-06-12
# 30157  A substantial proportion of hitherto unexplain...   2004-06-30
# 16472                                                NaN   2004-05-29
# 30417                                                NaN   2004-05-29
# 30155  Severe acute respiratory syndrome (SARS) is a ...   2005-08-31
# 42066  Severe acute respiratory syndrome (SARS) is a ...   2005-08-12
# 30146  The innate immunity system constitutes the fir...   2005-11-30
# 42052  The innate immunity system constitutes the fir...   2005-09-29
# 42070                                                NaN   2007-03-08
# 30145                                                NaN   2007-04-30
# 31020  Abstract Ciguatera fish poisoning (ciguatera) ...   2016-07-31
# 6994   Ciguatera fish poisoning (ciguatera) is a comm...   2016-08-30
# ...                                                  ...          ...
# 41846  Trump requests emergency funding for coronavir...   2020-03-17
# 42365  The use of plants for medicinal purposes dates...   2001-05-12
# 30917  Abstract The use of plants for medicinal purpo...   2001-05-01
# 30147                                                NaN   1998-02-28
# 42054                                                NaN   1998-02-12
# 17267  Coronaviruses (CoVs) traffic frequently betwee...   2020-04-06
# 19619  Coronaviruses (CoVs) traffic frequently betwee...   2020-04-29
# 30153                                                NaN   2006-01-31
# 42064                                                NaN   2006-01-12
# 28796  Purpose – The aims of this chapter are twofold...   2010-04-21
# 28806  Purpose – The aims of this chapter are twofold...   2010-04-21
# 28744  Purpose – The aims of this chapter are twofold...   2010-04-21
# 43261                                                NaN         2020
# 45083                                                NaN         2020
# 15968                                                NaN   2020-02-25
# 45076                                                NaN         2020
# 16451  The ability to detect nucleic acids has had an...   2002-12-03
# 30919  Abstract The ability to detect nucleic acids h...   2002-12-31
# 42289  Numerous challenges have been identified in va...   2013-10-12
# 30781  Numerous challenges have been identified in va...   2013-10-31
# 42073  We report the development of a new technology ...   2005-10-12
# 30993  We report the development of a new technology ...   2005-10-31
# 30976                                                NaN   2018-03-31
# 16453                                                NaN   2018-02-21
# 30447                                                NaN   1983-06-04
# 42492                                                NaN   1983-06-04
# 15967                                                NaN   2020-03-10
# 45082                                                NaN         2020
# 30154  Mice infected with mouse hepatitis virus strai...   2005-03-31
# 43765  Mice infected with mouse hepatitis virus strai...   2005-03-12
#
#                                                  authors  \
# 30977                                      Zwizwai, Ruth
# 16454                                      Zwizwai, Ruth
# 30885  Schilling, S.; Maltezou, H.C.; Fusco, F.M.; De...
# 16452  Schilling, S.; Maltezou, H.C.; Fusco, F.M.; De...
# 30416            de Leon, Samuel Ponce; Lazcano, Antonio
# 16473            de Leon, Samuel Ponce; Lazcano, Antonio
# 30156  Dandekar, Ajai A.; Anghelina, Daniela; Perlman...
# 42065  Dandekar, Ajai A.; Anghelina, Daniela; Perlman...
# 16467  Brouard, J.; Vabret, A.; Perrot, S.; Nimal, D....
# 30766  Brouard, J.; Vabret, A.; Perrot, S.; Nimal, D....
# 30994                Mahony, James B.; Richardson, Susan
# 42071                Mahony, James B.; Richardson, Susan
# 30159  Levy, Gary A.; Liu, Mingfeng; Ding, Jinwen; Yu...
# 42072  Levy, Gary A.; Liu, Mingfeng; Ding, Jinwen; Yu...
# 30920                               Bernard, Hans-Ulrich
# 15525                               Bernard, Hans-Ulrich
# 30590                                       Steinmann, J
# 16470                                       Steinmann, J
# 42067  Kuiken, Thijs; van den Hoogen, Bernadette G.; ...
# 30157  Kuiken, Thijs; van den Hoogen, Bernadette G.; ...
# 16472  Yip, CW; Hon, CC; Zeng, Fanya; Chow, Ken YC; L...
# 30417  Yip, CW; Hon, CC; Zeng, Fanya; Chow, Ken YC; L...
# 30155  Greenough, Thomas C.; Carville, Angela; Coderr...
# 42066  Greenough, Thomas C.; Carville, Angela; Coderr...
# 30146  Barreiro, Luis B.; Patin, Etienne; Neyrolles, ...
# 42052  Barreiro, Luis B.; Patin, Etienne; Neyrolles, ...
# 42070                                McKusick, Victor A.
# 30145                                McKusick, Victor A.
# 31020  Lopez, Maria-Cecilia; Ungaro, Ricardo F.; Bake...
# 6994   Lopez, Maria-Cecilia; Ungaro, Ricardo F.; Bake...
# ...                                                  ...
# 41846                                                NaN
# 42365  Daniell, Henry; Streatfield, Stephen J.; Wycof...
# 30917  Daniell, Henry; Streatfield, Stephen J; Wycoff...
# 30147                               Brownstein, David G.
# 42054                                    Brownstein, D G
# 17267  Sheahan, Timothy P.; Sims, Amy C.; Zhou, Shunt...
# 19619  Sheahan, Timothy P.; Sims, Amy C.; Zhou, Shunt...
# 30153                                      Brown, Corrie
# 42064                                      Brown, Corrie
# 28796                            Attenborough, Frederick
# 28806                            Attenborough, Frederick
# 28744                            Attenborough, Frederick
# 43261                                     DiRenna, James
# 45083                                     DiRenna, James
# 15968  Huh, Kyungmin; Shin, Hyoung-Shik; Peck, Kyong Ran
# 45076  Huh, Kyungmin; Shin, Hyoung Shik; Peck, Kyong Ran
# 16451                               Niesters, Hubert G.M
# 30919                               Niesters, Hubert G.M
# 42289  Mooney, Michael; McWeeney, Shannon; Canderan, ...
# 30781  Mooney, Michael; McWeeney, Shannon; Canderan, ...
# 42073  Garcia, Elizabeth P.; Dowding, Lori A.; Stanto...
# 30993  Garcia, Elizabeth P.; Dowding, Lori A.; Stanto...
# 30976                                      Zwizwai, Ruth
# 16453                                      Zwizwai, Ruth
# 30447              Butler, MerlinG.; Palmer, CatherineG.
# 42492            Butler, Merlin G.; Palmer, Catherine G.
# 15967                 Song, Young Goo; Shin, Hyoung-Shik
# 45082                 Song, Young Goo; Shin, Hyoung Shik
# 30154                     Kim, Taeg S.; Perlman, Stanley
# 43765                     Kim, Taeg S.; Perlman, Stanley
#
#                                       journal        mag_id who_covidence_id  \
# 30977          The Lancet Infectious Diseases           NaN              NaN
# 16454                       Lancet Infect Dis           NaN              NaN
# 30885     Clinical Microbiology and Infection           NaN              NaN
# 16452                   Clin Microbiol Infect           NaN              NaN
# 30416                              The Lancet           NaN              NaN
# 16473                                  Lancet           NaN              NaN
# 30156       The American Journal of Pathology           NaN              NaN
# 42065                                     NaN           NaN              NaN
# 16467                            Arch Pediatr           NaN              NaN
# 30766                   Archives de Pédiatrie           NaN              NaN
# 30994    The Journal of Molecular Diagnostics           NaN              NaN
# 42071                                     NaN           NaN              NaN
# 30159       The American Journal of Pathology           NaN              NaN
# 42072                                     NaN           NaN              NaN
# 30920            Journal of Clinical Virology           NaN              NaN
# 15525                            J Clin Virol           NaN              NaN
# 30590           Journal of Hospital Infection           NaN              NaN
# 16470                           J Hosp Infect           NaN              NaN
# 42067                                     NaN           NaN              NaN
# 30157       The American Journal of Pathology           NaN              NaN
# 16472                                  Lancet           NaN              NaN
# 30417                              The Lancet           NaN              NaN
# 30155       The American Journal of Pathology           NaN              NaN
# 42066                                     NaN           NaN              NaN
# 30146  The American Journal of Human Genetics           NaN              NaN
# 42052                                     NaN           NaN              NaN
# 42070                                     NaN           NaN              NaN
# 30145  The American Journal of Human Genetics           NaN              NaN
# 31020                           Harmful Algae           NaN              NaN
# 6994                            Harmful Algae           NaN              NaN
# ...                                       ...           ...              ...
# 41846                                  Nature  2.143542e+09            #2033
# 42365                                     NaN           NaN              NaN
# 30917                 Trends in Plant Science           NaN              NaN
# 30147  The American Journal of Human Genetics           NaN              NaN
# 42054                                     NaN           NaN              NaN
# 17267                          Sci Transl Med           NaN              NaN
# 19619                          Sci Transl Med           NaN              NaN
# 30153       The American Journal of Pathology           NaN              NaN
# 42064                                     NaN           NaN              NaN
# 28796                                     NaN           NaN              NaN
# 28806                                     NaN           NaN              NaN
# 28744                                     NaN           NaN              NaN
# 43261                                     NaN           NaN              NaN
# 45083                                  Mo Med           NaN            #7371
# 15968                        Infect Chemother           NaN              NaN
# 45076                        Infect Chemother           NaN            #2255
# 16451                            J Clin Virol           NaN              NaN
# 30919            Journal of Clinical Virology           NaN              NaN
# 42289                                     NaN           NaN              NaN
# 30781           Current Opinion in Immunology           NaN              NaN
# 42073                                     NaN           NaN              NaN
# 30993    The Journal of Molecular Diagnostics           NaN              NaN
# 30976          The Lancet Infectious Diseases           NaN              NaN
# 16453                       Lancet Infect Dis           NaN              NaN
# 30447                              The Lancet           NaN              NaN
# 42492                                     NaN           NaN              NaN
# 15967                        Infect Chemother           NaN              NaN
# 45082                        Infect Chemother           NaN            #6103
# 30154       The American Journal of Pathology           NaN              NaN
# 43765                                     NaN           NaN              NaN
#
#       arxiv_id                                     pdf_json_files  \
# 30977      NaN                                                NaN
# 16454      NaN                                                NaN
# 30885      NaN  document_parses/pdf_json/7e787fd2ae5b544add628...
# 16452      NaN  document_parses/pdf_json/7e787fd2ae5b544add628...
# 30416      NaN  document_parses/pdf_json/a25e212b03cc65c44dcc3...
# 16473      NaN                                                NaN
# 30156      NaN  document_parses/pdf_json/68249d769e1926678af8d...
# 42065      NaN                                                NaN
# 16467      NaN                                                NaN
# 30766      NaN  document_parses/pdf_json/6744bc52b1b29d2ab28cb...
# 30994      NaN  document_parses/pdf_json/4e8306655e7f3c6ae88db...
# 42071      NaN                                                NaN
# 30159      NaN  document_parses/pdf_json/5d2ed78357c0c88b4500d...
# 42072      NaN                                                NaN
# 30920      NaN  document_parses/pdf_json/bd3945ec343cc4535650c...
# 15525      NaN                                                NaN
# 30590      NaN  document_parses/pdf_json/e666b6507719561e391f4...
# 16470      NaN                                                NaN
# 42067      NaN                                                NaN
# 30157      NaN  document_parses/pdf_json/bad208dd9e4c71121ae41...
# 16472      NaN                                                NaN
# 30417      NaN                                                NaN
# 30155      NaN  document_parses/pdf_json/88a8c34283c82d0f85425...
# 42066      NaN                                                NaN
# 30146      NaN  document_parses/pdf_json/7fa6a89af06e588d737c8...
# 42052      NaN                                                NaN
# 42070      NaN                                                NaN
# 30145      NaN  document_parses/pdf_json/f3d760db99cfc4224b989...
# 31020      NaN  document_parses/pdf_json/58b578c2c6619df320c9a...
# 6994       NaN                                                NaN
# ...        ...                                                ...
# 41846      NaN                                                NaN
# 42365      NaN                                                NaN
# 30917      NaN  document_parses/pdf_json/a8dbc77e172c01c4f5c54...
# 30147      NaN  document_parses/pdf_json/4656f1c7a371893b0b6dc...
# 42054      NaN                                                NaN
# 17267      NaN  document_parses/pdf_json/c1402ba933f4a2a122d5e...
# 19619      NaN  document_parses/pdf_json/346855c8950ef288f1a27...
# 30153      NaN  document_parses/pdf_json/01213acdd86020357259f...
# 42064      NaN                                                NaN
# 28796      NaN                                                NaN
# 28806      NaN                                                NaN
# 28744      NaN  document_parses/pdf_json/24cc817d27e43b9e7bdc5...
# 43261      NaN                                                NaN
# 45083      NaN                                                NaN
# 15968      NaN  document_parses/pdf_json/ea2c56be23c5e3fb8261d...
# 45076      NaN                                                NaN
# 16451      NaN                                                NaN
# 30919      NaN  document_parses/pdf_json/151b80cfa218d8a252c17...
# 42289      NaN                                                NaN
# 30781      NaN  document_parses/pdf_json/9bc29db5852a315d57643...
# 42073      NaN                                                NaN
# 30993      NaN  document_parses/pdf_json/db732b73268d958bf73ae...
# 30976      NaN                                                NaN
# 16453      NaN                                                NaN
# 30447      NaN  document_parses/pdf_json/f3eefad19d628cbe1fc0d...
# 42492      NaN                                                NaN
# 15967      NaN  document_parses/pdf_json/2513ddf57215cb9297e05...
# 45082      NaN                                                NaN
# 30154      NaN  document_parses/pdf_json/c05522c7132d3162d433c...
# 43765      NaN                                                NaN
#
#                                      pmc_json_files  \
# 30977                                           NaN
# 16454                                           NaN
# 30885                                           NaN
# 16452  document_parses/pmc_json/PMC7128608.xml.json
# 30416                                           NaN
# 16473  document_parses/pmc_json/PMC7135165.xml.json
# 30156                                           NaN
# 42065                                           NaN
# 16467                                           NaN
# 30766                                           NaN
# 30994                                           NaN
# 42071                                           NaN
# 30159                                           NaN
# 42072                                           NaN
# 30920                                           NaN
# 15525  document_parses/pmc_json/PMC7108213.xml.json
# 30590                                           NaN
# 16470  document_parses/pmc_json/PMC7134461.xml.json
# 42067                                           NaN
# 30157                                           NaN
# 16472  document_parses/pmc_json/PMC7134863.xml.json
# 30417                                           NaN
# 30155                                           NaN
# 42066                                           NaN
# 30146                                           NaN
# 42052                                           NaN
# 42070                                           NaN
# 30145                                           NaN
# 31020                                           NaN
# 6994   document_parses/pmc_json/PMC5008692.xml.json
# ...                                             ...
# 41846                                           NaN
# 42365                                           NaN
# 30917                                           NaN
# 30147                                           NaN
# 42054                                           NaN
# 17267  document_parses/pmc_json/PMC7164393.xml.json
# 19619  document_parses/pmc_json/PMC7199910.xml.json
# 30153                                           NaN
# 42064                                           NaN
# 28796  document_parses/pmc_json/PMC7162272.xml.json
# 28806  document_parses/pmc_json/PMC7162427.xml.json
# 28744  document_parses/pmc_json/PMC7161675.xml.json
# 43261                                           NaN
# 45083                                           NaN
# 15968  document_parses/pmc_json/PMC7113450.xml.json
# 45076                                           NaN
# 16451  document_parses/pmc_json/PMC7128152.xml.json
# 30919                                           NaN
# 42289                                           NaN
# 30781                                           NaN
# 42073                                           NaN
# 30993                                           NaN
# 30976                                           NaN
# 16453                                           NaN
# 30447                                           NaN
# 42492                                           NaN
# 15967  document_parses/pmc_json/PMC7113449.xml.json
# 45082                                           NaN
# 30154                                           NaN
# 43765                                           NaN
#
#                                                      url
# 30977      https://doi.org/10.1016/s1473-3099(19)30075-1
# 16454  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 30885            https://doi.org/10.1111/1469-0691.12290
# 16452  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 30416      https://doi.org/10.1016/s0140-6736(03)14040-8
# 16473  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 30156      https://doi.org/10.1016/s0002-9440(10)63126-4
# 42065  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 16467  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 30766      https://doi.org/10.1016/s0929-693x(07)78706-7
# 30994      https://doi.org/10.1016/s1525-1578(10)60587-9
# 42071  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 30159      https://doi.org/10.1016/s0002-9440(10)64992-9
# 42072  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 30920          https://doi.org/10.1016/j.jcv.2004.10.021
# 15525  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 30590         https://doi.org/10.1016/j.jhin.2003.12.030
# 16470  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 42067  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 30157      https://doi.org/10.1016/s0002-9440(10)63750-9
# 16472  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 30417      https://doi.org/10.1016/s0140-6736(04)16311-3
# 30155      https://doi.org/10.1016/s0002-9440(10)62989-6
# 42066  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 30146                     https://doi.org/10.1086/497613
# 42052  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 42070  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 30145                     https://doi.org/10.1086/514346
# 31020          https://doi.org/10.1016/j.hal.2016.03.009
# 6994   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# ...                                                  ...
# 41846         https://doi.org/10.1038/d41586-020-00154-w
# 42365  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 30917      https://doi.org/10.1016/s1360-1385(01)01922-7
# 30147                     https://doi.org/10.1086/301735
# 42054  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 17267  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 19619  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 30153         https://doi.org/10.2353/ajpath.2006.050979
# 42064  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 28796  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 28806  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 28744  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 43261  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 45083      https://www.ncbi.nlm.nih.gov/pubmed/32158035/
# 15968  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 45076      https://www.ncbi.nlm.nih.gov/pubmed/32100487/
# 16451  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 30919      https://doi.org/10.1016/s1386-6532(02)00197-x
# 42289  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 30781          https://doi.org/10.1016/j.coi.2013.09.014
# 42073  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 30993      https://doi.org/10.1016/s1525-1578(10)60575-2
# 30976      https://doi.org/10.1016/s1473-3099(18)30088-4
# 16453  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 30447      https://doi.org/10.1016/s0140-6736(83)92745-9
# 42492  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 15967  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 45082      https://www.ncbi.nlm.nih.gov/pubmed/32153144/
# 30154      https://doi.org/10.1016/s0002-9440(10)62301-2
# 43765  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
#
# [81 rows x 18 columns]

# %% [markdown]
# For the number there are here, it is probably just easiest to merge manually.
#
# __Restart here, merge manually__

# %%
for Column in SingleValued_and_Unique:
    ValueCounts = metadataFrame[Column].value_counts()
    print(ValueCounts[ValueCounts>1])
    #print(Column, metadataFrame[Column].is_unique)
# Out:
# fzq71ghi    8
# jsk1oztb    3
# m6q8kbjg    2
# 5kzx5hgg    2
# 4hlvrfeh    2
# adygntbe    2
# c4u0gxp5    2
# 8fwa2c24    2
# e9pwguwm    2
# 4fbr8fx8    2
# xjpev4jw    2
# eich19nx    2
# 3ury4hnv    2
# 5ei7iwu0    2
# j7swau26    2
# hox2xwjg    2
# o4r34pff    2
# vqbreyna    2
# mmls866r    2
# huablvd1    2
# qhftb6d7    2
# j3b964oz    2
# 940au47y    2
# vp5358rr    2
# 21htepa1    2
# 30duqivi    2
# 6hdoap81    2
# 0klupmep    2
# sv9mdgek    2
# 6z5f2gz3    2
# 7y8fd521    2
# 2maferew    2
# brz1fn2h    2
# 21qu87oh    2
# laq5ze8o    2
# 0z5wacxs    2
# 79mzwv1c    2
# Name: cord_uid, dtype: int64
# Series([], Name: pmcid, dtype: int64)
# 32158035.0    2
# 32305024.0    2
# 31903811.0    2
# 14550714.0    2
# 16237214.0    2
# 32117569.0    2
# 14742242.0    2
# 26766408.0    2
# 16400004.0    2
# 32100487.0    2
# 11335175.0    2
# 12466134.0    2
# 27381971.0    2
# 15635312.0    2
# 15743792.0    2
# 10751347.0    2
# 12932399.0    2
# 6134086.0     2
# 25957460.0    2
# 16252244.0    2
# 15172785.0    2
# 17357067.0    2
# 32153144.0    2
# 16194517.0    2
# 16049331.0    2
# 12788592.0    2
# 16258152.0    2
# 15161626.0    2
# 32253226.0    2
# 9463342.0     2
# 24358511.0    2
# Name: pubmed_id, dtype: int64
# 3.006646e+09    14
# 3.004791e+09    11
# 3.006304e+09    10
# 3.005943e+09     9
# 3.006643e+09     8
# 2.604381e+09     8
# 3.005657e+09     7
# 3.001119e+09     7
# 3.004897e+09     6
# 3.006356e+09     6
# 3.005847e+09     6
# 3.006338e+09     6
# 3.005080e+09     6
# 3.005478e+09     5
# 3.005680e+09     5
# 3.004824e+09     5
# 3.005539e+09     5
# 3.004398e+09     4
# 3.005689e+09     4
# 3.004450e+09     4
# 3.002539e+09     4
# 3.006008e+09     4
# 3.003886e+09     4
# 2.002765e+09     3
# 3.006448e+09     3
# 3.005490e+09     3
# 3.004511e+09     3
# 3.004668e+09     3
# 3.006114e+09     3
# 3.005929e+09     3
#                 ..
# 3.006111e+09     2
# 3.006116e+09     2
# 3.006128e+09     2
# 3.005811e+09     2
# 3.006178e+09     2
# 3.005803e+09     2
# 3.006211e+09     2
# 3.005789e+09     2
# 3.006304e+09     2
# 3.006329e+09     2
# 3.006395e+09     2
# 3.004906e+09     2
# 3.006474e+09     2
# 3.006494e+09     2
# 3.005550e+09     2
# 3.006610e+09     2
# 3.006672e+09     2
# 2.116733e+09     2
# 3.005256e+09     2
# 3.005149e+09     2
# 3.006354e+09     2
# 3.005036e+09     2
# 3.006419e+09     2
# 2.055652e+09     2
# 2.999410e+09     2
# 3.005996e+09     2
# 2.166868e+09     2
# 3.004659e+09     2
# 3.004913e+09     2
# 3.004827e+09     2
# Name: mag_id, Length: 88, dtype: int64
# Series([], Name: who_covidence_id, dtype: int64)
# Series([], Name: arxiv_id, dtype: int64)
# https://doi.org/10.1038/d41586-020-00154-w                                         8
# http://digitalcommons.unl.edu/cgi/viewcontent.cgi?article=1074&context=veterans    2
# https://www.eurjbreasthealth.com/Content/files/Cover%20and%20front%20matter.pdf    2
# http://ajph.aphapublications.org/doi/pdf/10.2105/AJPH.2012.300761r                 2
# http://www.hcup-us.ahrq.gov/reports/statbriefs/sb162.pdf                           2
# http://europepmc.org/articles/pmc4143473?pdf=render                                2
# Name: url, dtype: int64

# %% [markdown]
# This is annoying to say the least. In any case, this is not all that informative as we cannot tell if the duplicates are the same across these different columns. Other than the mag_id this is very much possible and if it is the case, we will just sort out those duplicates and discard the mag_id.

# %%
metadataFrame['cord_uid'].is_unique
# Out:
# False
