# %% [markdown]
# In this notebook the structure of the CORD-19 metadata.csv file is explored to the end of arriving at an appropriate database structure.

# %% [markdown]
# # TOC
#
# 1. [Imports](#Imports)
# 1. [metadata.csv](#metadata_csv)
#     1. [Columns](#Columns)
#        1. [Single valued and unique](#Single_valued_and_unique)
#        1. [Single valued](#Single_valued)
# 1. [Setting up a schema](#Setting_up_a_schema)
#     1. [Main table](#Main_table)
#     1. [Multivalued field tables](#Multivalued_field_tables)
#        1. [pdf_json_files](#pdf_json_files)
#        1. [pmc_json_files](#pmc_json_files)
#        1. [sha](#sha)
#        1. [authors](#authors)
#     1. [Quick test](#Quick_test)

# %% [markdown]
# <a id='Imports'></a>
# # Imports

# %%
import csv
import pandas as pd
from pprint import pprint as pp

# %%
DataDirectory = './cord-19_2020-06-01/'

# %% [markdown]
# <a id='metadata_csv'></a>
# # metadata.csv

# %%
metadataFile = open(DataDirectory+'metadata.csv', 'r')
csvReader = csv.reader(metadataFile, delimiter=',', quotechar='"')

Header = next(csvReader)
pp(Header)
# Out:
# ['cord_uid',
#  'sha',
#  'source_x',
#  'title',
#  'doi',
#  'pmcid',
#  'pubmed_id',
#  'license',
#  'abstract',
#  'publish_time',
#  'authors',
#  'journal',
#  'mag_id',
#  'who_covidence_id',
#  'arxiv_id',
#  'pdf_json_files',
#  'pmc_json_files',
#  'url',
#  's2_id']

# %% [markdown]
# <a id='Columns'></a>
# ## Columns
#
# Starting from the readme provided with the data (metadata.readme) we can outline what each columns should cover and, importantly for databasing it, whether it is single value of potentially multi-valued.
#
# 'cord_uid' - This is a persistent identifier for the article within the CORD-19 ecosystem. __single valued__, __unique__.
#
# 'sha' - The hash of the article's PDF. There may be multiple PDFs associated to one article (supporting materials, ?preprints?). __multi-valued__.
#
# 'source_x' - The source of the article data. Sources covered include CZI (Chan-Zuckerberg Initiative), PMC (pubmed central), bioRxiv and medRxiv. Confirm sources from data. Should be __single valued__.
#
# 'title' - The article's title. __single valued__.
#
# 'doi' - The article's doi. __single valued__.
#
# 'pmcid' - The article's pubmed central id, if it has one. __single valued__, __unique__.
#
#
# 'pubmed_id' - The article's pubmed id. For distinction between this and the previous, see [here](https://publicaccess.nih.gov/include-pmcid-citations.htm#Difference). __single valued__, __unique__.
#
# 'license' - The license under which the data is being shared. Should be __single valued__.
#
# 'abstract' - The article's abstract. __single valued__.
#
# 'publish_time' - The date the article was published. __single valued__.
#
# 'authors' - The article's authors. Coverage questionable. __multi-valued__.
#
# 'journal' - The journal in which the article was published. If it was published in a journal. What happens with preprints? __single valued__.
#
# 'mag_id' - The article's microsoft academic graph id. __single valued__, __unique__.
#
# 'who_covidence_id' - The article's WHO #Covidence id. Should only be populated for CZI source articles. __single valued__, __unique__.
#
# 'arxiv_id' - The article's arXiv id. __single valued__, __unique__.
#
# 'pdf_json_files' - Relative path of the json(s) parsed from pdf file(s). __multi-valued__, __unique__.
#
# 'pmc_json_files' - Relative path of the json(s) parsed from pmc file(s). __multi-valued__, __unique__.
#
# 'url' - The article's URL. Should be __single valued__, __unique__.
#
# 's2_id' - The article's Semantic Scholar id. Can be resolved at https://api.semanticscholar.org/. Should be __single valued__, __unique__.

# %% [markdown]
# To explore the columns, it is probably easier to work with the csv via pandas.

# %%
metadataFrame = pd.read_csv(DataDirectory+'metadata.csv', low_memory=False)
metadataFrame
# Out:
#         cord_uid                                                sha  \
# 0       ug7v899j           d1aafb70c066a2068b02786f8929fd9c900897fb
# 1       02tnwd4m           6b0567729c2143a66d737eb0a2f63f2dce2e5a7d
# 2       ejv2xln0           06ced00a5fc04215949aa72528f2eeaae1d58927
# 3       2b73a28n           348055649b6b8cf2b9a376498df9bf41f7123605
# 4       9785vg6d           5f48792a5fa08bed9f56016f4981ae2ca6031b32
# 5       zjufx4fo           b2897e1277f56641193a6db73825f707eed3e4c9
# 6       ymceytj3           e3d0d482ebd9a8ba81c254cc433f314142e72174
# 7       wzj2glte           00b1d99e70f779eb4ede50059db469c65e8c1469
# 8       2sfqsfm1           cf584e00f637cbd8f1bb35f3f09f5ed07b71aeb0
# 9       i0zym7iq           dde02f11923815e6a16a31dd6298c46b109c5dfa
# 10      5yhe786e           3bb07ea10432f7738413dff9816809cc90f03f99
# 11      8zchiykl           5806726a24dc91de3954001effbdffd7a82d54e2
# 12      xqhn0vbp           1e1286db212100993d03cc22374b624f7caee956
# 13      gi6uaa83           8ae137c8da1607b3a8e4c946c07ca8bda67f88ac
# 14      0m32ecnu           23bc55d6f63fab18b02004483888db2b6a0bfa48
# 15      le0ogx1s                                                NaN
# 16      8qnrcgnk           faaf1022ccfe93b032c5608097a53543ba24aedb
# 17      3oxzzxnd           7ff45096210eeb392d51f646f5c7fe011079aaf3
# 18      fy4w7xz8           0104f6ceccf92ae8567a0102f89cbb976969a774
# 19      jg13scgo           5b44feca5d6ffaaeb66501fa84cc6dd44d06660a
# 20      0qaoam29           5b68a553a7cbbea13472721cd1ad617d42b40c26
# 21      qj4dh6rg           3ed670f60a7be2e3e2a991ea8af1fdd5fa5e2b2c
# 22      1wswi7us           59ffca26c9d1f881e4e37e7c5af626d72d858dc4
# 23      yy96yeu9           c63c4d58d170136b8d3b5a66424b5ac3f73a92d9
# 24      5o38ihe0           dab2d95da5307c840eb4a1e00f0186022541d63d
# 25      1ul8owic           75ebad1e8641e5fe2a51214f4d97742ab59a8dae
# 26      5s6acr7m           6c0dee643345c93436cfa8d58270aa887ad92e3d
# 27      5tkvsudh           9d4e3e8eb092d5ed282d0aa4aadcaa8b7165b5e9
# 28      6lvn10f4           14e0cac6e86d62859e6c9f1351ab67466d89e5b3
# 29      tvxpckxo           d09b79026117ec9faebba46a8d13aa9b23ec751e
# ...          ...                                                ...
# 140502  22s9umrj           cdbdc0b6176729a11ba5e08c708408592d189657
# 140503  icowa7wn           d27842f2883b8884d975fe744e1157bb727d6f9b
# 140504  kon3ooo3           fb0bce3654938b8c93e5b324d2a23e90f95bb15b
# 140505  ccdj7137           8d1498b4b95b0bf8f6d9577764fffcecd1bae360
# 140506  zl91u567           738d255294896f43d6ac7546a891900714ef1d51
# 140507  47okncdw           2918a43791587306be37d4e23f804c1efdbdd8fa
# 140508  4bheqtk5           21974784c3eb198439eabbd88509396d8ad2c156
# 140509  bary8svr           1b759c9a06fa77009c2271b444b2236874e99cbc
# 140510  oo5x3rrz           f7c6f6eda0e0bfa77134c4fdbd34ce45a9e9c054
# 140511  jhiap68j           621832d547930a8c23859fa443c2c9c38ff07e42
# 140512  7kiahjyy           b466c5c6dc539542eba79097001d04e2b3fca72e
# 140513  uau5ygys           ff8610a4d772b4ec5497589889f8c8bf8179dd7b
# 140514  r41ilao6           6bde3798df501fc40dd89e2cff0a1a8fd2b9dd47
# 140515  ke5hxd8o                                                NaN
# 140516  9aacmywu                                                NaN
# 140517  gubekyum           704fd6c6608f5b400f005042357180f8a4fd029d
# 140518  h9m4iexp           556e48d9685a2e212757cc015b35c203ecf31487
# 140519  p83we2ye           ff09007b2973bf3dc9a0435228a1b220587763da
# 140520  cekegxop           3711609ee9f51aed04b50dc095784795c7e0202d
# 140521  hp11at50                                                NaN
# 140522  j9nllb4f           ab98d1b125aa0704e63adef426b27abd32e935f0
# 140523  qgy3xk73           633e89365f800d4e5c888ad2e2d8e580a7843065
# 140524  zawfotcx           0a67144ee20745181efe19f9e3b9ac0929b578d4
# 140525  x51jorbm           047ca5a826da314da2421d2101ae6cef6ec6644d
# 140526  1f96hzfz           9057e2fc54df6336793afb230942867598ee7da4
# 140527  ls17j4v4           0bfafe584842551754428e1473a565d03fa7e9ac
# 140528  haddndoi                                                NaN
# 140529  i3dcqjzq  35908ee476f9b20d8e21458f4882c9fa448ea6fd; f1e1...
# 140530  lsll6pft           c48c0b02b9160433003864b6023a488b6c690b01
# 140531  6vy19as4           a87e85c0e1a7473370e861cffdb14a3a73062eb8
#
#                            source_x  \
# 0                               PMC
# 1                               PMC
# 2                               PMC
# 3                               PMC
# 4                               PMC
# 5                               PMC
# 6                               PMC
# 7                               PMC
# 8                               PMC
# 9                               PMC
# 10                              PMC
# 11                              PMC
# 12                              PMC
# 13                              PMC
# 14                              PMC
# 15                              PMC
# 16                              PMC
# 17                              PMC
# 18                              PMC
# 19                              PMC
# 20                              PMC
# 21                              PMC
# 22                              PMC
# 23                              PMC
# 24                              PMC
# 25                              PMC
# 26                              PMC
# 27                              PMC
# 28                              PMC
# 29                              PMC
# ...                             ...
# 140502                 Medline; PMC
# 140503                Elsevier; PMC
# 140504                 Medline; PMC
# 140505                Elsevier; PMC
# 140506                 Medline; PMC
# 140507                Elsevier; PMC
# 140508       Elsevier; Medline; PMC
# 140509                 Medline; PMC
# 140510  Elsevier; Medline; PMC; WHO
# 140511                 Medline; PMC
# 140512                Elsevier; PMC
# 140513       Elsevier; Medline; PMC
# 140514                Elsevier; PMC
# 140515                 Medline; WHO
# 140516                 Medline; WHO
# 140517                 Medline; PMC
# 140518                Elsevier; PMC
# 140519                 Medline; PMC
# 140520       Elsevier; Medline; PMC
# 140521                 Medline; WHO
# 140522                 Medline; PMC
# 140523                 Medline; PMC
# 140524  Elsevier; Medline; PMC; WHO
# 140525                 Medline; PMC
# 140526                 Medline; PMC
# 140527                 Medline; PMC
# 140528                Elsevier; PMC
# 140529    ArXiv; Elsevier; PMC; WHO
# 140530                 Medline; PMC
# 140531                 Medline; PMC
#
#                                                     title  \
# 0       Clinical features of culture-proven Mycoplasma...
# 1       Nitric oxide: a pro-inflammatory mediator in l...
# 2         Surfactant protein-D and pulmonary host defense
# 3                    Role of endothelin-1 in lung disease
# 4       Gene expression in epithelial cells in respons...
# 5       Sequence requirements for RNA strand transfer ...
# 6       Crystal structure of murine sCEACAM1a[1,4]: a ...
# 7       Synthesis of a novel hepatitis C virus protein...
# 8       Structure of coronavirus main proteinase revea...
# 9       Discontinuous and non-discontinuous subgenomic...
# 10      Debate: Transfusing to normal haemoglobin leve...
# 11      The 21st International Symposium on Intensive ...
# 12      Airborne rhinovirus detection and effect of ul...
# 13        Discovering human history from stomach bacteria
# 14      Prokaryotic-style frameshifting in a plant tra...
# 15         A new recruit for the army of the men of death
# 16      Heme oxygenase-1 and carbon monoxide in pulmon...
# 17      SseG, a virulence protein that targets Salmone...
# 18      Association of HLA class I with severe acute r...
# 19      Technical Description of RODS: A Real-time Pub...
# 20       A double epidemic model for the SARS propagation
# 21      Cloaked similarity between HIV-1 and SARS-CoV ...
# 22      Relationship of SARS-CoV to other pathogenic R...
# 23      Viral Discovery and Sequence Recovery Using DN...
# 24      A model of tripeptidyl-peptidase I (CLN2), a u...
# 25      Air pollution and case fatality of SARS in the...
# 26                        The Virus That Changed My World
# 27      Conservation of polyamine regulation by transl...
# 28      Heterogeneous nuclear ribonucleoprotein A1 reg...
# 29      A Method to Identify p62's UBA Domain Interact...
# ...                                                   ...
# 140502  Spatial analysis of falls in an urban communit...
# 140503  Prise en charge des exacerbations : de la vill...
# 140504  Selective evolution of Toll-like receptors 3, ...
# 140505  Direct diagnosis of human respiratory coronavi...
# 140506       PEGylated Adenoviruses: From Mice to Monkeys
# 140507  Mismatch Extension During Strong Stop Strand T...
# 140508  Influenza B virus infections in Western Saxony...
# 140509  Polymorphism of 2′-5′-oligoadenylate synthetas...
# 140510                     COVID-19: The road to recovery
# 140511  Expression Profiles of mRNA and lncRNA in HCT-...
# 140512  Chapter 5 The GRANCH Techniques for Analysis o...
# 140513  Channel catfish, Ictalurus punctatus, cysteine...
# 140514  Molecular analyses of disease pathogenesis: Ap...
# 140515  Synergistic effect of Vitamin D and Remdesivir...
# 140516  Psychological distress in serious mental illne...
# 140517  Applications of Protein Biochips in Biomedical...
# 140518  At the epicenter of severe acute respiratory s...
# 140519  Emerging Trends in Clinical Tropical Medicine ...
# 140520  Novel platinum(II) and palladium(II) complexes...
# 140521  Mental Health Problems during the COVID-19 Pan...
# 140522  Full Genome Virus Detection in Fecal Samples U...
# 140523  Detection and characterization of three zoonot...
# 140524  Creating a Palliative Care Inpatient Response ...
# 140525  Contamination by respiratory viruses on outer ...
# 140526  Reconstruction of the most recent common ances...
# 140527  Nonessential Research in the New Normal: The I...
# 140528                     Author index and Subject index
# 140529  A multi-group SEIRA model for the spread of CO...
# 140530  Acquisition of multidrug-resistant Enterobacte...
# 140531  The role of additive manufacturing and antimic...
#
#                                        doi       pmcid   pubmed_id    license  \
# 0                    10.1186/1471-2334-1-6    PMC35282  11472636.0      no-cc
# 1                             10.1186/rr14    PMC59543  11667967.0      no-cc
# 2                             10.1186/rr19    PMC59549  11667972.0      no-cc
# 3                             10.1186/rr44    PMC59574  11686871.0      no-cc
# 4                             10.1186/rr61    PMC59580  11686888.0      no-cc
# 5                 10.1093/emboj/20.24.7220   PMC125340  11742998.0   green-oa
# 6                  10.1093/emboj/21.9.2076   PMC125375  11980704.0   green-oa
# 7                 10.1093/emboj/20.14.3840   PMC125543  11447125.0      no-cc
# 8                     10.1093/emboj/cdf327   PMC126080  12093723.0   green-oa
# 9                     10.1093/emboj/cdf635   PMC136939  12456663.0   green-oa
# 10                           10.1186/cc987   PMC137267  11299062.0      no-cc
# 11                          10.1186/cc1013   PMC137274  11353930.0      no-cc
# 12                   10.1186/1471-2458-3-5   PMC140314  12525263.0      no-cc
# 13                 10.1186/gb-2003-4-5-213   PMC156578  12734001.0      no-cc
# 14                    10.1093/emboj/cdg365   PMC169038  12881428.0   green-oa
# 15                 10.1186/gb-2003-4-7-113   PMC193621  12844350.0      no-cc
# 16                   10.1186/1465-9921-4-7   PMC193681  12964953.0      no-cc
# 17                    10.1093/emboj/cdg517   PMC204495  14517239.0   green-oa
# 18                   10.1186/1471-2350-4-9   PMC212558  12969506.0      no-cc
# 19                     10.1197/jamia.m1345   PMC212776  12807803.0  bronze-oa
# 20                  10.1186/1471-2334-3-19   PMC222908  12964944.0      no-cc
# 21                  10.1186/1471-2180-3-20   PMC222911  14499001.0      no-cc
# 22                  10.1186/1471-2105-4-43   PMC222961  14499005.0      no-cc
# 23            10.1371/journal.pbio.0000002   PMC261870  14624234.0      cc-by
# 24                   10.1186/1472-6807-3-8   PMC280685  14609438.0      no-cc
# 25                  10.1186/1476-069x-2-15   PMC293432  14629774.0      no-cc
# 26            10.1371/journal.pbio.0000066   PMC300679  14691538.0      no-cc
# 27                 10.1093/emboj/19.8.1907   PMC302018  10775274.0      no-cc
# 28                10.1093/emboj/19.17.4701   PMC302072  10970862.0   green-oa
# 29                           10.1251/bpo66   PMC302190  14702098.0      no-cc
# ...                                    ...         ...         ...        ...
# 140502              10.1186/1476-072x-8-14  PMC2666650  19291326.0      cc-by
# 140503        10.1016/j.jeurea.2015.02.002  PMC7148602         NaN  els-covid
# 140504           10.1007/s00251-016-0966-2  PMC7079974  28013457.0      no-cc
# 140505       10.1016/s0166-0934(01)00343-3  PMC7119936  11483217.0      no-cc
# 140506                    10.3390/v2020468  PMC3185605  21994645.0      cc-by
# 140507       10.1016/s0022-2836(03)00597-7  PMC7173232  12850138.0  els-covid
# 140508       10.1016/j.vaccine.2019.08.027  PMC7115636  31521415.0  els-covid
# 140509           10.1134/s002689331006004x  PMC7088653  32214471.0      no-cc
# 140510       10.1016/j.amjsurg.2020.05.024  PMC7236708  32446466.0      no-cc
# 140511            10.3389/fmicb.2018.01409  PMC6036261  30013528.0      cc-by
# 140512  10.1016/b978-1-68108-053-6.50005-3  PMC7151884         NaN  els-covid
# 140513           10.1016/j.fsi.2008.11.010  PMC7111680  19084602.0      no-cc
# 140514        10.1016/j.vetimm.2005.02.015  PMC7112672  15808306.0      no-cc
# 140515       10.1080/07391102.2020.1773929         NaN  32456606.0        unk
# 140516           10.1017/s0033291720001841         NaN  32423496.0        unk
# 140517              10.1002/anie.200901480  PMC7159567  19757463.0      no-cc
# 140518         10.1016/j.jtcvs.2004.03.002  PMC7127222  15173706.0      no-cc
# 140519               10.4269/ajtmh.19-0043  PMC6609189  31094312.0      cc-by
# 140520        10.1016/j.ejmech.2011.09.031  PMC7126824  21993152.0  els-covid
# 140521              10.3390/ijerph17103722         NaN  32466163.0        unk
# 140522        10.1371/journal.pone.0093269  PMC3973683  24695106.0      cc-by
# 140523           10.1007/s12250-017-3973-z  PMC6598888  28721632.0  bronze-oa
# 140524   10.1016/j.jpainsymman.2020.03.025  PMC7171263  32240754.0  els-covid
# 140525           10.1186/s12879-019-4109-x  PMC6547584  31159777.0      cc-by
# 140526                    10.1360/04wc0153  PMC7089140  32214711.0      no-cc
# 140527               10.4269/ajtmh.20-0325  PMC7253117  32333545.0      cc-by
# 140528       10.1016/s1055-937x(00)80034-1  PMC7147218         NaN  els-covid
# 140529         10.1016/j.chaos.2020.109925  PMC7247502         NaN      no-cc
# 140530          10.1186/s13756-020-00733-6  PMC7237615  32434591.0      cc-by
# 140531       10.1080/17434440.2020.1756771  PMC7196922  32312129.0      no-cc
#
#                                                  abstract publish_time  \
# 0       OBJECTIVE: This retrospective chart review des...   2001-07-04
# 1       Inflammatory diseases of the respiratory tract...   2000-08-15
# 2       Surfactant protein-D (SP-D) participates in th...   2000-08-25
# 3       Endothelin-1 (ET-1) is a 21 amino acid peptide...   2001-02-22
# 4       Respiratory syncytial virus (RSV) and pneumoni...   2001-05-11
# 5       Nidovirus subgenomic mRNAs contain a leader se...   2001-12-17
# 6       CEACAM1 is a member of the carcinoembryonic an...   2002-05-01
# 7       Hepatitis C virus (HCV) is an important human ...   2001-07-16
# 8       The key enzyme in coronavirus polyprotein proc...   2002-07-01
# 9       Arteri-, corona-, toro- and roniviruses are ev...   2002-12-01
# 10      Recent evidence suggests that critically ill p...   2001-03-08
# 11      The 21st International Symposium on Intensive ...   2001-05-02
# 12      BACKGROUND: Rhinovirus, the most common cause ...   2003-01-13
# 13      Recent analyses of human pathogens have reveal...   2003-04-28
# 14      Ribosomal frameshifting signals are found in m...   2003-08-01
# 15      The army of the men of death, in John Bunyan's...   2003-06-27
# 16      Heme oxygenase-1 (HO-1), an inducible stress p...   2003-08-07
# 17      Intracellular replication of the bacterial pat...   2003-10-01
# 18      BACKGROUND: The human leukocyte antigen (HLA) ...   2003-09-12
# 19      This report describes the design and implement...   2003-09-01
# 20      BACKGROUND: An epidemic of a Severe Acute Resp...   2003-09-10
# 21      BACKGROUND: Severe acute respiratory syndrome ...   2003-09-21
# 22      BACKGROUND: The exact origin of the cause of t...   2003-09-20
# 23      Because of the constant threat posed by emergi...   2003-11-17
# 24      BACKGROUND: Tripeptidyl-peptidase I, also know...   2003-11-11
# 25      BACKGROUND: Severe acute respiratory syndrome ...   2003-11-20
# 26      Personal account of a young virologist working...   2003-12-22
# 27      Regulation of ornithine decarboxylase in verte...   2000-04-17
# 28      Heterogeneous nuclear ribonucleoprotein (hnRNP...   2000-09-01
# 29      The UBA domain is a conserved sequence motif a...   2003-12-12
# ...                                                   ...          ...
# 140502  BACKGROUND: Falls are an issue of great public...   2009-03-17
# 140503  Points essentiels La Société de pneumologie de...   2015-04-30
# 140504  Previous studies have shown that bats are rese...   2016-12-24
# 140505  An RT-PCR-hybridization was developed that amp...   2001-07-30
# 140506  Covalent modification with polyethylene glycol...   2010-02-01
# 140507  Abstract Reverse transcription requires two re...   2003-07-18
# 140508  Abstract Background The impact of annual influ...   2019-10-08
# 140509  2′-5′-oligoadenylate synthetases are a family ...   2010-12-04
# 140510                                                NaN   2020-05-19
# 140511  Cryptosporidium parvum is one of the most impo...   2018-06-27
# 140512  Abstract: The very rapid growth in molecular s...   2015-12-31
# 140513  The antigen recognition by the host immune sys...   2008-11-28
# 140514  The molecular analysis of disease pathogenesis...   2005-05-15
# 140515                                                NaN         2020
# 140516                                                NaN   2020-05-19
# 140517  Progress in the development of protein‐immobil...   2009-09-15
# 140518                                                NaN   2004-05-25
# 140519  The American Society for Tropical Medicine and...   2019-05-13
# 140520  Abstract A series of thiosemicarbazones and th...   2011-11-30
# 140521  (1) Background: The novel coronavirus disease ...   2020-05-25
# 140522  We have developed a full genome virus detectio...   2014-04-02
# 140523  Diverse species of rodents and shrews, which a...   2017-07-17
# 140524  Abstract Context The coronavirus disease 2019 ...   2020-03-31
# 140525  BACKGROUND: Medical masks are commonly used in...   2019-06-03
# 140526                                                NaN   2013-08-30
# 140527  Nonessential Research in the New Normal: The I...   2020-04-24
# 140528                                                NaN   2000-10-31
# 140529  The outbreak and propagation of COVID-19 have ...   2020-05-25
# 140530  BACKGROUND: International tourism increased fr...   2020-05-20
# 140531                                                NaN   2020-04-30
#
#                                                   authors  \
# 0                     Madani, Tariq A; Al-Ghamdi, Aisha A
# 1       Vliet, Albert van der; Eiserich, Jason P; Cros...
# 2                                         Crouch, Erika C
# 3       Fagan, Karen A; McMurtry, Ivan F; Rodman, David M
# 4       Domachowske, Joseph B; Bonville, Cynthia A; Ro...
# 5       Pasternak, Alexander O.; van den Born, Erwin; ...
# 6       Tan, Kemin; Zelus, Bruce D.; Meijers, Rob; Liu...
# 7       Xu, Zhenming; Choi, Jinah; Yen, T.S.Benedict; ...
# 8       Anand, Kanchan; Palm, Gottfried J.; Mesters, J...
# 9       van Vliet, A.L.W.; Smits, S.L.; Rottier, P.J.M...
# 10        Alvarez, Gonzalo; Hébert, Paul C; Szick, Sharyn
# 11                          Ball, Jonathan; Venn, Richard
# 12      Myatt, Theodore A; Johnston, Sebastian L; Rudn...
# 13                                       Disotell, Todd R
# 14      Napthine, Sawsan; Vidakovic, Marijana; Girnary...
# 15                                      Petsko, Gregory A
# 16      Slebos, Dirk-Jan; Ryter, Stefan W; Choi, Augus...
# 17                   Salcedo, Suzana P.; Holden, David W.
# 18      Lin, Marie; Tseng, Hsiang-Kuang; Trejaut, Jean...
# 19      Tsui, Fu-Chiang; Espino, Jeremy U.; Dato, Virg...
# 20      Ng, Tuen Wai; Turinici, Gabriel; Danchin, Antoine
# 21                        Kliger, Yossef; Levanon, Erez Y
# 22         Yap, Yee Leng; Zhang, Xue Wu; Danchin, Antoine
# 23      Wang, David; Urisman, Anatoly; Liu, Yu-Tsueng;...
# 24      Wlodawer, Alexander; Durell, Stewart R; Li, Mi...
# 25      Cui, Yan; Zhang, Zuo-Feng; Froines, John; Zhao...
# 26                                      Poh Ng, Lisa Fong
# 27      Ivanov, Ivaylo P.; Matsufuji, Senya; Murakami,...
# 28      Shi, Stephanie T.; Huang, Peiyong; Li, Hsin-Pa...
# 29      Pridgeon, Julia W.; Geetha, Thangiah; Wooten, ...
# ...                                                   ...
# 140502  Lai, Poh C; Low, Chien T; Wong, Martin; Wong, ...
# 140503  Jouneau, Stéphane; Brinchault, Graziella; Desr...
# 140504  Jiang, Haiying; Li, Juan; Li, Linmiao; Zhang, ...
# 140505  Vabret, Astrid; Mouthon, Franck; Mourez, Thoma...
# 140506               Wonganan, Piyanuch; Croyle, Maria A.
# 140507             Marr, Sharon Fodor; Telesnitsky, Alice
# 140508  Hönemann, M.; Martin, D.; Pietsch, C.; Maier, ...
# 140509  Barkhash, A. V.; Babenko, V. N.; Kobzev, V. F....
# 140510  Diaz, Adrian; Rahmanian, Armin; Pawlik, Timoth...
# 140511  Liu, Ting-Li; Fan, Xian-Chen; Li, Yun-Hui; Yua...
# 140512                                      Nandy, Ashesh
# 140513                Yeh, Hung-Yueh; Klesius, Phillip H.
# 140514  Wilson, Heather L.; Aich, Palok; Roche, Fiona ...
# 140515                  Arya, Aditya; Dwivedi, Vivek Dhar
# 140516  Iasevoli, Felice; Fornaro, Michele; D'Urso, Gi...
# 140517  Weinrich, Dirk; Jonkheijm, Pascal; Niemeyer, C...
# 140518                        Wan, Song; Yim, Anthony P.C
# 140519  Huntington, Mark K.; Bryan, Joe P.; Moon, Troy...
# 140520  Karaküçük-İyidoğan, Ayşegül; Taşdemir, Demet; ...
# 140521    Zhang, Yao; Zhang, Haoyu; Ma, Xindong; Di, Qian
# 140522  Cotten, Matthew; Oude Munnink, Bas; Canuti, Ma...
# 140523  Wang, Bo; Cai, Chun-Lin; Li, Bei; Zhang, Wei; ...
# 140524  Fausto, James; Hirano, Lianne; Lam, Daniel; Me...
# 140525  Chughtai, Abrar Ahmad; Stelzer-Braid, Sacha; R...
# 140526     Yuan, Zhang; Nan, Zheng; Pei, Hao; Yang, Zhong
# 140527              Yanow, Stephanie K.; Good, Michael F.
# 140528                                                NaN
# 140529  Contreras, Sebastián; Villavicencio, H. Andrés...
# 140530  Voor in ‘t holt, Anne F.; Mourik, Kees; Beishu...
# 140531                    Zuniga, Jorge M.; Cortes, Aaron
#
#                                                   journal  mag_id  \
# 0                                          BMC Infect Dis     NaN
# 1                                              Respir Res     NaN
# 2                                              Respir Res     NaN
# 3                                              Respir Res     NaN
# 4                                              Respir Res     NaN
# 5                                        The EMBO Journal     NaN
# 6                                        The EMBO Journal     NaN
# 7                                                  EMBO J     NaN
# 8                                        The EMBO Journal     NaN
# 9                                        The EMBO Journal     NaN
# 10                                              Crit Care     NaN
# 11                                              Crit Care     NaN
# 12                                      BMC Public Health     NaN
# 13                                            Genome Biol     NaN
# 14                                       The EMBO Journal     NaN
# 15                                            Genome Biol     NaN
# 16                                             Respir Res     NaN
# 17                                       The EMBO Journal     NaN
# 18                                          BMC Med Genet     NaN
# 19      Journal of the American Medical Informatics As...     NaN
# 20                                         BMC Infect Dis     NaN
# 21                                          BMC Microbiol     NaN
# 22                                     BMC Bioinformatics     NaN
# 23                                              PLoS Biol     NaN
# 24                                        BMC Struct Biol     NaN
# 25                                         Environ Health     NaN
# 26                                              PLoS Biol     NaN
# 27                                                 EMBO J     NaN
# 28                                       The EMBO Journal     NaN
# 29                                     Biol Proced Online     NaN
# ...                                                   ...     ...
# 140502                                 Int J Health Geogr     NaN
# 140503    Journal Européen des Urgences et de Réanimation     NaN
# 140504                                     Immunogenetics     NaN
# 140505                                    J Virol Methods     NaN
# 140506                                            Viruses     NaN
# 140507                       Journal of Molecular Biology     NaN
# 140508                                            Vaccine     NaN
# 140509                                           Mol Biol     NaN
# 140510                                          Am J Surg     NaN
# 140511                                    Front Microbiol     NaN
# 140512  Advances in Mathematical Chemistry and Applica...     NaN
# 140513                             Fish Shellfish Immunol     NaN
# 140514                           Vet Immunol Immunopathol     NaN
# 140515                                J Biomol Struct Dyn     NaN
# 140516                             Psychological medicine     NaN
# 140517                             Angew Chem Int Ed Engl     NaN
# 140518                           J Thorac Cardiovasc Surg     NaN
# 140519                                  Am J Trop Med Hyg     NaN
# 140520            European Journal of Medicinal Chemistry     NaN
# 140521  International journal of environmental researc...     NaN
# 140522                                           PLoS One     NaN
# 140523                                  Virologica Sinica     NaN
# 140524                              J Pain Symptom Manage     NaN
# 140525                                     BMC Infect Dis     NaN
# 140526                                      Chin Sci Bull     NaN
# 140527                                  Am J Trop Med Hyg     NaN
# 140528          Seminars in Avian and Exotic Pet Medicine     NaN
# 140529                            Chaos Solitons Fractals     NaN
# 140530                   Antimicrob Resist Infect Control     NaN
# 140531                             Expert Rev Med Devices     NaN
#
#        who_covidence_id    arxiv_id  \
# 0                   NaN         NaN
# 1                   NaN         NaN
# 2                   NaN         NaN
# 3                   NaN         NaN
# 4                   NaN         NaN
# 5                   NaN         NaN
# 6                   NaN         NaN
# 7                   NaN         NaN
# 8                   NaN         NaN
# 9                   NaN         NaN
# 10                  NaN         NaN
# 11                  NaN         NaN
# 12                  NaN         NaN
# 13                  NaN         NaN
# 14                  NaN         NaN
# 15                  NaN         NaN
# 16                  NaN         NaN
# 17                  NaN         NaN
# 18                  NaN         NaN
# 19                  NaN         NaN
# 20                  NaN         NaN
# 21                  NaN         NaN
# 22                  NaN         NaN
# 23                  NaN         NaN
# 24                  NaN         NaN
# 25                  NaN         NaN
# 26                  NaN         NaN
# 27                  NaN         NaN
# 28                  NaN         NaN
# 29                  NaN         NaN
# ...                 ...         ...
# 140502              NaN         NaN
# 140503              NaN         NaN
# 140504              NaN         NaN
# 140505              NaN         NaN
# 140506              NaN         NaN
# 140507              NaN         NaN
# 140508              NaN         NaN
# 140509              NaN         NaN
# 140510          #306217         NaN
# 140511              NaN         NaN
# 140512              NaN         NaN
# 140513              NaN         NaN
# 140514              NaN         NaN
# 140515          #381967         NaN
# 140516          #306124         NaN
# 140517              NaN         NaN
# 140518              NaN         NaN
# 140519              NaN         NaN
# 140520              NaN         NaN
# 140521          #361457         NaN
# 140522              NaN         NaN
# 140523              NaN         NaN
# 140524           #19674         NaN
# 140525              NaN         NaN
# 140526              NaN         NaN
# 140527              NaN         NaN
# 140528              NaN         NaN
# 140529          #361398  2004.13452
# 140530              NaN         NaN
# 140531              NaN         NaN
#
#                                            pdf_json_files  \
# 0       document_parses/pdf_json/d1aafb70c066a2068b027...
# 1       document_parses/pdf_json/6b0567729c2143a66d737...
# 2       document_parses/pdf_json/06ced00a5fc04215949aa...
# 3       document_parses/pdf_json/348055649b6b8cf2b9a37...
# 4       document_parses/pdf_json/5f48792a5fa08bed9f560...
# 5       document_parses/pdf_json/b2897e1277f56641193a6...
# 6       document_parses/pdf_json/e3d0d482ebd9a8ba81c25...
# 7       document_parses/pdf_json/00b1d99e70f779eb4ede5...
# 8       document_parses/pdf_json/cf584e00f637cbd8f1bb3...
# 9       document_parses/pdf_json/dde02f11923815e6a16a3...
# 10      document_parses/pdf_json/3bb07ea10432f7738413d...
# 11      document_parses/pdf_json/5806726a24dc91de39540...
# 12      document_parses/pdf_json/1e1286db212100993d03c...
# 13      document_parses/pdf_json/8ae137c8da1607b3a8e4c...
# 14      document_parses/pdf_json/23bc55d6f63fab18b0200...
# 15                                                    NaN
# 16      document_parses/pdf_json/faaf1022ccfe93b032c56...
# 17      document_parses/pdf_json/7ff45096210eeb392d51f...
# 18      document_parses/pdf_json/0104f6ceccf92ae8567a0...
# 19      document_parses/pdf_json/5b44feca5d6ffaaeb6650...
# 20      document_parses/pdf_json/5b68a553a7cbbea134727...
# 21      document_parses/pdf_json/3ed670f60a7be2e3e2a99...
# 22      document_parses/pdf_json/59ffca26c9d1f881e4e37...
# 23      document_parses/pdf_json/c63c4d58d170136b8d3b5...
# 24      document_parses/pdf_json/dab2d95da5307c840eb4a...
# 25      document_parses/pdf_json/75ebad1e8641e5fe2a512...
# 26      document_parses/pdf_json/6c0dee643345c93436cfa...
# 27      document_parses/pdf_json/9d4e3e8eb092d5ed282d0...
# 28      document_parses/pdf_json/14e0cac6e86d62859e6c9...
# 29      document_parses/pdf_json/d09b79026117ec9faebba...
# ...                                                   ...
# 140502  document_parses/pdf_json/cdbdc0b6176729a11ba5e...
# 140503  document_parses/pdf_json/d27842f2883b8884d975f...
# 140504  document_parses/pdf_json/fb0bce3654938b8c93e5b...
# 140505  document_parses/pdf_json/8d1498b4b95b0bf8f6d95...
# 140506  document_parses/pdf_json/738d255294896f43d6ac7...
# 140507  document_parses/pdf_json/2918a43791587306be37d...
# 140508  document_parses/pdf_json/21974784c3eb198439eab...
# 140509  document_parses/pdf_json/1b759c9a06fa77009c227...
# 140510  document_parses/pdf_json/f7c6f6eda0e0bfa77134c...
# 140511  document_parses/pdf_json/621832d547930a8c23859...
# 140512  document_parses/pdf_json/b466c5c6dc539542eba79...
# 140513  document_parses/pdf_json/ff8610a4d772b4ec54975...
# 140514  document_parses/pdf_json/6bde3798df501fc40dd89...
# 140515                                                NaN
# 140516                                                NaN
# 140517  document_parses/pdf_json/704fd6c6608f5b400f005...
# 140518  document_parses/pdf_json/556e48d9685a2e212757c...
# 140519  document_parses/pdf_json/ff09007b2973bf3dc9a04...
# 140520  document_parses/pdf_json/3711609ee9f51aed04b50...
# 140521                                                NaN
# 140522  document_parses/pdf_json/ab98d1b125aa0704e63ad...
# 140523  document_parses/pdf_json/633e89365f800d4e5c888...
# 140524  document_parses/pdf_json/0a67144ee20745181efe1...
# 140525  document_parses/pdf_json/047ca5a826da314da2421...
# 140526  document_parses/pdf_json/9057e2fc54df6336793af...
# 140527  document_parses/pdf_json/0bfafe584842551754428...
# 140528                                                NaN
# 140529  document_parses/pdf_json/35908ee476f9b20d8e214...
# 140530  document_parses/pdf_json/c48c0b02b916043300386...
# 140531  document_parses/pdf_json/a87e85c0e1a7473370e86...
#
#                                       pmc_json_files  \
# 0         document_parses/pmc_json/PMC35282.xml.json
# 1         document_parses/pmc_json/PMC59543.xml.json
# 2         document_parses/pmc_json/PMC59549.xml.json
# 3         document_parses/pmc_json/PMC59574.xml.json
# 4         document_parses/pmc_json/PMC59580.xml.json
# 5        document_parses/pmc_json/PMC125340.xml.json
# 6        document_parses/pmc_json/PMC125375.xml.json
# 7        document_parses/pmc_json/PMC125543.xml.json
# 8        document_parses/pmc_json/PMC126080.xml.json
# 9        document_parses/pmc_json/PMC136939.xml.json
# 10       document_parses/pmc_json/PMC137267.xml.json
# 11       document_parses/pmc_json/PMC137274.xml.json
# 12       document_parses/pmc_json/PMC140314.xml.json
# 13       document_parses/pmc_json/PMC156578.xml.json
# 14       document_parses/pmc_json/PMC169038.xml.json
# 15                                               NaN
# 16       document_parses/pmc_json/PMC193681.xml.json
# 17       document_parses/pmc_json/PMC204495.xml.json
# 18       document_parses/pmc_json/PMC212558.xml.json
# 19       document_parses/pmc_json/PMC212776.xml.json
# 20       document_parses/pmc_json/PMC222908.xml.json
# 21       document_parses/pmc_json/PMC222911.xml.json
# 22       document_parses/pmc_json/PMC222961.xml.json
# 23       document_parses/pmc_json/PMC261870.xml.json
# 24       document_parses/pmc_json/PMC280685.xml.json
# 25       document_parses/pmc_json/PMC293432.xml.json
# 26       document_parses/pmc_json/PMC300679.xml.json
# 27       document_parses/pmc_json/PMC302018.xml.json
# 28       document_parses/pmc_json/PMC302072.xml.json
# 29       document_parses/pmc_json/PMC302190.xml.json
# ...                                              ...
# 140502  document_parses/pmc_json/PMC2666650.xml.json
# 140503                                           NaN
# 140504  document_parses/pmc_json/PMC7079974.xml.json
# 140505  document_parses/pmc_json/PMC7119936.xml.json
# 140506  document_parses/pmc_json/PMC3185605.xml.json
# 140507  document_parses/pmc_json/PMC7173232.xml.json
# 140508  document_parses/pmc_json/PMC7115636.xml.json
# 140509                                           NaN
# 140510  document_parses/pmc_json/PMC7236708.xml.json
# 140511  document_parses/pmc_json/PMC6036261.xml.json
# 140512  document_parses/pmc_json/PMC7151884.xml.json
# 140513  document_parses/pmc_json/PMC7111680.xml.json
# 140514  document_parses/pmc_json/PMC7112672.xml.json
# 140515                                           NaN
# 140516                                           NaN
# 140517  document_parses/pmc_json/PMC7159567.xml.json
# 140518  document_parses/pmc_json/PMC7127222.xml.json
# 140519  document_parses/pmc_json/PMC6609189.xml.json
# 140520  document_parses/pmc_json/PMC7126824.xml.json
# 140521                                           NaN
# 140522  document_parses/pmc_json/PMC3973683.xml.json
# 140523  document_parses/pmc_json/PMC6598888.xml.json
# 140524  document_parses/pmc_json/PMC7171263.xml.json
# 140525  document_parses/pmc_json/PMC6547584.xml.json
# 140526                                           NaN
# 140527  document_parses/pmc_json/PMC7253117.xml.json
# 140528                                           NaN
# 140529  document_parses/pmc_json/PMC7247502.xml.json
# 140530  document_parses/pmc_json/PMC7237615.xml.json
# 140531  document_parses/pmc_json/PMC7196922.xml.json
#
#                                                       url        s2_id
# 0       https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...          NaN
# 1       https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...          NaN
# 2       https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...          NaN
# 3       https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...          NaN
# 4       https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...          NaN
# 5       http://europepmc.org/articles/pmc125340?pdf=re...          NaN
# 6       http://europepmc.org/articles/pmc125375?pdf=re...          NaN
# 7       https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...          NaN
# 8       http://europepmc.org/articles/pmc126080?pdf=re...          NaN
# 9       http://europepmc.org/articles/pmc136939?pdf=re...          NaN
# 10      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...          NaN
# 11      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...          NaN
# 12      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...          NaN
# 13      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...          NaN
# 14      http://europepmc.org/articles/pmc169038?pdf=re...          NaN
# 15      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...          NaN
# 16      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...          NaN
# 17      http://europepmc.org/articles/pmc204495?pdf=re...          NaN
# 18      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...          NaN
# 19      https://academic.oup.com/jamia/article-pdf/10/...          NaN
# 20      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...          NaN
# 21      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...          NaN
# 22      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...          NaN
# 23      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...          NaN
# 24      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...          NaN
# 25      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...          NaN
# 26      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...          NaN
# 27      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...          NaN
# 28      http://europepmc.org/articles/pmc302072?pdf=re...          NaN
# 29      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...          NaN
# ...                                                   ...          ...
# 140502  https://doi.org/10.1186/1476-072x-8-14; https:...   22110055.0
# 140503  https://www.sciencedirect.com/science/article/...   81970801.0
# 140504  https://doi.org/10.1007/s00251-016-0966-2; htt...   27740438.0
# 140505  https://api.elsevier.com/content/article/pii/S...   28787868.0
# 140506  https://doi.org/10.3390/v2020468; https://www....      23116.0
# 140507  https://www.sciencedirect.com/science/article/...   45061718.0
# 140508  https://doi.org/10.1016/j.vaccine.2019.08.027;...  202581101.0
# 140509  https://doi.org/10.1134/s002689331006004x; htt...   25495270.0
# 140510  https://www.sciencedirect.com/science/article/...  218685136.0
# 140511  https://www.ncbi.nlm.nih.gov/pubmed/30013528/;...   49426287.0
# 140512  https://api.elsevier.com/content/article/pii/B...   84045346.0
# 140513  https://www.ncbi.nlm.nih.gov/pubmed/19084602/;...   10174449.0
# 140514  https://www.sciencedirect.com/science/article/...   25988951.0
# 140515  https://doi.org/10.1080/07391102.2020.1773929;...  218907132.0
# 140516  https://www.ncbi.nlm.nih.gov/pubmed/32423496/;...  218690811.0
# 140517  https://doi.org/10.1002/anie.200901480; https:...   35417338.0
# 140518  https://www.sciencedirect.com/science/article/...   45864836.0
# 140519  https://doi.org/10.4269/ajtmh.19-0043; https:/...  155103407.0
# 140520  https://doi.org/10.1016/j.ejmech.2011.09.031; ...  207237586.0
# 140521  https://www.ncbi.nlm.nih.gov/pubmed/32466163/;...  218985202.0
# 140522  https://www.ncbi.nlm.nih.gov/pubmed/24695106/;...   16539865.0
# 140523  https://www.ncbi.nlm.nih.gov/pubmed/28721632/;...    3879134.0
# 140524  https://www.ncbi.nlm.nih.gov/pubmed/32240754/;...  214755608.0
# 140525  https://www.ncbi.nlm.nih.gov/pubmed/31159777/;...  174805535.0
# 140526  https://www.ncbi.nlm.nih.gov/pubmed/32214711/;...   85848597.0
# 140527  https://doi.org/10.4269/ajtmh.20-0325; https:/...  216129217.0
# 140528  https://www.sciencedirect.com/science/article/...  214755761.0
# 140529  https://doi.org/10.1016/j.chaos.2020.109925; h...  216562685.0
# 140530  https://doi.org/10.1186/s13756-020-00733-6; ht...  218694154.0
# 140531  https://doi.org/10.1080/17434440.2020.1756771;...  216045863.0
#
# [140532 rows x 19 columns]

# %% [markdown]
# <a id='Single_valued_and_unique'></a>
# ### Single valued and unique
#
# First start by making sure the columns that are supposed to be single valued and unique are actually so.

# %%
SingleValued_and_Unique = ['cord_uid', 'pmcid', 'pubmed_id', 'mag_id', 'who_covidence_id', 'arxiv_id', 'url', 's2_id']

# %%
for Column in SingleValued_and_Unique:
    print(Column, metadataFrame[Column].dropna().is_unique)
# Out:
# cord_uid False
# pmcid True
# pubmed_id False
# mag_id True
# who_covidence_id True
# arxiv_id True
# url False
# s2_id False

# %% [markdown]
# All except mag_id, who_covidence_id and arxiv_id appear to be non-unique. Less than optimal...
#
# Start by checking the cord_uid.

# %%
ValueCounts = metadataFrame['cord_uid'].value_counts()
ValueCounts[ValueCounts>1]
# Out:
# uym826bh    6
# hgpgeel6    5
# lhj7cd8t    5
# 30sjxtnk    5
# 3l4mntw2    4
# q66wkdkd    4
# 7plpn6sn    4
# 4kgndu36    4
# 453q288g    4
# lmo0ry4k    4
# ftanlk8k    4
# hkm8yspk    4
# opwd03wp    4
# 9naohwpo    4
# 4wsueam1    4
# tnctqc1a    4
# q6px4r3j    4
# v88f9e7m    4
# hl8v7n66    4
# mejio1m7    4
# c9jg3bf3    4
# kriro0t4    4
# w0brwyby    4
# ciqrsfpo    4
# f8hgcngj    4
# 8xz0ddci    4
# trzkb9ne    4
# ux7bdk9x    4
# 3msk5ggc    4
# klseuylw    4
#            ..
# 05xedq1l    2
# ziepfnpz    2
# ucorpfw5    2
# 6donibpz    2
# nn2an4up    2
# ydq687u6    2
# q5dhugfa    2
# p370gjjn    2
# 28ygsbo1    2
# 3xe2jjl4    2
# o6bkxn7l    2
# ojtp90na    2
# 2tu707ng    2
# eich19nx    2
# 7xb7hj9u    2
# pauzgepm    2
# bim76jna    2
# h10o18ss    2
# olveh2gf    2
# ywkavncn    2
# 56lr1rlf    2
# l0ggbztj    2
# cb56np26    2
# 0irr4tnw    2
# a6o88zlr    2
# qqh7ayga    2
# l0ongbag    2
# 0n5bxp93    2
# ft9hclnz    2
# fcd07krs    2
# Name: cord_uid, Length: 781, dtype: int64

# %% [markdown]
# As this is supposed to the persistent identifier, looks like some duplicates happening. Close to 800 in fact.
#
# So the easiest way to start with this is by checking to see if these are duplicates, and if they are just eliminating the double records.

# %%
metadataFrame[metadataFrame['cord_uid'].duplicated(keep=False)].sort_values(by=['cord_uid'])
# Out:
#         cord_uid                                                sha  \
# 27100   028avudf                                                NaN
# 60114   028avudf                                                NaN
# 134087  028avudf           4e11d7fbd071bf098dddb9e5beca620fcdaacc39
# 97788   04jbodmf                                                NaN
# 65413   04jbodmf                                                NaN
# 105132  052xdp69           9d9d15ee5ecd1555d091ef0a2a36485d8c810e49
# 61380   052xdp69           9d9d15ee5ecd1555d091ef0a2a36485d8c810e49
# 61379   052xdp69                                                NaN
# 51971   05my504t                                                NaN
# 56347   05my504t                                                NaN
# 65337   05p0hgvq                                                NaN
# 59683   05p0hgvq                                                NaN
# 127725  05xedq1l           17de15d04f7a7643550666d2f0da773f5b7dc95c
# 65404   05xedq1l                                                NaN
# 65772   06vqlhoz                                                NaN
# 116298  06vqlhoz                                                NaN
# 65940   07l9hqsr                                                NaN
# 131408  07l9hqsr           7eb8da93320ea097a81497d97ed22bdad6e708dc
# 108349  08hvlnff           9d6692c99e291964c6eac6a314e3b602ea00acf9
# 38353   08hvlnff                                                NaN
# 66472   08o0re45           57187437fad015cfa48ce55168ac6e60c9f687a4
# 106728  08o0re45           57187437fad015cfa48ce55168ac6e60c9f687a4
# 63377   097nifny                                                NaN
# 137296  097nifny           308576d6375abb65564b6dce15c7e3d5d014cb35
# 139546  0cq5ee1i                                                NaN
# 64269   0cq5ee1i           6936e1a9ece051a13678f9386d399edea38170ff
# 64268   0cq5ee1i                                                NaN
# 64404   0dxl6t4p           000eec3f1e93c3792454ac59415c928ce3a6b4ad
# 115247  0dxl6t4p           000eec3f1e93c3792454ac59415c928ce3a6b4ad
# 30090   0fbmelx0                                                NaN
# ...          ...                                                ...
# 47226   zhcghyw8                                                NaN
# 41140   zhcghyw8                                                NaN
# 62532   ziepfnpz           f7f99b10a8f56b2e0e85885a30ef3e3f3258ce7d
# 132548  ziepfnpz                                                NaN
# 62392   ziijht2j                                                NaN
# 130094  ziijht2j           0ad7c9ac2c3ced6c5cee4267796228ca532da097
# 106317  zmokxa10           831875bf3c05bcfb942f2a35f4b066a1e4cb87d7
# 60379   zmokxa10                                                NaN
# 60380   zmokxa10           831875bf3c05bcfb942f2a35f4b066a1e4cb87d7
# 65087   zn87f1lk                                                NaN
# 140441  zn87f1lk           1cf54d1c77b7f0494ab971429d26e0e199952d09
# 40643   zpib1us1                                                NaN
# 112901  zpib1us1           9ec51cd6ce837abb8eb9bede87b12bf6ea05ed4d
# 60684   zpqrm0a3                                                NaN
# 109019  zpqrm0a3  2d709b295d267319f77e9aa399066b54e34dd265; e87b...
# 113179  zq2h0avw  294cdeb31114bf4946dfdb239252a8ffe49cbdf7; dbaf...
# 60567   zq2h0avw                                                NaN
# 126173  zqbume1i           314260241c5b8b3bf04c0d1f8019893c80c26bda
# 61238   zqbume1i           314260241c5b8b3bf04c0d1f8019893c80c26bda
# 97254   zrf8lam8                                                NaN
# 63144   zrf8lam8                                                NaN
# 63145   zrf8lam8                                                NaN
# 56991   zssgqpv7                                                NaN
# 4422    zssgqpv7           c410269beb98d142c4248faf1e0e212df05c585d
# 33971   zwkl1ywk                                                NaN
# 3740    zwkl1ywk           5a2d0804fc8a4c5d6c661deca4e3150e5cbc77d5
# 62839   zzpw375i                                                NaN
# 110744  zzpw375i                                                NaN
# 128541  zzvqjfet                                                NaN
# 62611   zzvqjfet                                                NaN
#
#                            source_x  \
# 27100                       Medline
# 60114                           WHO
# 134087                 Medline; PMC
# 97788                  Medline; WHO
# 65413                           WHO
# 105132                 Medline; PMC
# 61380                      Elsevier
# 61379                           WHO
# 51971                       Medline
# 56347                       Medline
# 65337                           WHO
# 59683                       Medline
# 127725           Elsevier; PMC; WHO
# 65404                           WHO
# 65772                           WHO
# 116298                 Medline; WHO
# 65940                           WHO
# 131408            Medline; PMC; WHO
# 108349                 Medline; PMC
# 38353                       Medline
# 66472                      Elsevier
# 106728                 Medline; PMC
# 63377                           WHO
# 137296           Elsevier; PMC; WHO
# 139546                 Medline; PMC
# 64269                      Elsevier
# 64268                           WHO
# 64404                      Elsevier
# 115247                 Medline; PMC
# 30090                       Medline
# ...                             ...
# 47226                       Medline
# 41140                       Medline
# 62532                      Elsevier
# 132548                 Medline; PMC
# 62392                           WHO
# 130094            Medline; PMC; WHO
# 106317                 Medline; PMC
# 60379                           WHO
# 60380                      Elsevier
# 65087                           WHO
# 140441            Medline; PMC; WHO
# 40643                       Medline
# 112901       Elsevier; Medline; PMC
# 60684                           WHO
# 109019  Elsevier; Medline; PMC; WHO
# 113179  Elsevier; Medline; PMC; WHO
# 60567                           WHO
# 126173                 Medline; PMC
# 61238                      Elsevier
# 97254                  Medline; PMC
# 63144                           WHO
# 63145                      Elsevier
# 56991                       Medline
# 4422                            PMC
# 33971                       Medline
# 3740                            PMC
# 62839                           WHO
# 110744                 Medline; WHO
# 128541  Elsevier; Medline; PMC; WHO
# 62611                           WHO
#
#                                                     title  \
# 27100   Burden and prevalence of prognostic factors fo...
# 60114   Burden and prevalence of prognostic factors fo...
# 134087  Burden and prevalence of prognostic factors fo...
# 97788   Epidemiologic characteristics of early cases w...
# 65413   Epidemiologic characteristics of early cases w...
# 105132  PERSONAS MAYORES, DEPENDENCIA Y VULNERABILIDAD...
# 61380   PERSONAS MAYORES, DEPENDENCIA Y VULNERABILIDAD...
# 61379   Personas Mayores, Dependencia Y Vulnerabilidad...
# 51971   COVID-19 and Paediatric Inflammatory Bowel Dis...
# 56347   Corona Virus Disease 2019 and Paediatric Infla...
# 65337   Mathematical Modeling of COVID-19 Control and ...
# 59683   An Evaluation Model of COVID-19 Spread Control...
# 127725                          VSI: COVID-19 Therapeutic
# 65404                 COVID-19 Therapeutic and Prevention
# 65772   Editors' Comments Regarding Special Feature Ar...
# 116298  Editors' Comments Regarding Special Feature Ar...
# 65940   An Ounce of Prevention: Coronavirus (COVID-19)...
# 131408  An Ounce of Prevention: Coronavirus (COVID-19)...
# 108349  Chloroquine-induced QTc prolongation in COVID-...
# 38353   Chloroquine-induced QTc prolongation in COVID-...
# 66472   Infecciones virales respiratorias en una cohor...
# 106728  Infecciones virales respiratorias en una cohor...
# 63377   Enfermedad pulmonar obstructiva crónica e infe...
# 137296  Enfermedad pulmonar obstructiva crónica e infe...
# 139546  Influencia de la infección SARS-CoV-2 sobre en...
# 64269   Influencia de la infección SARS-Cov2 sobre Enf...
# 64268   Influencia de la infección SARS-CoV-2 sobre en...
# 64404        Pneumonie virale sévère de l'immunocompétent
# 115247       Pneumonie virale sévère de l'immunocompétent
# 30090   Changes in population movement make COVID-19 s...
# ...                                                   ...
# 47226   Controversy around airborne versus droplet tra...
# 41140   Controversy around airborne versus droplet tra...
# 62532   EPIDEMIOLOGICAL AND CLINICAL CHARACTERISTICS O...
# 132548  EPIDEMIOLOGICAL AND CLINICAL CHARACTERISTICS O...
# 62392   Molecular mechanism for antibody-dependent enh...
# 130094  Molecular Mechanism for Antibody-Dependent Enh...
# 106317  Working in the emergency and inpatient COVID-1...
# 60379   Working in the emergency and inpatient COVID-1...
# 60380   Working in the emergency and inpatient COVID-1...
# 65087   Hydroxychloroquine, a less toxic derivative of...
# 140441  Hydroxychloroquine, a less toxic derivative of...
# 40643   Pathogenicity of a QX-like avian infectious br...
# 112901  Pathogenicity of a QX-like avian infectious br...
# 60684   A multipurpose portable negative air flow isol...
# 109019  A multipurpose portable negative air flow isol...
# 113179  A conceptual model for the outbreak of Coronav...
# 60567   A conceptual model for the coronavirus disease...
# 126173  L’infection par SARS-CoV-2 peut se traduire pa...
# 61238   L’infection par SRAS-CoV-2 peut se traduire pa...
# 97254   Shoulder & Elbow Education During COVID19 – Pe...
# 63144   Shoulder and elbow education during COVID19-pe...
# 63145   Shoulder & Elbow Education During COVID19 – Pe...
# 56991   A randomized trial of the efficacy of hand dis...
# 4422    A Randomized Trial of the Efficacy of Hand Dis...
# 33971     The lifecycle of the Ebola virus in host cells.
# 3740       The lifecycle of the Ebola virus in host cells
# 62839   Features, Evaluation and Treatment Coronavirus...
# 110744  Features, Evaluation and Treatment Coronavirus...
# 128541        COVID-19 in pregnant women – Authors' reply
# 62611         COVID-19 in pregnant women - Authors' reply
#
#                                       doi       pmcid   pubmed_id    license  \
# 27100          10.1007/s10654-020-00646-z         NaN  32425318.0        unk
# 60114          10.1007/s10654-020-00646-z         NaN         NaN        unk
# 134087         10.1007/s10654-020-00646-z  PMC7233678  32424571.0      cc-by
# 97788               10.4178/epih.e2020007         NaN  32035431.0        unk
# 65413               10.4178/epih.e2020007         NaN         NaN        unk
# 105132       10.1016/j.enfcli.2020.05.004  PMC7229944  32425485.0      no-cc
# 61380        10.1016/j.enfcli.2020.05.004         NaN         NaN  els-covid
# 61379        10.1016/j.enfcli.2020.05.004         NaN         NaN        unk
# 51971        10.1097/mpg.0000000000002729         NaN  32235161.0        unk
# 56347        10.1097/mpg.0000000000002729         NaN  32443020.0        unk
# 65337                       10.2196/18638         NaN         NaN        unk
# 59683                       10.2196/18638         NaN  32396132.0        unk
# 127725  10.1016/j.ijantimicag.2020.105937  PMC7135736  32151714.0      no-cc
# 65404   10.1016/j.ijantimicag.2020.105937         NaN         NaN        unk
# 65772        10.1097/mpg.0000000000002745         NaN         NaN        unk
# 116298       10.1097/mpg.0000000000002745         NaN  32443018.0        unk
# 65940                 10.7759/cureus.7345         NaN         NaN        unk
# 131408                10.7759/cureus.7345  PMC7089620  32211279.0      cc-by
# 108349         10.1007/s12471-020-01429-7  PMC7189353  32351347.0      cc-by
# 38353          10.1007/s12471-020-01429-7         NaN  32350818.0        unk
# 66472        10.1016/j.anpedi.2016.08.002         NaN         NaN  els-covid
# 106728       10.1016/j.anpedi.2016.08.002  PMC7185499  27743968.0      no-cc
# 63377        10.1016/j.arbres.2020.04.016         NaN         NaN        unk
# 137296       10.1016/j.arbres.2020.04.016  PMC7218399         NaN  els-covid
# 139546          10.1016/j.nrl.2020.04.002  PMC7164900  32364119.0      no-cc
# 64269           10.1016/j.nrl.2020.04.002         NaN         NaN  els-covid
# 64268           10.1016/j.nrl.2020.04.002         NaN         NaN        unk
# 64404        10.1016/j.reaurg.2004.02.009         NaN         NaN  els-covid
# 115247       10.1016/j.reaurg.2004.02.009  PMC7133792  32288722.0      no-cc
# 30090     10.1016/j.socscimed.2020.113036         NaN  32461170.0        unk
# ...                                   ...         ...         ...        ...
# 47226        10.1097/qco.0000000000000563         NaN  31135389.0        unk
# 41140        10.1097/qco.0000000000000563         NaN  31259864.0        unk
# 62532        10.1016/j.healun.2020.03.008         NaN         NaN  els-covid
# 132548       10.1016/j.healun.2020.03.008  PMC7102567  32362392.0      no-cc
# 62392                10.1128/jvi.02015-19         NaN         NaN        unk
# 130094               10.1128/jvi.02015-19  PMC7022351  31826992.0      no-cc
# 106317          10.1016/j.ajp.2020.102157  PMC7198408  32416532.0      no-cc
# 60379           10.1016/j.ajp.2020.102157         NaN         NaN        unk
# 60380           10.1016/j.ajp.2020.102157         NaN         NaN  els-covid
# 65087           10.1038/s41421-020-0156-0         NaN         NaN        unk
# 140441          10.1038/s41421-020-0156-0  PMC7078228  32194981.0      cc-by
# 40643                   10.3382/ps/pez568         NaN  32416792.0        unk
# 112901                  10.3382/ps/pez568  PMC7111634  31573613.0      no-cc
# 60684           10.1016/j.bja.2020.04.059         NaN         NaN        unk
# 109019          10.1016/j.bja.2020.04.059  PMC7183948  32386834.0      no-cc
# 113179         10.1016/j.ijid.2020.02.058  PMC7102659  32145465.0      no-cc
# 60567          10.1016/j.ijid.2020.02.058         NaN         NaN        unk
# 126173       10.1016/j.jchirv.2020.04.007  PMC7158840  32296473.0      no-cc
# 61238        10.1016/j.jchirv.2020.04.007         NaN         NaN  els-covid
# 97254           10.1016/j.jse.2020.04.017  PMC7188618  32446761.0      no-cc
# 63144           10.1016/j.jse.2020.04.017         NaN         NaN        unk
# 63145           10.1016/j.jse.2020.04.017         NaN         NaN  els-covid
# 56991                  10.1093/cid/cis201         NaN  22412063.0        unk
# 4422                   10.1093/cid/cis201  PMC6276926  22109950.0      no-cc
# 33971           10.18632/oncotarget.18498         NaN  28653957.0        unk
# 3740            10.18632/oncotarget.18498  PMC5589696  28903457.0      cc-by
# 62839             10.1001/jama.2019.21022         NaN         NaN        unk
# 110744            10.1001/jama.2019.21022         NaN  32074261.0        unk
# 128541      10.1016/s1473-3099(20)30192-4  PMC7195406  32197096.0      no-cc
# 62611       10.1016/s1473-3099(20)30192-4         NaN         NaN        unk
#
#                                                  abstract publish_time  \
# 27100   The World Health Organization and European Cen...   2020-05-18
# 60114   The World Health Organization and European Cen...         2020
# 134087  The World Health Organization and European Cen...   2020-05-18
# 97788   In about 20 days since the diagnosis of the fi...         2020
# 65413   Since the first case of 2019 novel coronavirus...         2020
# 105132  The current SARS-CoV-2 pandemic (COVID-19) is ...   2020-05-16
# 61380   Resumen La pandemia actual por SARS-CoV-2 (COV...   2020-05-16
# 61379   The current SARS-CoV-2 pandemic (COVID-19) is ...         2020
# 51971   INTRODUCTION With the current COVID-19 pandemi...   2020-03-31
# 56347   INTRODUCTION With the current coronavirus dise...   2020-06-01
# 65337   BACKGROUND: At the end of February 2020, the s...         2020
# 59683   BACKGROUND Compared to the peak data in early ...   2020-05-12
# 127725                                                NaN   2020-03-07
# 65404                                                 NaN         2020
# 65772                                                 NaN         2020
# 116298                                                NaN         2020
# 65940   Widespread, non-stop, and often sensational co...         2020
# 131408  Widespread, non-stop, and often sensational co...   2020-03-20
# 108349  BACKGROUND: In the battle against the SARS-CoV...   2020-04-29
# 38353   BACKGROUND In the battle against the SARS-CoV‑...   2020-04-29
# 66472   Resumen Introducción Las infecciones respirato...   2017-08-31
# 106728  INTRODUCTION: It is known that infants with vi...   2016-10-13
# 63377                                                 NaN         2020
# 137296                                                NaN   2020-05-13
# 139546  INTRODUCTION: SARS-CoV-2 was first detected in...   2020-04-17
# 64269   RESUMEN INTRODUCCIÓN: La infección por el coro...   2020-04-17
# 64268   INTRODUCTION: SARS-CoV-2 was first detected in...         2020
# 64404   Résumé Les infections virales respiratoires co...   2004-05-31
# 115247  Respiratory infections are frequently encounte...   2004-04-15
# 30090   This comment discusses the contribution of pop...   2020-05-15
# ...                                                   ...          ...
# 47226   PURPOSE OF REVIEW Health agencies recommend tr...         2019
# 41140   PURPOSE OF REVIEW Health agencies recommend tr...         2019
# 62532   ABSTRACT BACKGROUND The epidemiological and cl...   2020-03-25
# 132548  BACKGROUND: The epidemiological and clinical c...   2020-03-25
# 62392   Antibody-dependent enhancement (ADE) of viral ...         2019
# 130094  Antibody-dependent enhancement (ADE) of viral ...   2020-02-14
# 106317  • Authorities of Iran University of Medical Sc...   2020-05-05
# 60379                                                 NaN         2020
# 60380                                                 NaN   2020-05-05
# 65087                                                 NaN         2020
# 140441                                                NaN   2020-03-18
# 40643   Avian infectious bronchitis is a serious and h...   2020-01-01
# 112901  Avian infectious bronchitis is a serious and h...   2019-12-30
# 60684                                                 NaN         2020
# 109019                                                NaN   2020-04-27
# 113179  The ongoing Coronavirus Disease 2019 (COVID-19...   2020-03-04
# 60567   The ongoing coronavirus disease 2019 (COVID-19...         2020
# 126173  The initial clinical presentation of coronavir...   2020-04-15
# 61238   Court résumé La présentation clinique initiale...   2020-04-15
# 97254                                                 NaN   2020-04-29
# 63144                                                 NaN         2020
# 63145                                                 NaN   2020-04-29
# 56991   BACKGROUND Hand disinfection is frequently rec...         2012
# 4422    Background. Hand disinfection is frequently re...   2012-05-15
# 33971   Ebola haemorrhagic fever causes deadly disease...         2017
# 3740    Ebola haemorrhagic fever causes deadly disease...   2017-06-15
# 62839   According to the World Health Organization (WH...         2020
# 110744  According to the World Health Organization (WH...         2020
# 128541                                                NaN   2020-03-17
# 62611                                                 NaN         2020
#
#                                                   authors  \
# 27100   Gémes, Katalin; Talbäck, Mats; Modig, Karin; A...
# 60114   Gémes, Katalin; Talbäck, Mats; Modig, Karin; A...
# 134087  Gémes, Katalin; Talbäck, Mats; Modig, Karin; A...
# 97788                  Ki, Moran; Task Force for -nCo, V.
# 65413                     Ki, Moran; nCoV, Task Force For
# 105132  Gálvez, Ana Mª Porcel; Romero, Bárbara Badanta...
# 61380   Gálvez, Ana Mª Porcel; Romero, Bárbara Badanta...
# 61379   Gálvez, Ana Mª Porcel; Romero, Bárbara Badanta...
# 51971   Turner, Dan; Huang, Ying; Martín-de-Carpi, Jav...
# 56347   Turner, Dan; Huang, Ying; Martín-de-Carpi, Jav...
# 65337                   Huang, Qiangsheng; Kang, Yu Sunny
# 59683                   Huang, Qiangsheng; Kang, Yu Sunny
# 127725  Raoult, Didier; Hsueh, Po-Ren; Stefania, Stefa...
# 65404   Raoult, Didier; Hsueh, Po-Ren; Stefani, Stefan...
# 65772                Heyman, Melvin B; Belli, Dominique C
# 116298               Heyman, Melvin B; Belli, Dominique C
# 65940                                   Escher, A. R. Jr.
# 131408                                    Escher, Allan R
# 108349  van den Broek, M. P. H.; Möhlmann, J. E.; Abel...
# 38353   van den Broek, M P H; Möhlmann, J E; Abeln, B ...
# 66472   Calvo, Cristina; Aguado, Isabel; García-García...
# 106728  Calvo, Cristina; Aguado, Isabel; García-García...
# 63377   Gonçalves, Juan Marco Figueira; Golpe, Rafael;...
# 137296  Gonçalves, Juan Marco Figueira; Golpe, Rafael;...
# 139546  Serrano-Castro, P.J.; Estivill-Torrús, G.; Cab...
# 64269   Serrano-Castro, Pedro J.; Estivill-Torrús, Gui...
# 64268   Serrano-Castro, P J; Estivill-Torrús, G; Cabez...
# 64404   Guery, B; d'Escrivan, T; Georges, H; Legout, L...
# 115247  Guery, B; d'Escrivan, T; Georges, H; Legout, L...
# 30090   Shi, Qiujie; Dorling, Danny; Cao, Guangzhong; ...
# ...                                                   ...
# 47226   Shiu, Eunice Y C; Leung, Nancy H L; Cowling, B...
# 41140   Shiu, Eunice Y C; Leung, Nancy H L; Cowling, B...
# 62532   Ren, Zong-Li; Hu, Rui; Wang, Zhi-Wei; Zhang, M...
# 132548  Ren, Zong-Li; Hu, Rui; Wang, Zhi-Wei; Zhang, M...
# 62392   Wan, Y.; Shang, J.; Sun, S.; Tai, W.; Chen, J....
# 130094  Wan, Yushun; Shang, Jian; Sun, Shihui; Tai, Wa...
# 106317  Behnam Shariati, M.; Mehrdad Eftekhar Ardebili...
# 60379   Shariati, Behnam; Eftekhar Ardebili, Mehrdad; ...
# 60380   Behnam Shariati, M.; Mehrdad Eftekhar Ardebili...
# 65087   Liu, J.; Cao, R.; Xu, M.; Wang, X.; Zhang, H.;...
# 140441  Liu, Jia; Cao, Ruiyuan; Xu, Mingyue; Wang, Xi;...
# 40643   Ren, Guangcai; Liu, Fan; Huang, Miaorong; Li, ...
# 112901  Ren, Guangcai; Liu, Fan; Huang, Miaorong; Li, ...
# 60684   Cubillos, Javier; Querney, Jill; Rankin, Adam;...
# 109019  Cubillos, Javier; Querney, Jill; Rankin, Adam;...
# 113179  Lin, Qianying; Zhao, Shi; Gao, Daozhou; Lou, Y...
# 60567   Lin, Qianying; Zhao, Shi; Gao, Daozhou; Lou, Y...
# 126173                           Pautrat, K.; Chergui, N.
# 61238                     Pautrat, Karine; Chergui, Naïma
# 97254   Jones, Steven D.; Thon, Stephen; Frank, Rachel M.
# 63144     Jones, Steven D; Thon, Stephen; Frank, Rachel M
# 63145   Jones, Steven D.; Thon, Stephen; Frank, Rachel M.
# 56991   Turner, Ronald B; Fuls, Janice L; Rodgers, Nan...
# 4422    Turner, Ronald B.; Fuls, Janice L.; Rodgers, N...
# 33971   Yu, Dong-Shan; Weng, Tian-Hao; Wu, Xiao-Xin; W...
# 3740    Yu, Dong-Shan; Weng, Tian-Hao; Wu, Xiao-Xin; W...
# 62839   Cascella, M.; Rajnik, M.; Cuomo, A.; Dulebohn,...
# 110744  Cascella, M.; Rajnik, M.; Cuomo, A.; Dulebohn,...
# 128541  Baud, David; Giannoni, Eric; Pomar, Léo; Qi, X...
# 62611   Baud, David; Giannoni, Eric; Pomar, Léo; Qi, X...
#
#                                                   journal  mag_id  \
# 27100                    European journal of epidemiology     NaN
# 60114                                     Eur J Epidemiol     NaN
# 134087                                    Eur J Epidemiol     NaN
# 97788                             Epidemiology and health     NaN
# 65413                                    Epidemiol Health     NaN
# 105132                                        Enferm Clin     NaN
# 61380                                                 NaN     NaN
# 61379                           Enferm. clin. (Ed. impr.)     NaN
# 51971   Journal of pediatric gastroenterology and nutr...     NaN
# 56347   Journal of pediatric gastroenterology and nutr...     NaN
# 65337                         JMIR Public Health Surveill     NaN
# 59683                 JMIR public health and surveillance     NaN
# 127725                            Int J Antimicrob Agents     NaN
# 65404                             Int J Antimicrob Agents     NaN
# 65772                        J Pediatr Gastroenterol Nutr     NaN
# 116298                       J Pediatr Gastroenterol Nutr     NaN
# 65940                                              Cureus     NaN
# 131408                                             Cureus     NaN
# 108349                                       Neth Heart J     NaN
# 38353   Netherlands heart journal : monthly journal of...     NaN
# 66472                                 Anales de Pediatría     NaN
# 106728                                  An Pediatr (Barc)     NaN
# 63377                     Arch. bronconeumol. (Ed. impr.)     NaN
# 137296                                  Arch Bronconeumol     NaN
# 139546                                         Neurologia     NaN
# 64269                                                 NaN     NaN
# 64268                       Neurologia (Barc., Ed. impr.)     NaN
# 64404                                         Réanimation     NaN
# 115247                                        Reanimation     NaN
# 30090                           Social science & medicine     NaN
# ...                                                   ...     ...
# 47226              Current opinion in infectious diseases     NaN
# 41140              Current opinion in infectious diseases     NaN
# 62532                                                 NaN     NaN
# 132548                            J Heart Lung Transplant     NaN
# 62392                                 Journal of virology     NaN
# 130094                                            J Virol     NaN
# 106317                                  Asian J Psychiatr     NaN
# 60379                                   Asian J Psychiatr     NaN
# 60380                                                 NaN     NaN
# 65087                                      Cell discovery     NaN
# 140441                                        Cell Discov     NaN
# 40643                                     Poultry science     NaN
# 112901                                          Poult Sci     NaN
# 60684                                      Br. j. anaesth     NaN
# 109019                                       Br J Anaesth     NaN
# 113179                                   Int J Infect Dis     NaN
# 60567                                    Int J Infect Dis     NaN
# 126173                     Journal de chirurgie viscerale     NaN
# 61238                                                 NaN     NaN
# 97254                               J Shoulder Elbow Surg     NaN
# 63144                              J. shoulder elbow surg     NaN
# 63145                                                 NaN     NaN
# 56991   Clinical infectious diseases : an official pub...     NaN
# 4422                                      Clin Infect Dis     NaN
# 33971                                          Oncotarget     NaN
# 3740                                           Oncotarget     NaN
# 62839                                          StatPearls     NaN
# 110744                                         StatPearls     NaN
# 128541                                  Lancet Infect Dis     NaN
# 62611                                  Lancet infect. dis     NaN
#
#        who_covidence_id arxiv_id  \
# 27100               NaN      NaN
# 60114           #291472      NaN
# 134087              NaN      NaN
# 97788            #10145      NaN
# 65413              #567      NaN
# 105132              NaN      NaN
# 61380               NaN      NaN
# 61379           #276713      NaN
# 51971               NaN      NaN
# 56347               NaN      NaN
# 65337           #245568      NaN
# 59683               NaN      NaN
# 127725            #5723      NaN
# 65404            #11258      NaN
# 65772            #38421      NaN
# 116298          #326300      NaN
# 65940         #32211279      NaN
# 131408           #18612      NaN
# 108349              NaN      NaN
# 38353               NaN      NaN
# 66472               NaN      NaN
# 106728              NaN      NaN
# 63377           #245595      NaN
# 137296          #260550      NaN
# 139546              NaN      NaN
# 64269               NaN      NaN
# 64268            #71976      NaN
# 64404               NaN      NaN
# 115247              NaN      NaN
# 30090               NaN      NaN
# ...                 ...      ...
# 47226               NaN      NaN
# 41140               NaN      NaN
# 62532               NaN      NaN
# 132548              NaN      NaN
# 62392               #10      NaN
# 130094             #908      NaN
# 106317              NaN      NaN
# 60379           #176119      NaN
# 60380               NaN      NaN
# 65087            #11351      NaN
# 140441        #32194981      NaN
# 40643               NaN      NaN
# 112901              NaN      NaN
# 60684           #125416      NaN
# 109019        #32386834      NaN
# 113179            #6596      NaN
# 60567             #4507      NaN
# 126173              NaN      NaN
# 61238               NaN      NaN
# 97254               NaN      NaN
# 63144           #141607      NaN
# 63145               NaN      NaN
# 56991               NaN      NaN
# 4422                NaN      NaN
# 33971               NaN      NaN
# 3740                NaN      NaN
# 62839            #12230      NaN
# 110744        #32150360      NaN
# 128541           #11553      NaN
# 62611            #14387      NaN
#
#                                            pdf_json_files  \
# 27100                                                 NaN
# 60114                                                 NaN
# 134087  document_parses/pdf_json/4e11d7fbd071bf098dddb...
# 97788                                                 NaN
# 65413                                                 NaN
# 105132  document_parses/pdf_json/9d9d15ee5ecd1555d091e...
# 61380   document_parses/pdf_json/9d9d15ee5ecd1555d091e...
# 61379                                                 NaN
# 51971                                                 NaN
# 56347                                                 NaN
# 65337                                                 NaN
# 59683                                                 NaN
# 127725  document_parses/pdf_json/17de15d04f7a764355066...
# 65404                                                 NaN
# 65772                                                 NaN
# 116298                                                NaN
# 65940                                                 NaN
# 131408  document_parses/pdf_json/7eb8da93320ea097a8149...
# 108349  document_parses/pdf_json/9d6692c99e291964c6eac...
# 38353                                                 NaN
# 66472   document_parses/pdf_json/57187437fad015cfa48ce...
# 106728  document_parses/pdf_json/57187437fad015cfa48ce...
# 63377                                                 NaN
# 137296  document_parses/pdf_json/308576d6375abb65564b6...
# 139546                                                NaN
# 64269   document_parses/pdf_json/6936e1a9ece051a13678f...
# 64268                                                 NaN
# 64404   document_parses/pdf_json/000eec3f1e93c3792454a...
# 115247  document_parses/pdf_json/000eec3f1e93c3792454a...
# 30090                                                 NaN
# ...                                                   ...
# 47226                                                 NaN
# 41140                                                 NaN
# 62532   document_parses/pdf_json/f7f99b10a8f56b2e0e858...
# 132548                                                NaN
# 62392                                                 NaN
# 130094  document_parses/pdf_json/0ad7c9ac2c3ced6c5cee4...
# 106317  document_parses/pdf_json/831875bf3c05bcfb942f2...
# 60379                                                 NaN
# 60380   document_parses/pdf_json/831875bf3c05bcfb942f2...
# 65087                                                 NaN
# 140441  document_parses/pdf_json/1cf54d1c77b7f0494ab97...
# 40643                                                 NaN
# 112901  document_parses/pdf_json/9ec51cd6ce837abb8eb9b...
# 60684                                                 NaN
# 109019  document_parses/pdf_json/2d709b295d267319f77e9...
# 113179  document_parses/pdf_json/294cdeb31114bf4946dfd...
# 60567                                                 NaN
# 126173  document_parses/pdf_json/314260241c5b8b3bf04c0...
# 61238   document_parses/pdf_json/314260241c5b8b3bf04c0...
# 97254                                                 NaN
# 63144                                                 NaN
# 63145                                                 NaN
# 56991                                                 NaN
# 4422    document_parses/pdf_json/c410269beb98d142c4248...
# 33971                                                 NaN
# 3740    document_parses/pdf_json/5a2d0804fc8a4c5d6c661...
# 62839                                                 NaN
# 110744                                                NaN
# 128541                                                NaN
# 62611                                                 NaN
#
#                                       pmc_json_files  \
# 27100                                            NaN
# 60114                                            NaN
# 134087  document_parses/pmc_json/PMC7233678.xml.json
# 97788                                            NaN
# 65413                                            NaN
# 105132                                           NaN
# 61380                                            NaN
# 61379                                            NaN
# 51971                                            NaN
# 56347                                            NaN
# 65337                                            NaN
# 59683                                            NaN
# 127725  document_parses/pmc_json/PMC7135736.xml.json
# 65404                                            NaN
# 65772                                            NaN
# 116298                                           NaN
# 65940                                            NaN
# 131408  document_parses/pmc_json/PMC7089620.xml.json
# 108349  document_parses/pmc_json/PMC7189353.xml.json
# 38353                                            NaN
# 66472                                            NaN
# 106728  document_parses/pmc_json/PMC7185499.xml.json
# 63377                                            NaN
# 137296                                           NaN
# 139546  document_parses/pmc_json/PMC7164900.xml.json
# 64269                                            NaN
# 64268                                            NaN
# 64404                                            NaN
# 115247  document_parses/pmc_json/PMC7133792.xml.json
# 30090                                            NaN
# ...                                              ...
# 47226                                            NaN
# 41140                                            NaN
# 62532                                            NaN
# 132548  document_parses/pmc_json/PMC7102567.xml.json
# 62392                                            NaN
# 130094  document_parses/pmc_json/PMC7022351.xml.json
# 106317  document_parses/pmc_json/PMC7198408.xml.json
# 60379                                            NaN
# 60380                                            NaN
# 65087                                            NaN
# 140441                                           NaN
# 40643                                            NaN
# 112901  document_parses/pmc_json/PMC7111634.xml.json
# 60684                                            NaN
# 109019  document_parses/pmc_json/PMC7183948.xml.json
# 113179  document_parses/pmc_json/PMC7102659.xml.json
# 60567                                            NaN
# 126173                                           NaN
# 61238                                            NaN
# 97254                                            NaN
# 63144                                            NaN
# 63145                                            NaN
# 56991                                            NaN
# 4422    document_parses/pmc_json/PMC6276926.xml.json
# 33971                                            NaN
# 3740    document_parses/pmc_json/PMC5589696.xml.json
# 62839                                            NaN
# 110744                                           NaN
# 128541  document_parses/pmc_json/PMC7195406.xml.json
# 62611                                            NaN
#
#                                                       url        s2_id
# 27100   https://doi.org/10.1007/s10654-020-00646-z; ht...  218675407.0
# 60114          https://doi.org/10.1007/s10654-020-00646-z  218675407.0
# 134087  https://doi.org/10.1007/s10654-020-00646-z; ht...  218689939.0
# 97788   https://www.ncbi.nlm.nih.gov/pubmed/32035431/;...  211072168.0
# 65413               https://doi.org/10.4178/epih.e2020007  211072168.0
# 105132  https://www.ncbi.nlm.nih.gov/pubmed/32425485/;...  218688637.0
# 61380   https://api.elsevier.com/content/article/pii/S...  218656984.0
# 61379        https://doi.org/10.1016/j.enfcli.2020.05.004  218656984.0
# 51971   https://doi.org/10.1097/mpg.0000000000002729; ...  214772386.0
# 56347   https://doi.org/10.1097/mpg.0000000000002729; ...  218856260.0
# 65337                       https://doi.org/10.2196/18638  218881990.0
# 59683   https://doi.org/10.2196/18638; https://www.ncb...  218599043.0
# 127725  https://www.sciencedirect.com/science/article/...  214758163.0
# 65404   https://doi.org/10.1016/j.ijantimicag.2020.105937  214758163.0
# 65772        https://doi.org/10.1097/mpg.0000000000002745  216348624.0
# 116298  https://doi.org/10.1097/mpg.0000000000002745; ...  216348624.0
# 65940                 https://doi.org/10.7759/cureus.7345  214643349.0
# 131408  https://doi.org/10.7759/cureus.7345; https://w...  214643349.0
# 108349  https://www.ncbi.nlm.nih.gov/pubmed/32351347/;...  216608674.0
# 38353   https://doi.org/10.1007/s12471-020-01429-7; ht...  217587436.0
# 66472   https://api.elsevier.com/content/article/pii/S...  196477918.0
# 106728  https://doi.org/10.1016/j.anpedi.2016.08.002; ...   23770537.0
# 63377        https://doi.org/10.1016/j.arbres.2020.04.016  218596478.0
# 137296  https://doi.org/10.1016/j.arbres.2020.04.016; ...  218596478.0
# 139546  https://www.ncbi.nlm.nih.gov/pubmed/32364119/;...  218492029.0
# 64269   https://api.elsevier.com/content/article/pii/S...  215801041.0
# 64268           https://doi.org/10.1016/j.nrl.2020.04.002  215801041.0
# 64404   https://api.elsevier.com/content/article/pii/S...   71748484.0
# 115247  https://www.ncbi.nlm.nih.gov/pubmed/32288722/;...  215774295.0
# 30090   https://doi.org/10.1016/j.socscimed.2020.11303...  218975707.0
# ...                                                   ...          ...
# 47226   https://doi.org/10.1097/qco.0000000000000563; ...  167221342.0
# 41140   https://doi.org/10.1097/qco.0000000000000563; ...  195756918.0
# 62532   https://api.elsevier.com/content/article/pii/S...  214729855.0
# 132548  https://doi.org/10.1016/j.healun.2020.03.008; ...  218490336.0
# 62392                https://doi.org/10.1128/jvi.02015-19  209330085.0
# 130094  https://www.ncbi.nlm.nih.gov/pubmed/31826992/;...  209330085.0
# 106317  https://www.ncbi.nlm.nih.gov/pubmed/32416532/;...  218670117.0
# 60379           https://doi.org/10.1016/j.ajp.2020.102157  218488468.0
# 60380   https://api.elsevier.com/content/article/pii/S...  218488468.0
# 65087           https://doi.org/10.1038/s41421-020-0156-0  212742290.0
# 140441  https://www.ncbi.nlm.nih.gov/pubmed/32194981/;...  212742290.0
# 40643   https://doi.org/10.3382/ps/pez568; https://www...  218677349.0
# 112901  https://www.sciencedirect.com/science/article/...  203622120.0
# 60684           https://doi.org/10.1016/j.bja.2020.04.059  216145080.0
# 109019  https://doi.org/10.1016/j.bja.2020.04.059; htt...  216145080.0
# 113179  https://www.ncbi.nlm.nih.gov/pubmed/32145465/;...  212629365.0
# 60567          https://doi.org/10.1016/j.ijid.2020.02.058  212629365.0
# 126173  https://www.ncbi.nlm.nih.gov/pubmed/32296473/;...  215793935.0
# 61238   https://api.elsevier.com/content/article/pii/S...  215769689.0
# 97254   https://www.ncbi.nlm.nih.gov/pubmed/32446761/;...  218873499.0
# 63144           https://doi.org/10.1016/j.jse.2020.04.017  216588790.0
# 63145   https://api.elsevier.com/content/article/pii/S...  216588790.0
# 56991   https://doi.org/10.1093/cid/cis201; https://ww...   18823544.0
# 4422    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...          NaN
# 33971   https://doi.org/10.18632/oncotarget.18498; htt...   10664454.0
# 3740    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...          NaN
# 62839             https://doi.org/10.1001/jama.2019.21022  211213857.0
# 110744  https://www.ncbi.nlm.nih.gov/pubmed/32074261/;...  211213857.0
# 128541  https://www.sciencedirect.com/science/article/...  214601689.0
# 62611       https://doi.org/10.1016/s1473-3099(20)30192-4  214601689.0
#
# [1781 rows x 19 columns]

# %% [markdown]
# It looks like this is primarily an issue of source.
#
# For now just drop these records. A little under 800 will not have an impact within a corpus of 140k+

# %%
print('Rows before: {}'.format(metadataFrame.shape[0]))
metadataFrame = metadataFrame.drop_duplicates('cord_uid', keep=False) # drop all duplicates. keep='first' or keep='last' would keep the first/last
print('Rows after: {}'.format(metadataFrame.shape[0]))
# Out:
# Rows before: 140532
# Rows after: 138751

# %%
metadataFrame['cord_uid'].dropna().is_unique
# Out:
# True

# %% [markdown]
# So that worked. cord_uid is now unique.

# %%
for Column in SingleValued_and_Unique:
    print(Column, metadataFrame[Column].dropna().is_unique)
# Out:
# cord_uid True
# pmcid True
# pubmed_id False
# mag_id True
# who_covidence_id True
# arxiv_id True
# url True
# s2_id False

# %% [markdown]
# Also cleared up pmcid and url. Would have been nice if it cleared up a few of the others too though. Let's do a quick check of what discrepancies are left.

# %%
# For each column in SingleValued_and_Unique, this prints the values that appear in more than 1 record.
for Column in SingleValued_and_Unique:
    ValueCounts = metadataFrame[Column].value_counts()
    print(ValueCounts[ValueCounts>1])
# Out:
# Series([], Name: cord_uid, dtype: int64)
# Series([], Name: pmcid, dtype: int64)
# 32419926.0    3
# 16575523.0    2
# 17098273.0    2
# 23842446.0    2
# 1655870.0     2
# 16115318.0    2
# 15313178.0    2
# 8546012.0     2
# 26499340.0    2
# 8545971.0     2
# 11918861.0    2
# 207058.0      2
# 16116432.0    2
# 16112641.0    2
# 16112593.0    2
# 1331160.0     2
# 1656597.0     2
# 16112259.0    2
# 9058755.0     2
# 16111992.0    2
# 15316497.0    2
# 26509109.0    2
# 1655802.0     2
# 9050994.0     2
# 26475793.0    2
# 18095180.0    2
# 16417929.0    2
# 2997998.0     2
# 32238613.0    2
# 16118891.0    2
#              ..
# 12683406.0    2
# 25458561.0    2
# 16964581.0    2
# 17030494.0    2
# 16534565.0    2
# 6171237.0     2
# 17037549.0    2
# 2446421.0     2
# 6199888.0     2
# 17037602.0    2
# 16781410.0    2
# 12484662.0    2
# 17037504.0    2
# 17002511.0    2
# 25558126.0    2
# 12781012.0    2
# 196571.0      2
# 17037499.0    2
# 17037567.0    2
# 17922397.0    2
# 16963099.0    2
# 16582497.0    2
# 16781449.0    2
# 12377851.0    2
# 17052935.0    2
# 16824137.0    2
# 16940861.0    2
# 17037505.0    2
# 16963814.0    2
# 16564412.0    2
# Name: pubmed_id, Length: 6904, dtype: int64
# Series([], Name: mag_id, dtype: int64)
# Series([], Name: who_covidence_id, dtype: int64)
# Series([], Name: arxiv_id, dtype: int64)
# Series([], Name: url, dtype: int64)
# 218505634.0    11
# 215757024.0     7
# 216594995.0     6
# 216608860.0     5
# 215516743.0     5
# 214750728.0     4
# 214806960.0     4
# 212416673.0     4
# 212566409.0     4
# 216646414.0     4
# 215792428.0     4
# 212416824.0     4
# 215789919.0     4
# 216083259.0     4
# 214771151.0     4
# 215773858.0     4
# 211727464.0     4
# 216277140.0     4
# 218505587.0     4
# 218894170.0     4
# 218469618.0     4
# 215410263.0     4
# 216588742.0     4
# 214767010.0     4
# 214645426.0     4
# 215599719.0     4
# 216647817.0     4
# 216111185.0     4
# 214763298.0     4
# 217547418.0     4
#                ..
# 25606886.0      2
# 218503635.0     2
# 216129954.0     2
# 211261524.0     2
# 24627568.0      2
# 218481688.0     2
# 211262275.0     2
# 218650288.0     2
# 215748994.0     2
# 215749622.0     2
# 218679959.0     2
# 22576500.0      2
# 215748266.0     2
# 215794093.0     2
# 212741413.0     2
# 215756358.0     2
# 218669625.0     2
# 19379075.0      2
# 25610886.0      2
# 6144193.0       2
# 28913787.0      2
# 12305892.0      2
# 218657621.0     2
# 22595348.0      2
# 218552569.0     2
# 216031045.0     2
# 215605103.0     2
# 216595987.0     2
# 8731122.0       2
# 216595078.0     2
# Name: s2_id, Length: 13570, dtype: int64

# %% [markdown]
# __pubmed_id__
# This has almost 7000 duplicates. Lets have a quick look.

# %%
# These get a bit complicated. Basically it starts by selecting the rows that have duplicate (non-null) pubmed_id

metadataFrame[metadataFrame['pubmed_id'].duplicated(keep=False) & metadataFrame['pubmed_id'].notnull()].sort_values(by=['pubmed_id'])
# Out:
#         cord_uid                                       sha           source_x  \
# 74183   crz30eba                                       NaN            Medline
# 137250  nl5kmmtd  3a2ff3a86c4b06fb35f0422034ce8c65f7ca0bd3      Elsevier; PMC
# 76159   4l35bv99                                       NaN            Medline
# 136565  m9j3pcj1  5610c53dce08ee3038eade1231d7d6d0fc6a8ad9      Elsevier; PMC
# 78077   3e7gpq2z                                       NaN            Medline
# 13229   smqmp1mm  8090cf4603341df5350674cd0ab3f9877f67f95e                PMC
# 125393  747jppsc  7747dfcb318bbbf7f9edebb69bc91c4b60f5e658      Elsevier; PMC
# 79613   u07xr5nt                                       NaN            Medline
# 83782   100z5zox                                       NaN            Medline
# 97482   h51cebpe  71d3406258973d7ea61a630bf16f5cfa04f78a13      Elsevier; PMC
# 78542   d52nz2mf                                       NaN            Medline
# 117722  v8nifzwn  937e8370900dc469c498f186ae7ede00332e6584      Elsevier; PMC
# 81708   3jfdx6w0                                       NaN            Medline
# 9715    tc402gn4  f7d6f18903a47360a5faff11192ba23e203e5fdf                PMC
# 6196    fe24ezt6  e9854fb393df6ec24710f80621ac88983c3a0fcc                PMC
# 77977   aq698q9r                                       NaN            Medline
# 75395   ol9ifnvq                                       NaN            Medline
# 97722   j3p8uj0c  3dfa916237b9663c3b6f17604d5e970bc4053898      Elsevier; PMC
# 6285    38rgcc5h  34ddcd68407fb141f82a9e14a071c671db883264                PMC
# 70834   0s0ebyla                                       NaN            Medline
# 6015    d6f6a5ds  76a7b0a301baf4436319df3e013755e6f69a80ca                PMC
# 79722   9zr35wfg                                       NaN            Medline
# 83799   p6i8srdt                                       NaN            Medline
# 128930  z58u1u12  b69e28669ea8392a9fa48373b0c4b9e94335914d      Elsevier; PMC
# 119615  4keq0c6u                                       NaN      Elsevier; PMC
# 71378   w0nobqu5                                       NaN            Medline
# 67916   fnkotkdy                                       NaN            Medline
# 130181  6eyetb5i  d62517543cff4abed85182bc70d1b5cfb15e0e6b      Elsevier; PMC
# 74705   k4no88d0                                       NaN            Medline
# 12188   qdh7okux  da8bd99cf1771969654dc5479f60d95636525c05                PMC
# ...          ...                                       ...                ...
# 106429  nnftb092                                       NaN  Medline; PMC; WHO
# 82776   qmmeae8c                                       NaN            Medline
# 67026   zgqbfmzl  08db45ce51ed0b3b32df8fb1b630dfbe2f7a4dff                PMC
# 67025   i8lgih81  630b2c2b88928c1c6196c8df498531a636b8019e                PMC
# 75377   l6r011by                                       NaN            Medline
# 69220   grt4vjck                                       NaN            Medline
# 67024   h0boxuse  aab8259cf3330a0e6d48218b13615fc684b5c016                PMC
# 72052   9fqo7dj8                                       NaN            Medline
# 67027   9alqngxk  8bdb3b4c901d599b20118528573e28c0833dfcf0                PMC
# 106029  f6muhf3d  7d5cc36c59956980c1b44c7de01bba774557eab9  Medline; PMC; WHO
# 55591   3gzh2m4w                                       NaN            Medline
# 81252   62f4tndc                                       NaN            Medline
# 13683   l405c850  88b5c94473256dc08e78e5344fd415773224045a                PMC
# 82999   wnlsxv7z                                       NaN            Medline
# 13681   apw1q940  967f4957bd4dd15955a22f8b644770397e04c407                PMC
# 13682   wl4y44l2  77626f41463222b88a4dae970efd16d14e3b5993                PMC
# 80887   w2jsxq03                                       NaN            Medline
# 139910  t4v368v2  b43c0006285d8b8135a8c632176b183d3451455c       Medline; PMC
# 55879   z20po3eq                                       NaN            Medline
# 74164   n11g2npw                                       NaN            Medline
# 13684   b7jqx7fi                                       NaN                PMC
# 82768   yt9vsxzt                                       NaN            Medline
# 13918   bisheysk  587ee276b2cf25da22405e085734fbbc73c43a8d                PMC
# 31467   mm01p7ha                                       NaN            Medline
# 125835  lweqrczo  4799c0512ecbf9fce0eb0371a8ba628082178a33       Medline; PMC
# 51225   d524xgpf                                       NaN            Medline
# 105934  k9zvsfvj  d06675fc813b77846fdc99f780c19342b2c9d214       Medline; PMC
# 57760   og92zxnf                                       NaN            Medline
# 117222  3bc72zgr  bbc8b65f5849c2007f27b94a1ddcf83598f645ee       Medline; PMC
# 58172   vogum3ir                                       NaN            Medline
#
#                                                     title  \
# 74183   Intestinal influenza: replication and characte...
# 137250  Intestinal influenza: Replication and characte...
# 76159   Resolution of the major poliovirus capsid poly...
# 136565  Resolution of the major poliovirus capsid poly...
# 78077   Physico-chemical properties of mouse hepatitis...
# 13229   Physico‐Chemical Properties of Mouse Hepatitis...
# 125393    PLEOMORPHIC VIRUS-LIKE PARTICLES IN HUMAN FÆCES
# 79613   Pleomorphic virus-like particles in human faeces.
# 83782   Coronavirus propagated from patient with non-b...
# 97482   CORONAVIRUS PROPAGATED FROM PATIENT WITH NON-B...
# 78542   Evidence of a viral aetiology in endemic (Balk...
# 117722  EVIDENCE OF A VIRAL ÆTIOLOGY IN ENDEMIC (BALKA...
# 81708   Antigenic relationship between human coronavir...
# 9715    Antigenic Relationship between Human Coronavir...
# 6196    “Runde“ virus, a coronavirus-like agent associ...
# 77977   "Runde" viurs, a coronavirus-like agent associ...
# 75395   Altered theophylline pharmacokinetics during a...
# 97722   ALTERED THEOPHYLLINE PHARMACOKINETICS DURING A...
# 6285    Antigenic relationship of the feline infectiou...
# 70834   Antigenic relationship of the feline infectiou...
# 6015    A new coronavirus-like particle associated wit...
# 79722   A new coronavirus-like particle associated wit...
# 83799   Development of allergy in children. I. Associa...
# 128930  Development of allergy in children I. Associat...
# 119615  Virus-like particles associated with porcine e...
# 71378   Virus-like particles associated with porcine e...
# 67916                   Neutralization of animal viruses.
# 130181                   Neutralization of Animal Viruses
# 74705   Isozyme characterization of cattle (Bos taurus...
# 12188   Isozyme characterization of cattle (Bos taurus...
# ...                                                   ...
# 106429             ¿Preparados para el nuevo coronavirus?
# 82776   A Novel Coronavirus Outbreak from Wuhan City i...
# 67026   A Novel Coronavirus Outbreak from Wuhan City i...
# 67025   Liver and Kidney Injuries in COVID-19 and Thei...
# 75377   Liver and Kidney Injuries in COVID-19 and Thei...
# 69220   Information Typology in Coronavirus (COVID-19)...
# 67024   Information Typology in Coronavirus (COVID-19)...
# 72052   Coronavirus Pandemic and Worries during Pregna...
# 67027   Coronavirus Pandemic and Worries during Pregna...
# 106029  Prediction of the SARS-CoV-2 (2019-nCoV) 3C-li...
# 55591   Prediction of the SARS-CoV-2 (2019-nCoV) 3C-li...
# 81252   Novel Coronavirus 2019 (2019-nCoV) Infection: ...
# 13683   Novel Coronavirus 2019 (2019-nCoV) Infection: ...
# 82999   Novel Coronavirus 2019 (2019-nCoV) Infection: ...
# 13681   Novel Coronavirus 2019 (2019-nCoV) Infection: ...
# 13682   Measles Immunization: Worth Considering Contai...
# 80887   Measles Immunization: Worth Considering Contai...
# 139910  In silico identification of vaccine targets fo...
# 55879   In silico identification of vaccine targets fo...
# 74164                     COVID-19 and Indian Pediatrics.
# 13684                      COVID-19 and Indian Pediatrics
# 82768   COVID-19: An update on diagnostic and therapeu...
# 13918   COVID-19: an update on diagnostic and therapeu...
# 31467   A review of open source ventilators for COVID-...
# 125835  A review of open source ventilators for COVID-...
# 51225   Gilles de la Tourette Syndrome: advice in the ...
# 105934  Gilles de la Tourette Syndrome: advice in the ...
# 57760   Use of the informational spectrum methodology ...
# 117222  Use of the informational spectrum methodology ...
# 58172   Use of the informational spectrum methodology ...
#
#                                        doi       pmcid   pubmed_id    license  \
# 74183                                  NaN         NaN     23604.0        unk
# 137250        10.1016/0042-6822(78)90247-7  PMC7131577     23604.0  els-covid
# 76159                                  NaN         NaN     27002.0        unk
# 136565        10.1016/0042-6822(78)90093-4  PMC7131310     27002.0  els-covid
# 78077                                  NaN         NaN     30881.0        unk
# 13229   10.1111/j.1348-0421.1978.tb00384.x  PMC7168437     30881.0      no-cc
# 125393       10.1016/s0140-6736(75)91832-2  PMC7173216     48733.0  els-covid
# 79613                                  NaN         NaN     48733.0        unk
# 83782                                  NaN         NaN     53434.0        unk
# 97482        10.1016/s0140-6736(75)90363-3  PMC7135454     53434.0  els-covid
# 78542                                  NaN         NaN     54796.0        unk
# 117722       10.1016/s0140-6736(75)90609-1  PMC7135235     54796.0  els-covid
# 81708                                  NaN         NaN     65439.0        unk
# 9715              10.1093/infdis/135.2.201  PMC7110497     65439.0      no-cc
# 6196                    10.1007/bf01314476  PMC7087166     72555.0      no-cc
# 77977                                  NaN         NaN     72555.0        unk
# 75395                                  NaN         NaN     77421.0        unk
# 97722        10.1016/s0140-6736(78)90305-7  PMC7135825     77421.0  els-covid
# 6285                    10.1007/bf01315534  PMC7087319     81044.0      no-cc
# 70834                                  NaN         NaN     81044.0        unk
# 6015                    10.1007/bf01317606  PMC7086830     83132.0      no-cc
# 79722                                  NaN         NaN     83132.0        unk
# 83799                                  NaN         NaN     85648.0        unk
# 128930        10.1016/0091-6749(79)90106-4  PMC7133211     85648.0  els-covid
# 119615       10.1016/s0034-5288(18)32994-1  PMC7130664    103154.0  els-covid
# 71378                                  NaN         NaN    103154.0        unk
# 67916                                  NaN         NaN    107731.0        unk
# 130181       10.1016/s0065-3527(08)60101-3  PMC7131355    107731.0  els-covid
# 74705                                  NaN         NaN    109020.0        unk
# 12188   10.1111/j.1365-2052.1978.tb01431.x  PMC7159466    109020.0      no-cc
# ...                                    ...         ...         ...        ...
# 106429        10.1016/j.arbres.2020.02.009  PMC7138172  32171583.0      no-cc
# 82776                                  NaN         NaN  32185368.0        unk
# 67026                                  NaN  PMC7075272  32185368.0      cc-by
# 67025                                  NaN  PMC7075271  32185369.0      cc-by
# 75377                                  NaN         NaN  32185369.0        unk
# 69220                                  NaN         NaN  32185370.0        unk
# 67024                                  NaN  PMC7075270  32185370.0      cc-by
# 72052                                  NaN         NaN  32185371.0        unk
# 67027                                  NaN  PMC7075675  32185371.0      cc-by
# 106029      10.12688/f1000research.22457.1  PMC7062204  32194944.0      cc-by
# 55591       10.12688/f1000research.22457.2         NaN  32194944.0        unk
# 81252                                  NaN         NaN  32238612.0        unk
# 13683            10.1007/s13312-020-1785-y  PMC7182738  32238612.0      no-cc
# 82999                                  NaN         NaN  32238613.0        unk
# 13681            10.1007/s13312-020-1786-x  PMC7182733  32238613.0      no-cc
# 13682            10.1007/s13312-020-1804-z  PMC7182737  32238614.0      no-cc
# 80887                                  NaN         NaN  32238614.0        unk
# 139910      10.12688/f1000research.22507.1  PMC7111504  32269766.0      cc-by
# 55879       10.12688/f1000research.22507.2         NaN  32269766.0        unk
# 74164                                  NaN         NaN  32284470.0        unk
# 13684            10.1007/s13312-020-1773-2  PMC7182739  32284470.0      no-cc
# 82768                                  NaN         NaN  32336317.0        unk
# 13918         10.5483/bmbrep.2020.53.4.080  PMC7196187  32336317.0   cc-by-nc
# 31467       10.12688/f1000research.22942.1         NaN  32411358.0        unk
# 125835      10.12688/f1000research.22942.2  PMC7195895  32411358.0      cc-by
# 51225       10.12688/f1000research.23275.1         NaN  32411359.0        unk
# 105934      10.12688/f1000research.23275.2  PMC7195896  32411359.0      cc-by
# 57760       10.12688/f1000research.22149.1         NaN  32419926.0        unk
# 117222      10.12688/f1000research.22149.3  PMC7202090  32419926.0      cc-by
# 58172       10.12688/f1000research.22149.2         NaN  32419926.0        unk
#
#                                                  abstract publish_time  \
# 74183                                                 NaN         1978
# 137250  Abstract Influenza A viruses isolated from the...   1978-02-28
# 76159                                                 NaN         1978
# 136565  Abstract Using the pH gradient electrophoretic...   1978-05-15
# 78077   Some properties of a strain of mouse hepatitis...         1978
# 13229   Some properties of a strain of mouse hepatitis...   2013-11-14
# 125393  Abstract Pleomorphic fringed particles bearing...   1975-05-10
# 79613   Pleomorphic fringed particles bearing some res...         1975
# 83782   A faecal suspension from a patient with gastro...         1975
# 97482   Abstract A fæcal suspension from a patient wit...   1975-11-15
# 78542   Segemental and focal pathological changes were...         1975
# 117722  Abstract Segmental and focal pathological chan...   1975-12-27
# 81708   Hemagglutinating encephalomyelitis virus of sw...         1977
# 9715    Hemagglutinating encephalomyelitis virus of sw...   1977-02-01
# 6196    From 206I. uriae collected in the seabird colo...         1977
# 77977   From 206 I. uriae collected in the seabird col...         1977
# 75395   The plasma half-life of theophylline was deter...         1978
# 97722   Abstract The plasma half-life of theophylline ...   1978-05-27
# 6285    Utilizing the direct and indirect fluorescent ...         1978
# 70834   Utilizing the direct and indirect fluorescent ...         1978
# 6015    Coronavirus-like particles were detected by el...         1978
# 79722   Coronavirus-like particles were detected by el...         1978
# 83799   Children born into allergic families, with two...         1979
# 128930  Abstract Children born into allergic families,...   1979-04-30
# 119615  Porcine epidemic diarrhoea type II was reprodu...   1978-09-30
# 71378   Porcine epidemic diarrhoea type II was reprodu...         1978
# 67916                                                 NaN         1978
# 130181  Publisher Summary Various aspects of the inter...   1978-12-31
# 74705   Four Bovidae cell lines (BEK-1, MDBK, Bu and E...         1978
# 12188   Four Bovidae cell lines (BEK‐1, MDBK, Bu and E...   2009-04-24
# ...                                                   ...          ...
# 106429                                                NaN   2020-03-11
# 82776                                                 NaN         2020
# 67026                                                 NaN   2020-02-02
# 67025                                                 NaN   2020-03-09
# 75377                                                 NaN         2020
# 69220                                                 NaN         2020
# 67024                                                 NaN   2020-03-12
# 72052                                                 NaN         2020
# 67027                                                 NaN   2020-03-16
# 106029  We prepared the three-dimensional model of the...   2020-02-21
# 55591   We prepared the three-dimensional model of the...         2020
# 81252   First reported in China, the 2019 novel corona...   2020-03-29
# 13683   First reported in China, the 2019 novel corona...   2020-04-25
# 82999   The 2019-novel coronavirus predominantly affec...   2020-03-29
# 13681   The 2019-novel coronavirus predominantly affec...   2020-03-29
# 13682                                                 NaN   2020-03-29
# 80887                                                 NaN   2020-03-29
# 139910  Background: The newly identified coronavirus k...   2020-02-25
# 55879   Background: The newly identified coronavirus k...         2020
# 74164                                                 NaN   2020-04-15
# 13684                                                 NaN   2020-04-25
# 82768   The unexpected pandemic set off by the novel c...   2020-04-27
# 13918   The unexpected pandemic set off by the novel c...   2020-04-30
# 31467   Coronavirus Disease 2019 (COVID-19) threatens ...         2020
# 125835  Coronavirus Disease 2019 (COVID-19) threatens ...   2020-04-30
# 51225   The novel coronavirus disease (COVID-19) was i...         2020
# 105934  The novel coronavirus disease (COVID-19) was i...   2020-04-28
# 57760   A novel coronavirus recently identified in Wuh...         2020
# 117222  A novel coronavirus recently identified in Wuh...   2020-04-27
# 58172   A novel coronavirus recently identified in Wuh...         2020
#
#                                                   authors  \
# 74183   Webster, R G; Yakhno, M; Hinshaw, V S; Bean, W...
# 137250  Webster, Robert G.; Yakhno, Maya; Hinshaw, Vir...
# 76159                    Vrijsen, R; Wouters, M; Boeye, A
# 136565                Vrijsen, R.; Wouters, M.; Boeye, A.
# 78077                     Hirano, N; Hino, S; Fujiwara, K
# 13229       Hirano, Norio; Hino, Shigeo; Fujiwara, Kosaku
# 125393  Mathan, M.; Swaminathan, S. P.; Mathan, V. I.;...
# 79613   Mathan, M; Mathan, V I; Swaminathan, S P; Yesu...
# 83782                              Caul, E O; Clarke, S K
# 97482                         Caul, E. O.; Clarke, S.K.R.
# 78542                             Apostolov, K; Spasic, P
# 117722                Apostolov, K; Spasic, P; Bojanic, N
# 81708   Kaye, H S; Yarbrough, W B; Reed, C J; Harrison...
# 9715    Kaye, Harold S.; Yarbrough, Wilma B.; Reed, Ca...
# 6196         Traavik, T.; Mehl, R.; Kjeldsberg, Elisabeth
# 77977                  Traavik, T; Mehl, R; Kjeldsberg, E
# 75395          Chang, K C; Bell, T D; Lauer, B A; Chai, H
# 97722   Chang, K. C.; Lauer, B. A.; Bell, T. D.; Chai, H.
# 6285          Pedersen, N. C.; Ward, J.; Mengeling, W. L.
# 70834              Pedersen, N C; Ward, J; Mengeling, W L
# 6015                        Pensaert, M. B.; de Bouck, P.
# 79722                          Pensaert, M B; de Bouck, P
# 83799                   Frick, O L; German, D F; Mills, J
# 128930    Frick, Oscar L.; German, Donald F.; Mills, John
# 119615                      Chasey, D.; Cartwright, S. F.
# 71378                          Chasey, D; Cartwright, S F
# 67916                                           Mandel, B
# 130181                                   Mandel, Benjamin
# 74705                 Carleer, J; Pastoret, P P; Ansay, M
# 12188              Carleer, J.; Pastoret, P.P.; Ansay, M.
# ...                                                   ...
# 106429  Peña-Otero, David; Díaz-Pérez, David; de-la-Ro...
# 82776                            Alavi-Moghaddam, Mostafa
# 67026                            Alavi-Moghaddam, Mostafa
# 67025                         Rismanbaf, Ali; Zarei, Sara
# 75377                         Rismanbaf, Ali; Zarei, Sara
# 69220               Ashrafi-Rizi, Hasan; Kazempour, Zahra
# 67024               Ashrafi-rizi, Hasan; Kazempour, Zahra
# 72052          Rashidi Fakari, Farzaneh; Simbar, Masoumeh
# 67027          Rashidi Fakari, Farzaneh; Simbar, Masoumeh
# 106029  Chen, Yu Wai; Yiu, Chin-Pang Bennu; Wong, Kwok...
# 55591   Chen, Yu Wai; Yiu, Chin-Pang Bennu; Wong, Kwok...
# 81252   Ravikumar, Namita; Nallasamy, Karthi; Bansal, ...
# 13683   Ravikumar, Namita; Nallasamy, Karthi; Bansal, ...
# 82999   Sundaram, Manu; Ravikumar, Namita; Bansal, Aru...
# 13681   Sundaram, Manu; Ravikumar, Namita; Bansal, Aru...
# 13682                                   Hanker, Varnit S.
# 80887                                     Shanker, Varnit
# 139910                Hyun-Jung Lee, Chloe; Koohy, Hashem
# 55879                         Lee, Chloe H; Koohy, Hashem
# 74164                                    Mishra, Devendra
# 13684                                    Mishra, Devendra
# 82768   Iyer, Mahalaxmi; Jayaramayya, Kaavya; Subraman...
# 13918   Iyer, Mahalaxmi; Jayaramayya, Kaavya; Subraman...
# 31467                                    Pearce, Joshua M
# 125835                                  Pearce, Joshua M.
# 51225   Robertson, Mary M; Eapen, Valsamma; Rizzo, Ren...
# 105934  Robertson, Mary M.; Eapen, Valsamma; Rizzo, Re...
# 57760   Veljkovic, Veljko; Vergara-Alert, Júlia; Segal...
# 117222  Veljkovic, Veljko; Vergara-Alert, Júlia; Segal...
# 58172   Veljkovic, Veljko; Vergara-Alert, Júlia; Segal...
#
#                                                journal  mag_id  \
# 74183                                         Virology     NaN
# 137250                                        Virology     NaN
# 76159                                         Virology     NaN
# 136565                                        Virology     NaN
# 78077                      Microbiology and immunology     NaN
# 13229                                Microbiol Immunol     NaN
# 125393                                      The Lancet     NaN
# 79613                                           Lancet     NaN
# 83782                                           Lancet     NaN
# 97482                                       The Lancet     NaN
# 78542                                           Lancet     NaN
# 117722                                      The Lancet     NaN
# 81708               The Journal of infectious diseases     NaN
# 9715                                      J Infect Dis     NaN
# 6196                                        Arch Virol     NaN
# 77977                             Archives of virology     NaN
# 75395                                           Lancet     NaN
# 97722                                       The Lancet     NaN
# 6285                                        Arch Virol     NaN
# 70834                             Archives of virology     NaN
# 6015                                        Arch Virol     NaN
# 79722                             Archives of virology     NaN
# 83799   The Journal of allergy and clinical immunology     NaN
# 128930      Journal of Allergy and Clinical Immunology     NaN
# 119615                  Research in Veterinary Science     NaN
# 71378                   Research in veterinary science     NaN
# 67916                       Advances in virus research     NaN
# 130181                      Advances in Virus Research     NaN
# 74705     Animal blood groups and biochemical genetics     NaN
# 12188                  Anim Blood Groups Biochem Genet     NaN
# ...                                                ...     ...
# 106429                               Arch Bronconeumol     NaN
# 82776          Archives of academic emergency medicine     NaN
# 67026                              Arch Acad Emerg Med     NaN
# 67025                              Arch Acad Emerg Med     NaN
# 75377          Archives of academic emergency medicine     NaN
# 69220          Archives of academic emergency medicine     NaN
# 67024                              Arch Acad Emerg Med     NaN
# 72052          Archives of academic emergency medicine     NaN
# 67027                              Arch Acad Emerg Med     NaN
# 106029                                        F1000Res     NaN
# 55591                                    F1000Research     NaN
# 81252                                Indian pediatrics     NaN
# 13683                                   Indian Pediatr     NaN
# 82999                                Indian pediatrics     NaN
# 13681                                   Indian Pediatr     NaN
# 13682                                   Indian Pediatr     NaN
# 80887                                Indian pediatrics     NaN
# 139910                                        F1000Res     NaN
# 55879                                    F1000Research     NaN
# 74164                                Indian pediatrics     NaN
# 13684                                   Indian Pediatr     NaN
# 82768                                      BMB reports     NaN
# 13918                                          BMB Rep     NaN
# 31467                                    F1000Research     NaN
# 125835                                        F1000Res     NaN
# 51225                                    F1000Research     NaN
# 105934                                        F1000Res     NaN
# 57760                                    F1000Research     NaN
# 117222                                        F1000Res     NaN
# 58172                                    F1000Research     NaN
#
#        who_covidence_id arxiv_id  \
# 74183               NaN      NaN
# 137250              NaN      NaN
# 76159               NaN      NaN
# 136565              NaN      NaN
# 78077               NaN      NaN
# 13229               NaN      NaN
# 125393              NaN      NaN
# 79613               NaN      NaN
# 83782               NaN      NaN
# 97482               NaN      NaN
# 78542               NaN      NaN
# 117722              NaN      NaN
# 81708               NaN      NaN
# 9715                NaN      NaN
# 6196                NaN      NaN
# 77977               NaN      NaN
# 75395               NaN      NaN
# 97722               NaN      NaN
# 6285                NaN      NaN
# 70834               NaN      NaN
# 6015                NaN      NaN
# 79722               NaN      NaN
# 83799               NaN      NaN
# 128930              NaN      NaN
# 119615              NaN      NaN
# 71378               NaN      NaN
# 67916               NaN      NaN
# 130181              NaN      NaN
# 74705               NaN      NaN
# 12188               NaN      NaN
# ...                 ...      ...
# 106429            #7893      NaN
# 82776               NaN      NaN
# 67026               NaN      NaN
# 67025               NaN      NaN
# 75377               NaN      NaN
# 69220               NaN      NaN
# 67024               NaN      NaN
# 72052               NaN      NaN
# 67027               NaN      NaN
# 106029            #6373      NaN
# 55591               NaN      NaN
# 81252               NaN      NaN
# 13683               NaN      NaN
# 82999               NaN      NaN
# 13681               NaN      NaN
# 13682               NaN      NaN
# 80887               NaN      NaN
# 139910              NaN      NaN
# 55879               NaN      NaN
# 74164               NaN      NaN
# 13684               NaN      NaN
# 82768               NaN      NaN
# 13918               NaN      NaN
# 31467               NaN      NaN
# 125835              NaN      NaN
# 51225               NaN      NaN
# 105934              NaN      NaN
# 57760               NaN      NaN
# 117222              NaN      NaN
# 58172               NaN      NaN
#
#                                            pdf_json_files  \
# 74183                                                 NaN
# 137250  document_parses/pdf_json/3a2ff3a86c4b06fb35f04...
# 76159                                                 NaN
# 136565  document_parses/pdf_json/5610c53dce08ee3038ead...
# 78077                                                 NaN
# 13229   document_parses/pdf_json/8090cf4603341df535067...
# 125393  document_parses/pdf_json/7747dfcb318bbbf7f9ede...
# 79613                                                 NaN
# 83782                                                 NaN
# 97482   document_parses/pdf_json/71d3406258973d7ea61a6...
# 78542                                                 NaN
# 117722  document_parses/pdf_json/937e8370900dc469c498f...
# 81708                                                 NaN
# 9715    document_parses/pdf_json/f7d6f18903a47360a5faf...
# 6196    document_parses/pdf_json/e9854fb393df6ec24710f...
# 77977                                                 NaN
# 75395                                                 NaN
# 97722   document_parses/pdf_json/3dfa916237b9663c3b6f1...
# 6285    document_parses/pdf_json/34ddcd68407fb141f82a9...
# 70834                                                 NaN
# 6015    document_parses/pdf_json/76a7b0a301baf4436319d...
# 79722                                                 NaN
# 83799                                                 NaN
# 128930  document_parses/pdf_json/b69e28669ea8392a9fa48...
# 119615                                                NaN
# 71378                                                 NaN
# 67916                                                 NaN
# 130181  document_parses/pdf_json/d62517543cff4abed8518...
# 74705                                                 NaN
# 12188   document_parses/pdf_json/da8bd99cf1771969654dc...
# ...                                                   ...
# 106429                                                NaN
# 82776                                                 NaN
# 67026   document_parses/pdf_json/08db45ce51ed0b3b32df8...
# 67025   document_parses/pdf_json/630b2c2b88928c1c6196c...
# 75377                                                 NaN
# 69220                                                 NaN
# 67024   document_parses/pdf_json/aab8259cf3330a0e6d482...
# 72052                                                 NaN
# 67027   document_parses/pdf_json/8bdb3b4c901d599b20118...
# 106029  document_parses/pdf_json/7d5cc36c59956980c1b44...
# 55591                                                 NaN
# 81252                                                 NaN
# 13683   document_parses/pdf_json/88b5c94473256dc08e78e...
# 82999                                                 NaN
# 13681   document_parses/pdf_json/967f4957bd4dd15955a22...
# 13682   document_parses/pdf_json/77626f41463222b88a4da...
# 80887                                                 NaN
# 139910  document_parses/pdf_json/b43c0006285d8b8135a8c...
# 55879                                                 NaN
# 74164                                                 NaN
# 13684                                                 NaN
# 82768                                                 NaN
# 13918   document_parses/pdf_json/587ee276b2cf25da22405...
# 31467                                                 NaN
# 125835  document_parses/pdf_json/4799c0512ecbf9fce0eb0...
# 51225                                                 NaN
# 105934  document_parses/pdf_json/d06675fc813b77846fdc9...
# 57760                                                 NaN
# 117222  document_parses/pdf_json/bbc8b65f5849c2007f27b...
# 58172                                                 NaN
#
#                                       pmc_json_files  \
# 74183                                            NaN
# 137250                                           NaN
# 76159                                            NaN
# 136565                                           NaN
# 78077                                            NaN
# 13229                                            NaN
# 125393                                           NaN
# 79613                                            NaN
# 83782                                            NaN
# 97482                                            NaN
# 78542                                            NaN
# 117722                                           NaN
# 81708                                            NaN
# 9715                                             NaN
# 6196                                             NaN
# 77977                                            NaN
# 75395                                            NaN
# 97722                                            NaN
# 6285                                             NaN
# 70834                                            NaN
# 6015                                             NaN
# 79722                                            NaN
# 83799                                            NaN
# 128930                                           NaN
# 119615                                           NaN
# 71378                                            NaN
# 67916                                            NaN
# 130181                                           NaN
# 74705                                            NaN
# 12188                                            NaN
# ...                                              ...
# 106429  document_parses/pmc_json/PMC7138172.xml.json
# 82776                                            NaN
# 67026   document_parses/pmc_json/PMC7075272.xml.json
# 67025   document_parses/pmc_json/PMC7075271.xml.json
# 75377                                            NaN
# 69220                                            NaN
# 67024   document_parses/pmc_json/PMC7075270.xml.json
# 72052                                            NaN
# 67027   document_parses/pmc_json/PMC7075675.xml.json
# 106029  document_parses/pmc_json/PMC7062204.xml.json
# 55591                                            NaN
# 81252                                            NaN
# 13683                                            NaN
# 82999                                            NaN
# 13681                                            NaN
# 13682                                            NaN
# 80887                                            NaN
# 139910  document_parses/pmc_json/PMC7111504.xml.json
# 55879                                            NaN
# 74164                                            NaN
# 13684                                            NaN
# 82768                                            NaN
# 13918   document_parses/pmc_json/PMC7196187.xml.json
# 31467                                            NaN
# 125835  document_parses/pmc_json/PMC7195895.xml.json
# 51225                                            NaN
# 105934  document_parses/pmc_json/PMC7195896.xml.json
# 57760                                            NaN
# 117222  document_parses/pmc_json/PMC7202090.xml.json
# 58172                                            NaN
#
#                                                       url        s2_id
# 74183          https://www.ncbi.nlm.nih.gov/pubmed/23604/   44623236.0
# 137250  https://api.elsevier.com/content/article/pii/0...   44623236.0
# 76159          https://www.ncbi.nlm.nih.gov/pubmed/27002/   45109889.0
# 136565  https://api.elsevier.com/content/article/pii/0...   45109889.0
# 78077          https://www.ncbi.nlm.nih.gov/pubmed/30881/   43253442.0
# 13229   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 125393  https://www.sciencedirect.com/science/article/...   40081364.0
# 79613          https://www.ncbi.nlm.nih.gov/pubmed/48733/   40081364.0
# 83782          https://www.ncbi.nlm.nih.gov/pubmed/53434/   31630465.0
# 97482   https://api.elsevier.com/content/article/pii/S...   31630465.0
# 78542          https://www.ncbi.nlm.nih.gov/pubmed/54796/    6875877.0
# 117722  https://api.elsevier.com/content/article/pii/S...    6875877.0
# 81708          https://www.ncbi.nlm.nih.gov/pubmed/65439/   37627404.0
# 9715    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 6196    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 77977          https://www.ncbi.nlm.nih.gov/pubmed/72555/   34183742.0
# 75395          https://www.ncbi.nlm.nih.gov/pubmed/77421/    6789466.0
# 97722   https://api.elsevier.com/content/article/pii/S...    6789466.0
# 6285    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 70834          https://www.ncbi.nlm.nih.gov/pubmed/81044/   35701342.0
# 6015    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 79722          https://www.ncbi.nlm.nih.gov/pubmed/83132/   21931969.0
# 83799          https://www.ncbi.nlm.nih.gov/pubmed/85648/   37444126.0
# 128930  https://api.elsevier.com/content/article/pii/0...   37444126.0
# 119615  https://api.elsevier.com/content/article/pii/S...    9408224.0
# 71378         https://www.ncbi.nlm.nih.gov/pubmed/103154/    9408224.0
# 67916         https://www.ncbi.nlm.nih.gov/pubmed/107731/   11068906.0
# 130181  https://api.elsevier.com/content/article/pii/S...   11068906.0
# 74705         https://www.ncbi.nlm.nih.gov/pubmed/109020/   33975522.0
# 12188   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# ...                                                   ...          ...
# 106429  https://doi.org/10.1016/j.arbres.2020.02.009; ...  212729407.0
# 82776       https://www.ncbi.nlm.nih.gov/pubmed/32185368/  212752636.0
# 67026   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 67025   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 75377       https://www.ncbi.nlm.nih.gov/pubmed/32185369/  212753109.0
# 69220       https://www.ncbi.nlm.nih.gov/pubmed/32185370/  212751485.0
# 67024   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 72052       https://www.ncbi.nlm.nih.gov/pubmed/32185371/  212751838.0
# 67027   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 106029  https://www.ncbi.nlm.nih.gov/pubmed/32194944/;...  213398118.0
# 55591   https://doi.org/10.12688/f1000research.22457.2...  216047140.0
# 81252       https://www.ncbi.nlm.nih.gov/pubmed/32238612/  214769074.0
# 13683   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 82999       https://www.ncbi.nlm.nih.gov/pubmed/32238613/  214772136.0
# 13681   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 13682   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 80887       https://www.ncbi.nlm.nih.gov/pubmed/32238614/  214770885.0
# 139910  https://doi.org/10.12688/f1000research.22507.1...  213965735.0
# 55879   https://doi.org/10.12688/f1000research.22507.2...  218632945.0
# 74164       https://www.ncbi.nlm.nih.gov/pubmed/32284470/  215758848.0
# 13684   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 82768       https://www.ncbi.nlm.nih.gov/pubmed/32336317/  216556498.0
# 13918   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 31467   https://doi.org/10.12688/f1000research.22942.1...  214754627.0
# 125835  https://doi.org/10.12688/f1000research.22942.2...  218615222.0
# 51225   https://doi.org/10.12688/f1000research.23275.1...  218648659.0
# 105934  https://doi.org/10.12688/f1000research.23275.2...  216652382.0
# 57760   https://doi.org/10.12688/f1000research.22149.1...  210937065.0
# 117222  https://doi.org/10.12688/f1000research.22149.3...  218629787.0
# 58172   https://doi.org/10.12688/f1000research.22149.2...  214247343.0
#
# [13809 rows x 19 columns]

# %% [markdown]
# This looks like a case where one has a pmcid and the other does not.
#
# I would like to keep the record that has a document parse.
#
# What I am going to do is a bit tricksy.
#
# I sort the dataframe by the parsefile columns. Then I use the duplicated funciton to keep only the first occuring row for each pubmed_id.

# %%
print('Rows before: {}'.format(metadataFrame.shape[0]))
metadataFrame = metadataFrame[~(metadataFrame.sort_values(by=['pdf_json_files', 'pmc_json_files']).duplicated('pubmed_id', keep='last') & metadataFrame['pubmed_id'].notnull())]
print('Rows after: {}'.format(metadataFrame.shape[0]))
# Out:
# Rows before: 138751
# Rows after: 131846

# %% [markdown]
# It eliminated about 7000 rows, matching what number of duplicates we found above.

# %%
metadataFrame['pubmed_id'].dropna().is_unique
# Out:
# True

# %% [markdown]
# And, indeed, pubmed_id is now unique.
#
# Now turning to __s2_id__, which recalling from above had over 13k duplicates.

# %%
metadataFrame[metadataFrame['s2_id'].duplicated(keep=False) & metadataFrame['s2_id'].notnull()].sort_values(by=['s2_id'])
# Out:
#         cord_uid                                                sha  \
# 74070   mo0bhc4s                                                NaN
# 62618   7d7ewkib           adae39fea7d473e279cfffb02a95617e2bd5d65c
# 134234  kllv27bl           aa7094234bc71c19d615cc130ca8c2ef98f543a9
# 85508   34qmk3jx           c1408f066c54987b04e0b997c6b38197f7ad6e3f
# 78579   t92nyi3g                                                NaN
# 64327   auasueaw                                                NaN
# 85421   lo3m6csl           466dc1e5c227ca49cd0fc535dd402f5049b9161b
# 110473  1lojd0xa           a3778f543ef74ff3a0dd90250221b77ee38d7533
# 85420   kto778l5           081fce9252d6f843d2329db65ae188d41bf4c30f
# 95650   5qp7vk0c           65078532d15de7dbfa1931a5e6e6eba317cee5e3
# 82388   pzsezf32                                                NaN
# 79148   595rmnjd                                                NaN
# 64549   ij8og0zc                                                NaN
# 81677   37yutynv                                                NaN
# 129358  ef4xg3q0           8167b94a7c3592a7ec805a977913bd34abb9e199
# 90870   1vtzahag           f3755a2f5ff6b3027b24baecfec0d1e412e1367b
# 120792  nrhq7lqg           1d613eb26d86e376a5f8cb5fdb673b7254110936
# 69005   sib9nnar                                                NaN
# 60691   k1xxz4hc           2d0bb0da2503469a9aa8e94a264c0f37d100ccba
# 92932   34vikc2n           5d7dc504177db9326327e5cc7417bfa045e0f8ad
# 133246  u4z9ijrr           eb84579d04e12484426a03cb27a4799d2c649f04
# 74611   jl2ro0jn                                                NaN
# 74608   31qldfs1                                                NaN
# 74609   9bb88qla                                                NaN
# 74610   77gibaow                                                NaN
# 94591   cfvw4crl           a4de3a6fc3e5ef424dd225e58b16b3c8049d2db5
# 110422  s3t2kdww  dc1e16996462dd1445f21c419b6e40dd0dd84c02; 354a...
# 116136  v9f5jck9                                                NaN
# 74633   jsjqfwcz                                                NaN
# 61320   q59axo1w           6fded905459e05a94147a83debeef8c4754f5263
# ...          ...                                                ...
# 131932  keb71cvg                                                NaN
# 86134   i058rghi                                                NaN
# 133394  rtduw3ly                                                NaN
# 85278   uip9sca1                                                NaN
# 85279   y5oikl9f                                                NaN
# 56481   1b57eqj3                                                NaN
# 95637   tmu9ygc5                                                NaN
# 87175   ttiz1gs4                                                NaN
# 87174   d8w53x4e                                                NaN
# 114921  ns957xmv                                                NaN
# 93050   q2ctl2cu                                                NaN
# 96406   6ld64bbb                                                NaN
# 96407   e68xqpxt                                                NaN
# 93109   bw8v7dr9                                                NaN
# 93108   qplgmh3y                                                NaN
# 95736   25w2ap1k                                                NaN
# 95737   qm3wqtab                                                NaN
# 95738   rrbxoylv                                                NaN
# 85316   9887fsv2                                                NaN
# 85317   gnu2ljp8                                                NaN
# 93082   yb313vfh                                                NaN
# 93081   mhx9bao2                                                NaN
# 85307   t7q3scsi                                                NaN
# 85306   01pghohv                                                NaN
# 87607   gpv5zjfj                                                NaN
# 87606   vqlzxt74                                                NaN
# 42200   fbtp2mgw                                                NaN
# 90198   f9kfczh5                                                NaN
# 96582   0v7ltjf1                                                NaN
# 96583   f67jr495                                                NaN
#
#                       source_x  \
# 74070                  Medline
# 62618                    ArXiv
# 134234  Elsevier; Medline; PMC
# 85508                    ArXiv
# 78579                  Medline
# 64327                    ArXiv
# 85421                    ArXiv
# 110473            Medline; PMC
# 85420                    ArXiv
# 95650                    ArXiv
# 82388                  Medline
# 79148                  Medline
# 64549                    ArXiv
# 81677                  Medline
# 129358           Elsevier; PMC
# 90870                    ArXiv
# 120792            Medline; PMC
# 69005                  Medline
# 60691                    ArXiv
# 92932                    ArXiv
# 133246  Elsevier; Medline; PMC
# 74611                  Medline
# 74608                  Medline
# 74609                  Medline
# 74610                  Medline
# 94591                    ArXiv
# 110422            Medline; PMC
# 116136           Elsevier; PMC
# 74633                  Medline
# 61320                 Elsevier
# ...                        ...
# 131932            Medline; WHO
# 86134                      WHO
# 133394            Medline; WHO
# 85278                      WHO
# 85279                      WHO
# 56481                  Medline
# 95637                      WHO
# 87175                      WHO
# 87174                      WHO
# 114921                PMC; WHO
# 93050                      WHO
# 96406                      WHO
# 96407                      WHO
# 93109                      WHO
# 93108                      WHO
# 95736                      WHO
# 95737                      WHO
# 95738                      WHO
# 85316                      WHO
# 85317                      WHO
# 93082                      WHO
# 93081                      WHO
# 85307                      WHO
# 85306                      WHO
# 87607                      WHO
# 87606                      WHO
# 42200                  Medline
# 90198                      WHO
# 96582                      WHO
# 96583                      WHO
#
#                                                     title  \
# 74070   Modeling the worldwide spread of pandemic infl...
# 62618   Modeling the Worldwide Spread of Pandemic Infl...
# 134234               Evolution of Chinese airport network
# 85508                Evolution of Chinese airport network
# 78579   Semiparametric Relative-risk Regression for In...
# 64327   Semiparametric Relative-risk Regression for In...
# 85421        Inverse Folding of RNA Pseudoknot Structures
# 110473       Inverse folding of RNA pseudoknot structures
# 85420        Inverse folding of RNA pseudoknot structures
# 95650      Eliciting Disease Data from Wikipedia Articles
# 82388     Eliciting Disease Data from Wikipedia Articles.
# 79148   The worldwide air transportation network: Anom...
# 64549   The worldwide air transportation network: Anom...
# 81677   Inpatient disposition classification for the c...
# 129358  Inpatient disposition classification for the c...
# 90870   Bayesian monitoring of emerging infectious dis...
# 120792  Bayesian Monitoring of Emerging Infectious Dis...
# 69005                        Electronic transport in DNA.
# 60691                         Electronic Transport in DNA
# 92932   Controlling nosocomial infection based on stru...
# 133246  Controlling nosocomial infection based on stru...
# 74611                                      News in brief.
# 74608                                      News in brief.
# 74609                                      News in brief.
# 74610                                      News in brief.
# 94591   Asymmetrically interacting spreading dynamics ...
# 110422  Asymmetrically interacting spreading dynamics ...
# 116136       Early evolution and the origin of eukaryotes
# 74633       Early evolution and the origin of eukaryotes.
# 61320   Appendix A Emergency Preparedness, Response & ...
# ...                                                   ...
# 131932  Metatranscriptomic Characterization of COVID-1...
# 86134   Letter: Using Continuous Intracranial Electroe...
# 133394  Letter: Using Continuous Intracranial Electroe...
# 85278   Pediatric anesthetic implications of COVID-19-...
# 85279   Pediatric anesthetic implications of COVID-19-...
# 56481                                                 NaN
# 95637   Asymptomatiske smittebærere av sars-CoV-2 i sy...
# 87175   Severe Acute Respiratory Syndrome Coronavirus ...
# 87174   Severe Acute Respiratory Syndrome Coronavirus ...
# 114921  Coronavirus Disease 2019 and Educational Engag...
# 93050                 COVID-19 and Educational Engagement
# 96406   Die COVID-19 Pandemie und ihre Folgen für die ...
# 96407   Die COVID-19 Pandemie und ihre Folgen für die ...
# 93109                 COVID-19, une approche polyphonique
# 93108                 COVID-19, une approche polyphonique
# 95736   Nosocomial SARS-CoV-2 infection among nurses i...
# 95737   Nosocomial SARS-CoV-2 infection among nurses i...
# 95738   Nosocomial SARS-CoV-2 infection among nurses i...
# 85316   Alfabetización en salud pública ante la emerge...
# 85317   Alfabetización en salud pública ante la emerge...
# 93082   COVID-19, Post-acute Care Preparedness and Nur...
# 93081   COVID-19, Post-acute Care Preparedness and Nur...
# 85307   18F-Fluorodeoxyglucose Uptake in Patient With ...
# 85306   18F-Fluorodeoxyglucose Uptake in Patient With ...
# 87607   [Farmakoterápiás lehetoségek SARS-CoV-2-fertoz...
# 87606   [Farmakoterápiás lehetoségek SARS-CoV-2-fertoz...
# 42200                                                 NaN
# 90198   Pneumothorax: Eine konservative Behandlung ist...
# 96582   Rational hand hygiene during the coronavirus 2...
# 96583   Rational hand hygiene during the coronavirus 2...
#
#                                      doi       pmcid   pubmed_id    license  \
# 74070                                NaN         NaN  17253899.0        unk
# 62618       10.1371/journal.pmed.0040013         NaN         NaN      arxiv
# 134234       10.1016/j.physa.2010.05.042  PMC7127146  32288080.0  els-covid
# 85508                                NaN         NaN         NaN      arxiv
# 78579                                NaN         NaN  26146425.0        unk
# 64327       10.1080/01621459.2014.896807         NaN         NaN      arxiv
# 85421                                NaN         NaN         NaN      arxiv
# 110473            10.1186/1748-7188-5-27  PMC2909241  20573197.0      cc-by
# 85420                                NaN         NaN         NaN      arxiv
# 95650                                NaN         NaN         NaN      arxiv
# 82388                                NaN         NaN  28721308.0        unk
# 79148                                NaN         NaN  15911778.0        unk
# 64549            10.1073/pnas.0407994102         NaN         NaN      arxiv
# 81677                                NaN         NaN  17141705.0        unk
# 129358     10.1016/s0140-6736(06)69808-5  PMC7138047         NaN  els-covid
# 90870                                NaN         NaN         NaN      arxiv
# 120792      10.1371/journal.pone.0152629  PMC4821533  27045370.0      cc-by
# 69005                                NaN         NaN  16040753.0        unk
# 60691        10.1529/biophysj.105.064014         NaN         NaN      arxiv
# 92932                                NaN         NaN         NaN      arxiv
# 133246        10.1016/j.jtbi.2008.07.001  PMC7094152  18647609.0      no-cc
# 74611                                NaN         NaN  27868829.0        unk
# 74608                                NaN         NaN  27700797.0        unk
# 74609                                NaN         NaN  27702091.0        unk
# 74610                                NaN         NaN  27705722.0        unk
# 94591                                NaN         NaN         NaN      arxiv
# 110422                 10.1038/srep05097  PMC4037715  24872257.0      cc-by
# 116136      10.1016/0960-9822(92)90423-8  PMC7172298         NaN  els-covid
# 74633                                NaN         NaN   1822277.0        unk
# 61320   10.1016/b978-012088440-7/50026-4         NaN         NaN  els-covid
# ...                                  ...         ...         ...        ...
# 131932               10.1093/cid/ciaa663         NaN  32463434.0        unk
# 86134                                NaN         NaN         NaN        unk
# 133394            10.1093/neuros/nyaa244         NaN  32463084.0        unk
# 85278                                NaN         NaN         NaN        unk
# 85279                                NaN         NaN         NaN        unk
# 56481            10.4045/tidsskr.20.0316         NaN  32323955.0        unk
# 95637                                NaN         NaN         NaN        unk
# 87175                                NaN         NaN         NaN        unk
# 87174                                NaN         NaN         NaN        unk
# 114921        10.1016/j.joms.2020.04.033  PMC7195013  32371146.0      no-cc
# 93050                                NaN         NaN         NaN        unk
# 96406                                NaN         NaN         NaN        unk
# 96407                                NaN         NaN         NaN        unk
# 93109                                NaN         NaN         NaN        unk
# 93108                                NaN         NaN         NaN        unk
# 95736                                NaN         NaN         NaN        unk
# 95737                                NaN         NaN         NaN        unk
# 95738                                NaN         NaN         NaN        unk
# 85316                                NaN         NaN         NaN        unk
# 85317                                NaN         NaN         NaN        unk
# 93082                                NaN         NaN         NaN        unk
# 93081                                NaN         NaN         NaN        unk
# 85307                                NaN         NaN         NaN        unk
# 85306                                NaN         NaN         NaN        unk
# 87607                                NaN         NaN         NaN        unk
# 87606                                NaN         NaN         NaN        unk
# 42200          10.1024/1661-8157/a003456         NaN  32345179.0        unk
# 90198                                NaN         NaN         NaN        unk
# 96582                                NaN         NaN         NaN        unk
# 96583                                NaN         NaN         NaN        unk
#
#                                                  abstract publish_time  \
# 74070   BACKGROUND The highly pathogenic H5N1 avian in...         2007
# 62618   We present a study of the worldwide spread of ...   2007-01-24
# 134234  Abstract With the rapid development of the eco...   2010-09-15
# 85508   With the rapid development of economy and the ...   2011-01-03
# 78579   This paper introduces semiparametric relative-...         2015
# 64327   This paper introduces semiparametric relative-...   2012-10-17
# 85421   Background: RNA exhibits a variety of structur...   2010-03-10
# 110473  BACKGROUND: RNA exhibits a variety of structur...   2010-06-23
# 85420   Background: RNA exhibits a variety of structur...   2009-05-06
# 95650   Traditional disease surveillance systems suffe...   2015-04-02
# 82388   Traditional disease surveillance systems suffe...         2015
# 79148   We analyze the global structure of the worldwi...         2005
# 64549   We analyze the global structure of the world-w...   2003-12-19
# 81677   BACKGROUND The ability to provide medical care...         2006
# 129358  Summary Background The ability to provide medi...   2006-12-08
# 90870   We define data analyses to monitor a change in...   2016-03-07
# 120792  We define data analyses to monitor a change in...   2016-04-05
# 69005   We study the electronic properties of DNA by w...         2005
# 60691   We study the electronic properties of DNA by w...   2005-04-04
# 92932   Nosocomial infection raises a serious public h...   2008-03-13
# 133246  Nosocomial infection (i.e. infection in health...   2008-10-07
# 74611               A roundup of the latest nursing news.         1998
# 74608               A roundup of the latest nursing news.         1996
# 74609               A roundup of the latest nursing news.         2012
# 74610               A roundup of the latest nursing news.         1993
# 94591   The spread of disease through a physical-conta...   2014-05-08
# 110422  The spread of disease through a physical-conta...   2014-05-29
# 116136                                                NaN   1992-01-31
# 74633   Our understanding of evolutionary relationship...         1991
# 61320                                             Unknown   2006-12-31
# ...                                                   ...          ...
# 131932  BACKGROUND: The recent identification of a nov...         2020
# 86134   The COVID-19 healthcare crisis and the resulti...         2020
# 133394                                                NaN         2020
# 85278   Pediatric anesthetists have an important role ...         2020
# 85279   Pediatric anesthetists have an important role ...         2020
# 56481                                                 NaN   2020-04-23
# 95637                                                 NaN         2020
# 87175   Little or nothing is known about the correlati...         2020
# 87174   Little or nothing is known about the correlati...         2020
# 114921                                                NaN   2020-04-28
# 93050                                                 NaN         2020
# 96406   The first case of a SARS-Cov-2 virus infection...         2020
# 96407   The first case of a SARS-Cov-2 virus infection...         2020
# 93109                                                 NaN         2020
# 93108   Au moment où nous avons entendu les premiers r...         2020
# 95736                                                 NaN         2020
# 95737                                                 NaN         2020
# 95738                                                 NaN         2020
# 85316   Health literacy is the process of obtaining kn...         2020
# 85317   Health literacy is the process of obtaining kn...         2020
# 93082                                                 NaN         2020
# 93081                                                 NaN         2020
# 85307                                                 NaN         2020
# 85306                                                 NaN         2020
# 87607   There is currently no proven effective therapy...         2020
# 87606   There is currently no proven effective therapy...         2020
# 42200                                                 NaN   2020-04-01
# 90198                                                 NaN         2020
# 96582                                                 NaN         2020
# 96583                                                 NaN         2020
#
#                                                   authors  \
# 74070   Colizza, Vittoria; Barrat, Alain; Barthelemy, ...
# 62618   Colizza, Vittoria; Barrat, Alain; Barthelemy, ...
# 134234  Zhang, Jun; Cao, Xian-Bin; Du, Wen-Bo; Cai, Ka...
# 85508   Zhang, Jun; Cao, Xian-Bin; Du, Wen-Bo; Cai, Ka...
# 78579                                         Kenah, Eben
# 64327                                         Kenah, Eben
# 85421   Gao, James Z.M.; Li, Linda Y.M.; Reidys, Chris...
# 110473   Gao, James ZM; Li, Linda YM; Reidys, Christian M
# 85420   Gao, James Z. M.; Li, Linda Y. M.; Reidys, Chr...
# 95650   Fairchild, Geoffrey; Silva, Lalindra De; Valle...
# 82388   Fairchild, Geoffrey; Del Valle, Sara Y; De Sil...
# 79148    Guimerà, R; Mossa, S; Turtschi, A; Amaral, L A N
# 64549   Guimera, R.; Mossa, S.; Turtschi, A.; Amaral, ...
# 81677   Kelen, Gabor D; Kraus, Chadd K; McCarthy, Meli...
# 129358  Kelen, Gabor D; Kraus, Chadd K; McCarthy, Meli...
# 90870                    Polyakov, Pavel; Breban, Romulus
# 120792                   Polyakov, Pavel; Breban, Romulus
# 69005   Klotsa, Daphne; Römer, Rudolf A; Turner, Matth...
# 60691   Klotsa, Daphne; Roemer, Rudolf A.; Turner, Mat...
# 92932                           Ueno, Taro; Masuda, Naoki
# 133246                          Ueno, Taro; Masuda, Naoki
# 74611                                                 NaN
# 74608                                                 NaN
# 74609                                                 NaN
# 74610                                                 NaN
# 94591   Wang, Wei; Tang, Ming; Yang, Hui; Do, Younghae...
# 110422  Wang, Wei; Tang, Ming; Yang, Hui; Younghae Do;...
# 116136                                  Sogin, Mitchell L
# 74633                                          Sogin, M L
# 61320   Belmont, Elisabeth; Fried, Bruce Merlin; Gonen...
# ...                                                   ...
# 131932  Zhang, Haocheng; Ai, Jing-Wen; Yang, Wenjiao; ...
# 86134         Emily A Mirro, B. S. Casey H. Halpern M. D.
# 133394                 Mirro, Emily A.; Halpern, Casey H.
# 85278    Lee-Archer, Paul; von Ungern-Sternberg, Britta S
# 85279    Lee-Archer, Paul; von Ungern-Sternberg, Britta S
# 56481   Hordnes, Knut; Løland, Karina Koller; Bovim, Egil
# 95637   Hordnes, Knut; Løland, Karina Koller; Bovim, Egil
# 87175   Bozzani, Antonio; Arici, Vittorio; Franciscone...
# 87174   Bozzani, Antonio; Arici, Vittorio; Franciscone...
# 114921                                   Carlson, Eric R.
# 93050                                     Carlson, Eric R
# 96406   Giunta, Riccardo E; Frank, Konstantin; Moellho...
# 96407   Giunta, Riccardo E; Frank, Konstantin; Moellho...
# 93109                              Blum, S.; Gavillet, M.
# 93108                              Blum, S.; Gavillet, M.
# 95736   Sun, Huimin; Lu, Mengxin; Chen, Song; Cheng, Z...
# 95737   Sun, Huimin; Lu, Mengxin; Chen, Song; Cheng, Z...
# 95738   Sun, Huimin; Lu, Mengxin; Chen, Song; Cheng, Z...
# 85316       Lazcano-Ponce, Eduardo; Alpuche-Aranda, Celia
# 85317       Lazcano-Ponce, Eduardo; Alpuche-Aranda, Celia
# 93082                                    Gurwitz, Jerry H
# 93081                                    Gurwitz, Jerry H
# 85307   Polverari, Giulia; Arena, Vincenzo; Ceci, Fran...
# 85306   Polverari, Giulia; Arena, Vincenzo; Ceci, Fran...
# 87607   Fábián, Ákos; László, István; Juhász, Marianna...
# 87606   Fábián, Ákos; László, István; Juhász, Marianna...
# 42200                                     Steurer, Johann
# 90198                                     Steurer, Johann
# 96582          Cavanagh, Gregory; Wambier, Carlos Gustavo
# 96583          Cavanagh, Gregory; Wambier, Carlos Gustavo
#
#                                                   journal  mag_id  \
# 74070                                       PLoS medicine     NaN
# 62618                                                 NaN     NaN
# 134234  Physica A: Statistical Mechanics and its Appli...     NaN
# 85508                                                 NaN     NaN
# 78579     Journal of the American Statistical Association     NaN
# 64327                                                 NaN     NaN
# 85421                                                 NaN     NaN
# 110473                                Algorithms Mol Biol     NaN
# 85420                                                 NaN     NaN
# 95650                                                 NaN     NaN
# 82388   Proceedings of the ... International AAAI Conf...     NaN
# 79148   Proceedings of the National Academy of Science...     NaN
# 64549                                                 NaN     NaN
# 81677                                              Lancet     NaN
# 129358                                         The Lancet     NaN
# 90870                                                 NaN     NaN
# 120792                                           PLoS One     NaN
# 69005                                 Biophysical journal     NaN
# 60691                                                 NaN     NaN
# 92932                                                 NaN     NaN
# 133246                                       J Theor Biol     NaN
# 74611   Nursing standard (Royal College of Nursing (Gr...     NaN
# 74608   Nursing standard (Royal College of Nursing (Gr...     NaN
# 74609                   Nursing children and young people     NaN
# 74610   Nursing standard (Royal College of Nursing (Gr...     NaN
# 94591                                                 NaN     NaN
# 110422                                            Sci Rep     NaN
# 116136                                    Current Biology     NaN
# 74633           Current opinion in genetics & development     NaN
# 61320                                                 NaN     NaN
# ...                                                   ...     ...
# 131932  Clinical infectious diseases : an official pub...     NaN
# 86134                                        Neurosurgery     NaN
# 133394                                       Neurosurgery     NaN
# 85278                                   Paediatr. anaesth     NaN
# 85279                                   Paediatr. anaesth     NaN
# 56481   Tidsskrift for den Norske laegeforening : tids...     NaN
# 95637                           Tidsskr. nor. laegeforen.     NaN
# 87175                                     Ann. vasc. surg     NaN
# 87174                                     Ann. vasc. surg     NaN
# 114921                             J Oral Maxillofac Surg     NaN
# 93050                            J. oral maxillofac. surg     NaN
# 96406                    Handchir. mikrochir. plast. chir     NaN
# 96407                    Handchir. mikrochir. plast. chir     NaN
# 93109                               Revue medicale suisse     NaN
# 93108                               Revue medicale suisse     NaN
# 95736                                            J Infect     NaN
# 95737                                            J Infect     NaN
# 95738                                            J Infect     NaN
# 85316                                   Salud publica Mex     NaN
# 85317                                   Salud publica Mex     NaN
# 93082                                 J. am. geriatr. soc     NaN
# 93081                                 J. am. geriatr. soc     NaN
# 85307                                    J. thorac. oncol     NaN
# 85306                                    J. thorac. oncol     NaN
# 87607                                           Orv Hetil     NaN
# 87606                                           Orv Hetil     NaN
# 42200                                              Praxis     NaN
# 90198                                  Praxis (Bern 1994)     NaN
# 96582                                  J Am Acad Dermatol     NaN
# 96583                                  J Am Acad Dermatol     NaN
#
#        who_covidence_id          arxiv_id  \
# 74070               NaN               NaN
# 62618               NaN     q-bio/0701038
# 134234              NaN               NaN
# 85508               NaN         1101.0656
# 78579               NaN               NaN
# 64327               NaN         1210.4630
# 85421               NaN         1003.2015
# 110473              NaN               NaN
# 85420               NaN         0905.0733
# 95650               NaN        1504.00657
# 82388               NaN               NaN
# 79148               NaN               NaN
# 64549               NaN  cond-mat/0312535
# 81677               NaN               NaN
# 129358              NaN               NaN
# 90870               NaN        1603.02265
# 120792              NaN               NaN
# 69005               NaN               NaN
# 60691               NaN     q-bio/0504004
# 92932               NaN         0803.1879
# 133246              NaN               NaN
# 74611               NaN               NaN
# 74608               NaN               NaN
# 74609               NaN               NaN
# 74610               NaN               NaN
# 94591               NaN         1405.1905
# 110422              NaN               NaN
# 116136              NaN               NaN
# 74633               NaN               NaN
# 61320               NaN               NaN
# ...                 ...               ...
# 131932          #401831               NaN
# 86134           #401710               NaN
# 133394          #401318               NaN
# 85278            #71919               NaN
# 85279         #32306440               NaN
# 56481               NaN               NaN
# 95637           #117128               NaN
# 87175           #197230               NaN
# 87174         #32335249               NaN
# 114921          #133238               NaN
# 93050         #32371146               NaN
# 96406         #32344444               NaN
# 96407           #155354               NaN
# 93109           #399038               NaN
# 93108           #208975               NaN
# 95736            #46149               NaN
# 95737         #32283150               NaN
# 95738            #46148               NaN
# 85316            #95174               NaN
# 85317            #71873               NaN
# 93082            #96624               NaN
# 93081         #32315075               NaN
# 85307         #32243920               NaN
# 85306           #143404               NaN
# 87607         #32324361               NaN
# 87606           #259868               NaN
# 42200               NaN               NaN
# 90198           #208303               NaN
# 96582            #31213               NaN
# 96583           #142081               NaN
#
#                                            pdf_json_files  \
# 74070                                                 NaN
# 62618   document_parses/pdf_json/adae39fea7d473e279cff...
# 134234  document_parses/pdf_json/aa7094234bc71c19d615c...
# 85508   document_parses/pdf_json/c1408f066c54987b04e0b...
# 78579                                                 NaN
# 64327                                                 NaN
# 85421   document_parses/pdf_json/466dc1e5c227ca49cd0fc...
# 110473  document_parses/pdf_json/a3778f543ef74ff3a0dd9...
# 85420   document_parses/pdf_json/081fce9252d6f843d2329...
# 95650   document_parses/pdf_json/65078532d15de7dbfa193...
# 82388                                                 NaN
# 79148                                                 NaN
# 64549                                                 NaN
# 81677                                                 NaN
# 129358  document_parses/pdf_json/8167b94a7c3592a7ec805...
# 90870   document_parses/pdf_json/f3755a2f5ff6b3027b24b...
# 120792  document_parses/pdf_json/1d613eb26d86e376a5f8c...
# 69005                                                 NaN
# 60691   document_parses/pdf_json/2d0bb0da2503469a9aa8e...
# 92932   document_parses/pdf_json/5d7dc504177db9326327e...
# 133246  document_parses/pdf_json/eb84579d04e12484426a0...
# 74611                                                 NaN
# 74608                                                 NaN
# 74609                                                 NaN
# 74610                                                 NaN
# 94591   document_parses/pdf_json/a4de3a6fc3e5ef424dd22...
# 110422  document_parses/pdf_json/dc1e16996462dd1445f21...
# 116136                                                NaN
# 74633                                                 NaN
# 61320   document_parses/pdf_json/6fded905459e05a94147a...
# ...                                                   ...
# 131932                                                NaN
# 86134                                                 NaN
# 133394                                                NaN
# 85278                                                 NaN
# 85279                                                 NaN
# 56481                                                 NaN
# 95637                                                 NaN
# 87175                                                 NaN
# 87174                                                 NaN
# 114921                                                NaN
# 93050                                                 NaN
# 96406                                                 NaN
# 96407                                                 NaN
# 93109                                                 NaN
# 93108                                                 NaN
# 95736                                                 NaN
# 95737                                                 NaN
# 95738                                                 NaN
# 85316                                                 NaN
# 85317                                                 NaN
# 93082                                                 NaN
# 93081                                                 NaN
# 85307                                                 NaN
# 85306                                                 NaN
# 87607                                                 NaN
# 87606                                                 NaN
# 42200                                                 NaN
# 90198                                                 NaN
# 96582                                                 NaN
# 96583                                                 NaN
#
#                                       pmc_json_files  \
# 74070                                            NaN
# 62618                                            NaN
# 134234  document_parses/pmc_json/PMC7127146.xml.json
# 85508                                            NaN
# 78579                                            NaN
# 64327                                            NaN
# 85421                                            NaN
# 110473  document_parses/pmc_json/PMC2909241.xml.json
# 85420                                            NaN
# 95650                                            NaN
# 82388                                            NaN
# 79148                                            NaN
# 64549                                            NaN
# 81677                                            NaN
# 129358  document_parses/pmc_json/PMC7138047.xml.json
# 90870                                            NaN
# 120792  document_parses/pmc_json/PMC4821533.xml.json
# 69005                                            NaN
# 60691                                            NaN
# 92932                                            NaN
# 133246  document_parses/pmc_json/PMC7094152.xml.json
# 74611                                            NaN
# 74608                                            NaN
# 74609                                            NaN
# 74610                                            NaN
# 94591                                            NaN
# 110422  document_parses/pmc_json/PMC4037715.xml.json
# 116136                                           NaN
# 74633                                            NaN
# 61320                                            NaN
# ...                                              ...
# 131932                                           NaN
# 86134                                            NaN
# 133394                                           NaN
# 85278                                            NaN
# 85279                                            NaN
# 56481                                            NaN
# 95637                                            NaN
# 87175                                            NaN
# 87174                                            NaN
# 114921  document_parses/pmc_json/PMC7195013.xml.json
# 93050                                            NaN
# 96406                                            NaN
# 96407                                            NaN
# 93109                                            NaN
# 93108                                            NaN
# 95736                                            NaN
# 95737                                            NaN
# 95738                                            NaN
# 85316                                            NaN
# 85317                                            NaN
# 93082                                            NaN
# 93081                                            NaN
# 85307                                            NaN
# 85306                                            NaN
# 87607                                            NaN
# 87606                                            NaN
# 42200                                            NaN
# 90198                                            NaN
# 96582                                            NaN
# 96583                                            NaN
#
#                                                       url        s2_id
# 74070       https://www.ncbi.nlm.nih.gov/pubmed/17253899/      72538.0
# 62618           https://arxiv.org/pdf/q-bio/0701038v1.pdf      72538.0
# 134234  https://www.sciencedirect.com/science/article/...      75478.0
# 85508               https://arxiv.org/pdf/1101.0656v1.pdf      75478.0
# 78579       https://www.ncbi.nlm.nih.gov/pubmed/26146425/     357136.0
# 64327               https://arxiv.org/pdf/1210.4630v1.pdf     357136.0
# 85421               https://arxiv.org/pdf/1003.2015v1.pdf     389081.0
# 110473  https://doi.org/10.1186/1748-7188-5-27; https:...     389081.0
# 85420               https://arxiv.org/pdf/0905.0733v2.pdf     389081.0
# 95650              https://arxiv.org/pdf/1504.00657v3.pdf    1254084.0
# 82388       https://www.ncbi.nlm.nih.gov/pubmed/28721308/    1254084.0
# 79148       https://www.ncbi.nlm.nih.gov/pubmed/15911778/    1281296.0
# 64549        https://arxiv.org/pdf/cond-mat/0312535v2.pdf    1281296.0
# 81677       https://www.ncbi.nlm.nih.gov/pubmed/17141705/    1581918.0
# 129358  https://api.elsevier.com/content/article/pii/S...    1581918.0
# 90870              https://arxiv.org/pdf/1603.02265v1.pdf    1903907.0
# 120792  https://www.ncbi.nlm.nih.gov/pubmed/27045370/;...    1903907.0
# 69005       https://www.ncbi.nlm.nih.gov/pubmed/16040753/    2010436.0
# 60691           https://arxiv.org/pdf/q-bio/0504004v1.pdf    2010436.0
# 92932               https://arxiv.org/pdf/0803.1879v2.pdf    2036366.0
# 133246  https://www.sciencedirect.com/science/article/...    2036366.0
# 74611       https://www.ncbi.nlm.nih.gov/pubmed/27868829/    2523515.0
# 74608       https://www.ncbi.nlm.nih.gov/pubmed/27700797/    2523515.0
# 74609       https://www.ncbi.nlm.nih.gov/pubmed/27702091/    2523515.0
# 74610       https://www.ncbi.nlm.nih.gov/pubmed/27705722/    2523515.0
# 94591               https://arxiv.org/pdf/1405.1905v1.pdf    2537264.0
# 110422  https://doi.org/10.1038/srep05097; https://www...    2537264.0
# 116136  https://api.elsevier.com/content/article/pii/0...    3055886.0
# 74633        https://www.ncbi.nlm.nih.gov/pubmed/1822277/    3055886.0
# 61320   https://api.elsevier.com/content/article/pii/B...    3113386.0
# ...                                                   ...          ...
# 131932  https://www.ncbi.nlm.nih.gov/pubmed/32463434/;...  218976519.0
# 86134                                                 NaN  218976631.0
# 133394  https://www.ncbi.nlm.nih.gov/pubmed/32463084/;...  218976631.0
# 85278                                                 NaN  218980247.0
# 85279                                                 NaN  218980247.0
# 56481   https://doi.org/10.4045/tidsskr.20.0316; https...  218992914.0
# 95637                                                 NaN  218992914.0
# 87175                                                 NaN  218993928.0
# 87174                                                 NaN  218993928.0
# 114921         https://doi.org/10.1016/j.joms.2020.04.033  219024061.0
# 93050                                                 NaN  219024061.0
# 96406                                                 NaN  219024746.0
# 96407                                                 NaN  219024746.0
# 93109                                                 NaN  219062544.0
# 93108                                                 NaN  219062544.0
# 95736                                                 NaN  219076241.0
# 95737                                                 NaN  219076241.0
# 95738                                                 NaN  219076241.0
# 85316                                                 NaN  219085692.0
# 85317                                                 NaN  219085692.0
# 93082                                                 NaN  219089207.0
# 93081                                                 NaN  219089207.0
# 85307                                                 NaN  219109629.0
# 85306                                                 NaN  219109629.0
# 87607                                                 NaN  219110895.0
# 87606                                                 NaN  219110895.0
# 42200   https://doi.org/10.1024/1661-8157/a003456; htt...  219110955.0
# 90198                                                 NaN  219110955.0
# 96582                                                 NaN  219115348.0
# 96583                                                 NaN  219115348.0
#
# [20975 rows x 19 columns]

# %% [markdown]
# The discrepancies here seem to arise from cases where Semantic Scholar has (seemingly correctly) grouped a published paper with its ArXiv version but the abstract differed between the two versions. This is really some tricky territory. My inclination at the moment is to leave this as is, and circle back to it if necessary.
#
# Lets finish by just checking again all the columns that should be single valued and unique.

# %%
for Column in SingleValued_and_Unique:
    print(Column, metadataFrame[Column].dropna().is_unique)
# Out:
# cord_uid True
# pmcid True
# pubmed_id True
# mag_id True
# who_covidence_id True
# arxiv_id True
# url True
# s2_id False

# %% [markdown]
# So other than s2_id all are now unique.

# %%
metadataFrame.shape[0]
# Out:
# 131846

# %% [markdown]
# And have arrived at 131,846 records.

# %% [markdown]
# <a id='Single_valued'></a>
# ### Single valued
#
# Based on investigations to the this point, it looks like they are denoting multiple values within a column via a semicolon (;). Thus it is likely best to quickly check to make sure the columns we inferred to be inferred to be single valued are actually so.

# %%
SingleValued = ['title', 'doi', 'license', 'publish_time']

# %%
for Column in SingleValued:
    print(Column, metadataFrame[Column].str.contains(';').fillna(False).sum())
# Out:
# title 575
# doi 25
# license 0
# publish_time 0

# %% [markdown]
# license and publish_time are single valued.
#
# doi has a few cases that are not, will have a look but likely ok to just leave as a single valued variable and deal with the corner case if we end up working with doi.
#
# title need to be investigated.

# %%
metadataFrame[metadataFrame['doi'].str.contains(';').fillna(False)]
# Out:
#         cord_uid                                       sha       source_x  \
# 8394    no7mnxtj  a1bf6ada1b47e286db751f32fb6d74a6a41328b4            PMC
# 12259   djxoiytq  64066db1148876bb85f1c65e2acfab11dfd89c11            PMC
# 12262   lreguu45  01207321329715e944d0ae2cba853b919340ad91            PMC
# 12422   23cdi61w  11c686b3de7f984cb5e82860014a23050d7cf740            PMC
# 12435   2cv7cs48  a0e60329e1527b513e6bfcc6f5da46c7bbf19bf8            PMC
# 12444   cuy6dihq  279b4d3afbe2142f1ca72d7536b78b042ce35529            PMC
# 12451   khxb15wp  c5bcf6c3957245b4a27e4cadb72c7f1181fc1a32            PMC
# 12456   0mw8x66n  e374c4e801f0bd2473b833d5aa9763fa9a1fcec0            PMC
# 12563   2rdtj01s  dc0c47c12c9fddc79adc3c14760cae6dd914eaa2            PMC
# 13103   d5eo1jv7  bd0283a74bd15c8b481ce8dc2d72d699cdcc7c86            PMC
# 13106   eeq50vi0  c06d625e79097828798cc8b814c9ab9f2581b1e8            PMC
# 13388   7nusffwg  660c54e43898f9b7c472f90d2858bcb19b2768bb            PMC
# 13393   xxwc9ysp  6a8accf080085c9b9d421dfef3fbfd4d51e660dd            PMC
# 13720   v862bw1o                                       NaN            PMC
# 16286   lzj56lm6                                       NaN            PMC
# 16287   1gf1l0to                                       NaN            PMC
# 19979   2v01j64f                                       NaN            PMC
# 23645   vgfv5pi4  5b28b06755683f53adeb5b5181903d5e45f577fb            PMC
# 23699   orjzvvau  4a7d736768e4bd25568077815a7254dad2b9e6a1            PMC
# 24066   d5pl7ie6  21c939104a13c465e95875671a281bb4d6506caa            PMC
# 53317   gcarnb6w                                       NaN        Medline
# 103791  2f5w411y  a9c2a7e2afbc82f6e729fd078eeb336946227116  Elsevier; PMC
# 110163  bropr0dy  2f185371b60849f8846c0b57934ae863ea7274ba   Medline; PMC
# 111937  ybhcwln6                                       NaN   Medline; PMC
# 125331  gihp7ulm  042a57ce54d353b67f9faff39f7829c45dc7b101   Medline; PMC
#
#                                                     title  \
# 8394    Generation of an immortal differentiated lung ...
# 12259   Molecular mimicry and multiple sclerosis: Dege...
# 12262   Increased serum levels of cartilage oligomeric...
# 12422   Electron microscopic observations on structure...
# 12435   Tubular complexes of endoplasmic reticulum in ...
# 12444   Kaposi's sarcoma in renal transplant recipient...
# 12451   Morphologic study of virus‐like particles in a...
# 12456                Introduction to virus‐caused cancers
# 12563   The role of ecological theory and practice in ...
# 13103   A Review of the Magnetic Relaxation and Its Ap...
# 13106   Factors Influencing the Size Structure of Broo...
# 13388   Classification of Texas Reservoirs in Relation...
# 13393   Seasonal Diversity, Abundance, and Distributio...
# 13720   Pediatric Patient Safety in the Ambulatory Set...
# 16286          Invasive Species: The Search for Solutions
# 16287   Global Zoonotic Disease Surveillance: An Emerg...
# 19979                 Atlas of Travel Medicine and Health
# 23645   SIMULATING NEW ZEALAND FOREST DYNAMICS WITH A ...
# 23699   Conservation Genetics and the Management of En...
# 24066   Water regimes and littoral plants in four weir...
# 53317   Polyvalent Interactions in Biological Systems:...
# 103791  Exotic Viral Diseases: A Global Guide Stephen ...
# 110163  Guidelines for managing lesser prairie‐chicken...
# 111937                                         Dispatches
# 125331  HIGH-FLOW NASAL CANNULA POST-TRACHEAL EXTUBATI...
#
#                                                       doi       pmcid  \
# 8394      10.1290/1071-2690(2000)036<0374:goaidl>2.0.co;2  PMC7101677
# 12259   10.1002/1531-8249(199905)45:5<559::aid-ana3>3....  PMC7159663
# 12262   10.1002/1529-0131(199803)41:3<544::aid-art21>3...  PMC7159671
# 12422   10.1002/1097-0142(197106)27:6<1449::aid-cncr28...  PMC7162171
# 12435   10.1002/1097-0142(19820415)49:8<1629::aid-cncr...  PMC7162261
# 12444   10.1002/1097-0142(19840115)53:2<258::aid-cncr2...  PMC7162315
# 12451   10.1002/1097-0142(197604)37:4<1718::aid-cncr28...  PMC7162349
# 12456   10.1002/1097-0142(197410)34:8+<1347::aid-cncr2...  PMC7162371
# 12563        10.1890/1540-9295(2006)4[533:troeta]2.0.co;2  PMC7164082
# 13103   10.1002/1521-396x(200010)181:2<233::aid-pssa23...  PMC7167824
# 13106     10.1577/1548-8675(1992)012<0109:fitsso>2.3.co;2  PMC7167839
# 13388     10.1577/1548-8659(1990)119<0511:cotrir>2.3.co;2  PMC7169796
# 13393      10.1577/1548-8659(1983)112<247:sdaado>2.0.co;2  PMC7169813
# 13720     10.1367/1539-4409(2004)004<0047:ppsita>2.0.co;2  PMC7185770
# 16286     10.1641/0006-3568(2004)054[0615:istsfs]2.0.co;2  PMC7110398
# 16287     10.1641/0006-3568(2004)054[0982:gzdsae]2.0.co;2  PMC7110399
# 19979         10.1580/1080-6032(2004)015[0154:br]2.0.co;2  PMC7128711
# 23645     10.1890/1051-0761(2000)010[0115:snzfdw]2.0.co;2  PMC7163527
# 23699     10.1577/1548-8446(1986)011<0014:cgatmo>2.0.co;2  PMC7164036
# 24066   10.1002/1099-1646(200009/10)16:5<445::aid-rrr5...  PMC7169220
# 53317   10.1002/(sici)1521-3773(19981102)37:20<2754::a...         NaN
# 103791      10.1580/1080-6032(2004)15[231:evdagg]2.0.co;2  PMC7129477
# 110163       10.2193/0091-7648(2004)32[69:gfmlpp]2.0.co;2  PMC7169742
# 111937         10.1890/1540-9295(2003)001[0284:d]2.0.co;2  PMC7164002
# 125331                 10.1590/1984-0462/;2018;36;3;00010  PMC6202903
#
#          pubmed_id    license  \
# 8394    10949996.0      no-cc
# 12259   10319877.0      no-cc
# 12262    9506583.0      no-cc
# 12422    5282620.0      no-cc
# 12435    6978174.0      no-cc
# 12444    6418373.0      no-cc
# 12451     177173.0      no-cc
# 12456    4422736.0      no-cc
# 12563   32313512.0      no-cc
# 13103   32327813.0      no-cc
# 13106   32327869.0      no-cc
# 13388   32327761.0      no-cc
# 13393   32327760.0      no-cc
# 13720   14731091.0      no-cc
# 16286          NaN      no-cc
# 16287          NaN      no-cc
# 19979          NaN      no-cc
# 23645          NaN      no-cc
# 23699          NaN      no-cc
# 24066          NaN      no-cc
# 53317   29711117.0        unk
# 103791         NaN  els-covid
# 110163  32327860.0      no-cc
# 111937  32313509.0      no-cc
# 125331  29995143.0      cc-by
#
#                                                  abstract publish_time  \
# 8394    This paper describes a new fully differentiate...         2000
# 12259   Various mechanisms have been proposed for the ...   2001-06-01
# 12262   OBJECTIVE: To investigate the utility of serum...   2004-05-28
# 12422   Human tumors of mesenchymal origin contain cyt...   2006-06-27
# 12435   Distinctive intracytoplasmic tubular complexes...   2006-06-28
# 12444   Tissues from four cases of Kaposi's sarcoma de...   2006-06-29
# 12451   Virus‐like particles, grouped in clusters not ...   2006-06-28
# 12456   Members of four different groups of animal vir...   2006-06-28
# 12563   The fight against global poverty has gained mo...   2006-12-01
# 13103   This review presents a comprehensive survey on...   2000-10-26
# 13106   We used discriminant models to identify relati...   2011-01-09
# 13388   I used cluster analysis to examine association...   2011-01-09
# 13393   The ichthyoplanktonic community of Tamiahua La...   2012-01-23
# 13720                                                 NaN   2005-12-12
# 16286                                                 NaN   2004-07-01
# 16287                                                 NaN   2004-11-01
# 19979                                                 NaN   2010-02-23
# 23645   A generalized computer model of forest growth ...   2000-02-01
# 23699   The emerging field of endangered fishes manage...   2011-01-09
# 24066   The composition and distribution of littoral v...   2000-09-27
# 53317   Found throughout biology, polyvalent interacti...         1998
# 103791                                            Unknown   2004-09-30
# 110163  Lesser prairie‐chicken (Tympanuchus pallidicin...   2010-12-13
# 111937                                                NaN   2003-08-01
# 125331  OBJECTIVE: To report a case of a patient who r...         2018
#
#                                                   authors  \
# 8394    deMello, Daphne E.; Mahmoud, Sohir; Padfield, ...
# 12259   Gran, Bruno; Hemmer, Bernhard; Vergelli, Marco...
# 12262   Vingsbo‐Lundberg, Carina; Saxne, Tore; Olsson,...
# 12422   Györkey, Ferenc; Sinkovics, Joseph G.; Györkey...
# 12435   Chu, Helen; Foucar, Kathy; Barlogie, Barthel; ...
# 12444   Akhtar, Mohammed; Bunuan, Hernando; Ali, Moham...
# 12451                   Foa, C.; Foa, J.; Carcassonne, Y.
# 12456                                    Temin, Howard M.
# 12563   DeClerck, Fabrice; Ingram, Jane C.; Rumbaitis ...
# 13103   Blythe, H.J.; Kronmüller, H.; Seeger, A.; Walz...
# 13106              Larscheid, Joseph G.; Hubert, Wayne A.
# 13388                                  Dolman, William B.
# 13393   Flores‐Coto, César; Barba‐Torres, Francisco; S...
# 13720   Miller, Marlene R.; Pronovost, Peter J.; Burst...
# 16286                                   Dybas, Cheryl Lyn
# 16287                                   Dudley, Joseph P.
# 19979                                    Saucier, John R.
# 23645             Hall, Graeme M. J.; Hollinger, David Y.
# 23699                                      Meffe, Gary K.
# 24066   Blanch, Stuart J.; Walker, Keith F.; Ganf, Geo...
# 53317   Mammen, Mathai; Choi, Seok-Ki; Whitesides, Geo...
# 103791                           Van Tilburg, Christopher
# 110163  Hagen, Christian A.; Jamison, Brent E.; Giesen...
# 111937                                                NaN
# 125331  Colleti, José; Longui, Tâmara Eleamen; de Carv...
#
#                                     journal  mag_id who_covidence_id arxiv_id  \
# 8394            In Vitro Cell Dev Biol Anim     NaN              NaN      NaN
# 12259                            Ann Neurol     NaN              NaN      NaN
# 12262                       Arthritis Rheum     NaN              NaN      NaN
# 12422                                Cancer     NaN              NaN      NaN
# 12435                                Cancer     NaN              NaN      NaN
# 12444                                Cancer     NaN              NaN      NaN
# 12451                                Cancer     NaN              NaN      NaN
# 12456                                Cancer     NaN              NaN      NaN
# 12563                    Front Ecol Environ     NaN              NaN      NaN
# 13103      Physica Status Solidi A Appl Res     NaN              NaN      NaN
# 13106                     N Am J Fish Manag     NaN              NaN      NaN
# 13388                     Trans Am Fish Soc     NaN              NaN      NaN
# 13393                     Trans Am Fish Soc     NaN              NaN      NaN
# 13720                         Ambul Pediatr     NaN              NaN      NaN
# 16286                            Bioscience     NaN              NaN      NaN
# 16287                            Bioscience     NaN              NaN      NaN
# 19979                Wilderness Environ Med     NaN              NaN      NaN
# 23645                             Ecol Appl     NaN              NaN      NaN
# 23699                                   NaN     NaN              NaN      NaN
# 24066                                   NaN     NaN              NaN      NaN
# 53317                     Angewandte Chemie     NaN              NaN      NaN
# 103791  Wilderness & Environmental Medicine     NaN              NaN      NaN
# 110163                       Wildl Soc Bull     NaN              NaN      NaN
# 111937                   Front Ecol Environ     NaN              NaN      NaN
# 125331                     Rev Paul Pediatr     NaN              NaN      NaN
#
#                                            pdf_json_files  \
# 8394    document_parses/pdf_json/a1bf6ada1b47e286db751...
# 12259   document_parses/pdf_json/64066db1148876bb85f1c...
# 12262   document_parses/pdf_json/01207321329715e944d0a...
# 12422   document_parses/pdf_json/11c686b3de7f984cb5e82...
# 12435   document_parses/pdf_json/a0e60329e1527b513e6bf...
# 12444   document_parses/pdf_json/279b4d3afbe2142f1ca72...
# 12451   document_parses/pdf_json/c5bcf6c3957245b4a27e4...
# 12456   document_parses/pdf_json/e374c4e801f0bd2473b83...
# 12563   document_parses/pdf_json/dc0c47c12c9fddc79adc3...
# 13103   document_parses/pdf_json/bd0283a74bd15c8b481ce...
# 13106   document_parses/pdf_json/c06d625e79097828798cc...
# 13388   document_parses/pdf_json/660c54e43898f9b7c472f...
# 13393   document_parses/pdf_json/6a8accf080085c9b9d421...
# 13720                                                 NaN
# 16286                                                 NaN
# 16287                                                 NaN
# 19979                                                 NaN
# 23645   document_parses/pdf_json/5b28b06755683f53adeb5...
# 23699   document_parses/pdf_json/4a7d736768e4bd2556807...
# 24066   document_parses/pdf_json/21c939104a13c465e9587...
# 53317                                                 NaN
# 103791  document_parses/pdf_json/a9c2a7e2afbc82f6e729f...
# 110163  document_parses/pdf_json/2f185371b60849f8846c0...
# 111937                                                NaN
# 125331  document_parses/pdf_json/042a57ce54d353b67f9fa...
#
#                                       pmc_json_files  \
# 8394                                             NaN
# 12259                                            NaN
# 12262                                            NaN
# 12422                                            NaN
# 12435                                            NaN
# 12444                                            NaN
# 12451                                            NaN
# 12456                                            NaN
# 12563   document_parses/pmc_json/PMC7164082.xml.json
# 13103                                            NaN
# 13106                                            NaN
# 13388                                            NaN
# 13393                                            NaN
# 13720   document_parses/pmc_json/PMC7185770.xml.json
# 16286                                            NaN
# 16287   document_parses/pmc_json/PMC7110399.xml.json
# 19979                                            NaN
# 23645   document_parses/pmc_json/PMC7163527.xml.json
# 23699                                            NaN
# 24066                                            NaN
# 53317                                            NaN
# 103791                                           NaN
# 110163                                           NaN
# 111937                                           NaN
# 125331  document_parses/pmc_json/PMC6202903.xml.json
#
#                                                       url        s2_id
# 8394    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 12259   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 12262   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 12422   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 12435   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 12444   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 12451   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 12456   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 12563   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 13103   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 13106   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 13388   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 13393   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 13720   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 16286   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 16287   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 19979   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 23645   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 23699   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 24066   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 53317   https://doi.org/10.1002/(sici)1521-3773(199811...    2699062.0
# 103791  https://www.sciencedirect.com/science/article/...  214756104.0
# 110163  https://www.ncbi.nlm.nih.gov/pubmed/32327860/;...   41199660.0
# 111937  https://doi.org/10.1890/1540-9295(2003)001[028...  215798552.0
# 125331  https://doi.org/10.1590/1984-0462/;2018;36;3;0...   51613150.0

# %% [markdown]
# So the __doi__ cases containing ';' just look like mis-parsings. Will assume doi is single valued and come back to this matter if we end up having to use doi for something.
#
# Turning to __title__:

# %%
metadataFrame[metadataFrame['title'].str.contains(';').fillna(False)]
# Out:
#         cord_uid                                                sha  \
# 1840    fkqdrwer           5e0504a1c581c36bbf2c2c97439b87b9834b108b
# 2271    s4qki9l5           f4c43e4ae49ca69dbac32620bd0a73ecbb683b91
# 2509    l2dc9x12           d760a0c49650a6c2a3d822bab4417057e6be1cd1
# 2615    9gftenfz  f4ac2b1e9b9523671d7c38c27a19f1eec2e15d75; 6044...
# 2880    k81qwzof           a7154cf3907686df4aab059a0be568e0dacb44cb
# 3515    n7ev5osc           7018967c7ebc76e4c6d3decf7e836957ff427602
# 3641    muozucj7                                                NaN
# 4377    eoz1l5fi           041e50456e5c62980ff8bb61d83283f58f09ef6d
# 4756    q10zmids           3061f05203159384dfbb2fd9b1d9a1ca7b98c8a6
# 5456    5fk3clav                                                NaN
# 5509    l1hmki8o                                                NaN
# 5612    i696fyja                                                NaN
# 5656    p4s5uqz8           6cc29c53c7f0a16b790c0bc685b6ca05abd98d7a
# 5931    ptsuhbod           7a127771726a4021821b1741661518a10cc1f73f
# 7909    5pzcfcoe           541f2811c88ee0894e8ef20190edcf403125f902
# 9994    187o4ukz                                                NaN
# 10416   r1haxog5                                                NaN
# 10603   hjkx4k1a           d017f18e6abdd511226d2fddfd8b797499484fc4
# 10729   cweeatnh           f275fa315d349056864929245493ee422a2f5c4d
# 11670   3l62b03x                                                NaN
# 11930   8v25etag           00fddd1ce0dae85355b9fdf8bbbe6bed4475f7e8
# 11984   ub4p4ngr                                                NaN
# 12311   s2db8r85                                                NaN
# 12359   n4wqy6vh                                                NaN
# 12605   xq3951b3                                                NaN
# 12625   rgzccqp3           7f2863b59185c97f0e948a9caa32c0deb3e1a5a0
# 12713   cla2ta1b                                                NaN
# 13021   qcfts6fu           1038b97923cff88c849b94467976ba1f93a3ceda
# 13286   1cxrnrv3           122ed2c3ce7840bf533c05931efe085f2e74d7d3
# 13515   vhqc5svz           2a1af58bd788fca168913f1d5de3a0a0f707c735
# ...          ...                                                ...
# 130195  eci120hv                                                NaN
# 130401  sbsyzbse                                                NaN
# 130588  jb455t9p           05513da119ba8f48c1c468a8a40a591b731c4479
# 131072  1yarrsep           a3bbdeb8416af69d5dd2a752af1c87eb195c5fa4
# 131089  2bzh4tqg           2182aebd9ddd3f56f1898087c02430e1e92cf205
# 131119  lxtqc77m                                                NaN
# 131361  9ibswt32           915bbf3af94c8bb413b496b0d4d7f88a1ed7d7bb
# 131479  uqrewfd5                                                NaN
# 131498  knc0ruou           a4660be6df902c34e11658e30722bff0b504429a
# 132429  vx8z54m7                                                NaN
# 132523  avov4yxv           322c0f442764f80b0ba7408dff7e0741e0246d6d
# 132554  6o9grg76                                                NaN
# 132677  9k52e5i5                                                NaN
# 133152  kwy9puxo           8b49451747e38074c425e289a7105ac6c4ef297c
# 133667  52kq2u8a           8315fb05f84a283b0bdab306586803bd4c6a2c7e
# 134029  n0x192pm                                                NaN
# 134165  e171z7fh                                                NaN
# 134369  84ci8h6p           73f37594450d368d25b6b3c4df0013805d345d73
# 134432  0ddutmdd           27bafe2069fadba9638ec9eb5ae1afaf3c78cfb8
# 135228  n32nx0bz                                                NaN
# 135325  pdqkfhtq  1b8770691fe974dfb269a16db59750370b9c0c21; 1c4e...
# 135726  m5h2w6nm                                                NaN
# 135827  v6a41kh8           ff4fffe02138b0b232334d997965d11fd936916b
# 137714  zedd7ug4           cafe63b787c472f52f88daab2977460e6283bd58
# 137908  1bmpvmdd           0c8febdb69cd99fd74bd78ee9289ff697f7696f4
# 138184  ehqerbt1           811ae9afd7a07d05da065433fcccafda4ca8ca33
# 138320  ouw2pdi4                                                NaN
# 139449  rk0cmi0q                                                NaN
# 140292  uojg84ir           949089ccf173bf92c560427330e8522c3d1f4700
# 140404  gaxfdwl7           d7e2a75f1fadfef8bda86717738d29efedb0985f
#
#                            source_x  \
# 1840                            PMC
# 2271                            PMC
# 2509                            PMC
# 2615                            PMC
# 2880                            PMC
# 3515                            PMC
# 3641                            PMC
# 4377                            PMC
# 4756                            PMC
# 5456                            PMC
# 5509                            PMC
# 5612                            PMC
# 5656                            PMC
# 5931                            PMC
# 7909                            PMC
# 9994                            PMC
# 10416                           PMC
# 10603                           PMC
# 10729                           PMC
# 11670                           PMC
# 11930                           PMC
# 11984                           PMC
# 12311                           PMC
# 12359                           PMC
# 12605                           PMC
# 12625                           PMC
# 12713                           PMC
# 13021                           PMC
# 13286                           PMC
# 13515                           PMC
# ...                             ...
# 130195       Elsevier; Medline; PMC
# 130401                 Medline; WHO
# 130588                 Medline; PMC
# 131072                 Medline; PMC
# 131089                     PMC; WHO
# 131119                 Medline; WHO
# 131361                 Medline; PMC
# 131479       Elsevier; Medline; WHO
# 131498            Medline; PMC; WHO
# 132429  Elsevier; Medline; PMC; WHO
# 132523  Elsevier; Medline; PMC; WHO
# 132554  Elsevier; Medline; PMC; WHO
# 132677  Elsevier; Medline; PMC; WHO
# 133152           Elsevier; PMC; WHO
# 133667            Medline; PMC; WHO
# 134029                 Medline; WHO
# 134165                Elsevier; PMC
# 134369            Medline; PMC; WHO
# 134432                 Medline; PMC
# 135228                 Medline; WHO
# 135325       Elsevier; Medline; PMC
# 135726       Elsevier; Medline; PMC
# 135827                 Medline; PMC
# 137714       Elsevier; Medline; PMC
# 137908  Elsevier; Medline; PMC; WHO
# 138184       Elsevier; Medline; PMC
# 138320                 Medline; WHO
# 139449  Elsevier; Medline; PMC; WHO
# 140292                 Medline; PMC
# 140404       Elsevier; Medline; PMC
#
#                                                     title  \
# 1840    Induction of Interferon-Stimulated Genes on th...
# 2271    Exploring the Innate Immunological Response of...
# 2509    Correction: Xie, H.; et al. 3D QSAR Studies, P...
# 2615    Meta-genomic analysis of toilet waste from lon...
# 2880    Surfactant Protein C-associated interstitial l...
# 3515    Correlation of central venous pressure with ve...
# 3641    Authors’ correction for Euro Surveill. 2017;22...
# 4377    Award Winners and Abstracts of the 32nd Annual...
# 4756    Iranian Emergency Medical Service Response in ...
# 5456                Erratum for Euro Surveill. 2020;25(5)
# 5509    Author’s correction for Euro Surveill. 2020;25(4)
# 5612    Authors’ correction for Euro Surveill. 2020;25(9)
# 5656    Virus diseases in ICU patients: a long time un...
# 5931    Early infantile pertussis; increasingly preval...
# 7909    Effect of a behaviour-change intervention on h...
# 9994    Construction of a bovine-murine heteromyeloma ...
# 10416   The main neutral aminopeptidase activity of hu...
# 10603   Nipah strikes in India; an urgent call for out...
# 10729   Alternative Methods to Reduce, Refine, and Rep...
# 11670                β&rarr;LACTAMASE-PRODUCING ANAEROBES
# 11930   COVID-2019 is still rapidly spreading in Iran;...
# 11984   Alteration of intracellular traffic by monensi...
# 12311   Authors’ correction for Euro Surveill. 2020;25(3)
# 12359   Advances in experimental medicine and biology....
# 12605   Correction to Lancet Child Adolesc Health 2020...
# 12625   Flavivirus‐Induced Up‐regulation of MHC Class ...
# 12713   “THE CLASSIFICATION OF VIRUSES; WHY, WHEN, AND...
# 13021   Mixed viral infections of the respiratory trac...
# 13286   Loop mediated isothermal amplification (LAMP):...
# 13515   Avian flu virus H5N1: No proof for existence, ...
# ...                                                   ...
# 130195  Correction to Lancet Gastroenterol Hepatol 202...
# 130401  Letter to the Editor in relation to Bistrian B...
# 130588  The role of facemasks and hand hygiene in the ...
# 131072  Seroprevalence of three paramyxoviruses; Hendr...
# 131089  Current pharmacy practices in low- and middle-...
# 131119  COVID-19 pneumonia and pregnancy; a systematic...
# 131361  Infectious diseases in children and adolescent...
# 131479  Correction to Lancet Infect Dis 2020; Publishe...
# 131498  Evaluation of a COVID-19 IgM and IgG rapid tes...
# 132429       Correction to Lancet Respir Med 2020; 8: e21
# 132523  Philanthropy and Humanity in the Face of a Pan...
# 132554  Correction to Lancet Public Health 2020; 5; e2...
# 132677   Correction to Lancet Infect Dis 2019; 20: 275–76
# 133152  Safety netting; best practice in the face of u...
# 133667  Dysosmia and dysgeusia due to the 2019 Novel C...
# 134029  COVID-19 pandemic; prevention, treatment, and ...
# 134165  Zoonoses Second Edition Zoonoses. Martin Shake...
# 134369  Hydroxychloroquine and azithromycin as potenti...
# 134432  Mechanisms of HIV non-progression; robust and ...
# 135228             COVID-19 Convalescent Plasma; Phase 2.
# 135325  Epidemiology and etiology of influenza-like-il...
# 135726  Correction to Lancet Infect Dis 2020; publishe...
# 135827  RNA viruses in community-acquired childhood pn...
# 137714  Interferon and cytokine responses to Crimean C...
# 137908  Cancer and COVID-19; how do we manage cancer o...
# 138184  On constitutional isomers and tautomers of oxa...
# 138320  Covid-19 associated SIADH; a clue in the times...
# 139449  Correction to Lancet Glob Health 2020; publish...
# 140292  COVID-19 Digestive Symptoms Mimicking Internal...
# 140404  COVID-19: The time for action is just now; It'...
#
#                                               doi       pmcid   pubmed_id  \
# 1840                 10.1371/journal.pone.0064868  PMC3664578  23724103.0
# 2271                          10.1155/2014/913632  PMC4129158  25170519.0
# 2509                         10.3390/ijms16035072  PMC4394465  25751723.0
# 2615                            10.1038/srep11444  PMC4498435  26161690.0
# 2880                    10.1186/s13052-016-0235-x  PMC4772310  26925580.0
# 3515                   10.1016/j.tjem.2016.09.006  PMC5357094  28345066.0
# 3641        10.2807/1560-7917.es.2017.22.19.30531  PMC5476985  28537549.0
# 4377                             10.1002/pro.3513  PMC6247239  30461082.0
# 4756                       10.22114/ajem.v0i0.121  PMC6548112  31172124.0
# 5456       10.2807/1560-7917.es.2020.25.6.2002132  PMC7029446  32070469.0
# 5509     10.2807/1560-7917.es.2020.25.7.20200220c  PMC7043049  32098643.0
# 5612    10.2807/1560-7917.es.2020.25.10.20200312c  PMC7078826  32183936.0
# 5656                    10.1007/s00134-006-0203-9  PMC7079854  16791659.0
# 5931                           10.1007/pl00008365  PMC7086691  11131347.0
# 7909                    10.1007/s13312-014-0409-9  PMC7096841  24953582.0
# 9994                 10.1016/0165-2427(90)90037-s  PMC7119475   2160144.0
# 10416               10.1016/s0167-4889(96)00132-2  PMC7125594   9042335.0
# 10603                 10.1016/j.tmaid.2018.08.001  PMC7128596  30081100.0
# 10729                10.1016/j.provac.2011.10.011  PMC7129308  32288916.0
# 11670               10.1016/s0140-6736(80)92122-4  PMC7135568   6107605.0
# 11930                        10.34172/hpp.2020.16  PMC7146036  32296620.0
# 11984                10.1016/0304-4157(90)90008-z  PMC7148783   2160275.0
# 12311   10.2807/1560-7917.es.2020.25.14.20200409c  PMC7160439  32290903.0
# 12359                10.1016/0307-4412(82)90179-0  PMC7161825  32317825.0
# 12605               10.1016/s2352-4642(20)30128-0  PMC7164848  32311313.0
# 12625          10.1111/j.1600-065x.1996.tb00908.x  PMC7165549   8930665.0
# 12713                         10.1038/icb.1974.21  PMC7165891   4212523.0
# 13021                           10.1002/jmv.25006  PMC7167177  29244214.0
# 13286                             10.1002/rmv.593  PMC7169140  18716992.0
# 13515                  10.1016/j.mehy.2005.11.007  PMC7173052  16364561.0
# ...                                           ...         ...         ...
# 130195              10.1016/s2468-1253(20)30130-8  PMC7255321  32416863.0
# 130401                          10.1002/jpen.1933         NaN  32463483.0
# 130588                    10.1186/1471-2334-12-26  PMC3285078  22280120.0
# 131072               10.1371/journal.pone.0232339  PMC7202650  32374743.0
# 131089                 10.1007/s40267-020-00745-7  PMC7245645         NaN
# 131119              10.1080/14767058.2020.1763952         NaN  32429786.0
# 131361                 10.3345/kjp.2011.54.12.489  PMC3274655  22323905.0
# 131479              10.1016/s1473-3099(20)30252-8         NaN  32224311.0
# 131498              10.1080/20008686.2020.1754538  PMC7178815  32363011.0
# 132429              10.1016/s2213-2600(20)30235-6  PMC7234787  32437647.0
# 132523                 10.1016/j.ijsu.2020.05.012  PMC7214301  32407796.0
# 132554              10.1016/s2468-2667(20)30098-0  PMC7198160  32380035.0
# 132677              10.1016/s1473-3099(20)30071-2  PMC7128360  32112770.0
# 133152                10.1016/j.msksp.2020.102179  PMC7214294         NaN
# 133667                 10.1186/s40902-020-00254-7  PMC7103905  32289035.0
# 134029              10.1080/21645515.2020.1759976         NaN  32437231.0
# 134165                 10.1016/j.ijid.2010.03.018  PMC7129465         NaN
# 134369                 10.1007/s10928-020-09689-x  PMC7220612  32405664.0
# 134432                    10.1186/1742-4690-5-112  PMC2633348  19077215.0
# 135228                          10.1111/trf.15842         NaN  32374890.0
# 135325                  10.1016/j.jcv.2016.07.014  PMC4994428  27479176.0
# 135726              10.1016/s1473-3099(20)30223-1  PMC7195302  32199077.0
# 135827                     10.1186/1741-7015-7-35  PMC2727531  19635124.0
# 137714              10.1016/j.cytogfr.2008.11.001  PMC7153731  19027345.0
# 137908                 10.1016/j.ejca.2020.04.001  PMC7165280  32335477.0
# 138184               10.1016/j.comptc.2012.11.003  PMC7104208  32288988.0
# 138320                 10.1152/ajpendo.00178.2020         NaN  32396497.0
# 139449              10.1016/s2214-109x(20)30083-8  PMC7128611  32145764.0
# 140292                 10.1007/s11695-020-04664-4  PMC7209764  32385664.0
# 140404                10.1016/j.tmaid.2020.101676  PMC7162786  32305632.0
#
#             license                                           abstract  \
# 1840          cc-by  Epstein-Barr virus (EBV) is an oncogenic virus...
# 2271          cc-by  The common marmoset (Callithrix jacchus) is in...
# 2509          cc-by                                                NaN
# 2615          cc-by  Human populations worldwide are increasingly c...
# 2880          cc-by  BACKGROUND: Monoallelic mutations of the Surfa...
# 3515    cc-by-nc-nd  OBJECTIVE: This study was conducted to assess ...
# 3641          cc-by                                                NaN
# 4377      bronze-oa                                                NaN
# 4756       cc-by-nc  INTRODUCTION: The earthquake is one of the mos...
# 5456          cc-by                                                NaN
# 5509          cc-by                                                NaN
# 5612          cc-by                                                NaN
# 5656          no-cc                                                NaN
# 5931          no-cc  We report nine cases of severe early pertussis...
# 7909          no-cc                                                NaN
# 9994          no-cc  Bovine-murine heteromyeloma cell lines were pr...
# 10416         no-cc  Lymphocytes and related cell lines are predomi...
# 10603         no-cc                                                NaN
# 10729         no-cc  The Virus-Serum-Toxin Act of 1913 provides the...
# 11670         no-cc                                                NaN
# 11930         cc-by                                                NaN
# 11984         no-cc  Monensin, a monovalent ion-selective ionophore...
# 12311         cc-by                                                NaN
# 12359         no-cc                                                NaN
# 12605         no-cc                                                NaN
# 12625         no-cc                                                NaN
# 12713         no-cc                                                NaN
# 13021         no-cc  The current study aimed to describe the molecu...
# 13286         no-cc  Loop mediated isothermal amplification (LAMP) ...
# 13515         no-cc                                                NaN
# ...             ...                                                ...
# 130195    els-covid                                                NaN
# 130401          unk  In this letter we discuss the proposition of B...
# 130588        cc-by  BACKGROUND: Previous controlled studies on the...
# 131072        cc-by  Habitat-mediated global change is driving shif...
# 131089        no-cc                                                NaN
# 131119          unk  Background: The new SARS-CoV-2 originated from...
# 131361     cc-by-nc  Compared to the past decades, in recent decade...
# 131479    els-covid                                                NaN
# 131498        cc-by  COVID-19 is the most rapidly growing pandemic ...
# 132429    els-covid                                                NaN
# 132523        no-cc                                                NaN
# 132554    els-covid  Prem K, Liu Y, Russel TW, et al The effect of ...
# 132677    els-covid                                                NaN
# 133152        no-cc  Safety netting is a recognised General Practit...
# 133667        cc-by                                                NaN
# 134029          unk                                                NaN
# 134165    els-covid                                            Unknown
# 134369        no-cc                                                NaN
# 134432        cc-by  BACKGROUND: Elite non-progressors (plasma vira...
# 135228          unk                                                NaN
# 135325        cc-by  BACKGROUND: Household studies provide opportun...
# 135726    els-covid                                                NaN
# 135827        cc-by  BACKGROUND: Pneumonia is among the main causes...
# 137714    els-covid  Abstract Crimean Congo hemorrhagic fever virus...
# 137908        no-cc                                                NaN
# 138184        no-cc  The constitutional isomers and tautomers of ox...
# 138320          unk                                                NaN
# 139449    els-covid                                                NaN
# 140292        no-cc                                                NaN
# 140404    els-covid                                                NaN
#
#        publish_time                                            authors  \
# 1840     2013-05-27  Smith, Nikki; Tierney, Rosemary; Wei, Wenbin; ...
# 2271     2014-07-22                            Nelson, M.; Loveday, M.
# 2509     2015-03-05        Xie, Huiding; Qiu, Kaixiong; Xie, Xiaoguang
# 2615     2015-07-10  Nordahl Petersen, Thomas; Rasmussen, Simon; Ha...
# 2880     2016-02-29  Salerno, Teresa; Peca, Donatella; Menchini, La...
# 3515     2016-11-20  Rahim-Taleghani, Sima; Fatemi, Alireza; Alavi ...
# 3641     2017-05-11                                                NaN
# 4377     2018-11-01                                                NaN
# 4756     2019-01-14  Saberian, Peyman; Kolivand, Pir-Hossein; Hasan...
# 5456     2020-02-13                                                NaN
# 5509     2020-02-20                                                NaN
# 5612     2020-03-12                                                NaN
# 5656     2006-05-24                              Luyt, Charles-Edouard
# 5931           2000                         Smith, Craig; Vyas, Harish
# 7909     2014-05-14  Mathew, Joseph L.; Lahariya, Chandrakant; Bhar...
# 9994     2002-11-12  Booman, P.; Tieman, M.; Van Zaane, D.; Bosma, ...
# 10416    1997-02-04  Wex, T; Lendeckel, U; Kähne, T; Ittenson, A; F...
# 10603    2018-08-03  Mallhi, Tauqeer Hussain; Khan, Yusra Habib; Kh...
# 10729    2011-12-23                                   Hill, Richard E.
# 11670    1980-11-01                   Reilly, Sheena; Trevor Willis, A
# 11930    2020-03-19                                    Nadrian, Haidar
# 11984    1990-05-07  Mollenhauer, Hilton H.; James Morré, D.; Rowe,...
# 12311    2020-04-09                                                NaN
# 12359    2002-12-16                                                NaN
# 12605    2020-04-17                                                NaN
# 12625    2006-04-28  Lobigs, Mario; Blanden, Robert V.; Müllbacher,...
# 12713    1974-04-01                                      Fenner, Frank
# 13021    2018-01-17  Antalis, Emmanouil; Oikonomopoulou, Zacharoula...
# 13286    2008-08-20  Parida, Manmohan; Sannarangaiah, Santhosh; Das...
# 13515    2005-12-20                 Crowe, David; Engelbrecht, Torsten
# ...             ...                                                ...
# 130195   2020-06-30                                                NaN
# 130401         2020  Torrinhas, Raquel S.; Calder, Philip C.; Waitz...
# 130588   2012-01-26  Suess, Thorsten; Remschmidt, Cornelius; Schink...
# 131072   2020-05-06  Boardman, Wayne S. J.; Baker, Michelle L.; Boy...
# 131089   2020-05-24  Hamid, Husnain; Masood, Rizwan Ali; Tariq, Hir...
# 131119         2020  Kasraeian, Maryam; Zare, Marjan; Vafaei, Homei...
# 131361   2011-12-31                                     Kim, Jong-Hyun
# 131479   2020-03-27                                                NaN
# 131498   2020-04-14  Hoffman, Tove; Nissen, Karolina; Krambrich, Ja...
# 132429   2020-05-18                                                NaN
# 132523   2020-05-12                                       Liu, Antonio
# 132554   2020-05-31                                                NaN
# 132677   2020-03-31                                                NaN
# 133152   2020-05-12  Greenhalgh, Sue; Finucane, Laura M.; Mercer, C...
# 133667   2020-03-30  Keyhan, Seied Omid; Fallahi, Hamid Reza; Chesh...
# 134029   2020-05-21  Khan, Suliman; Siddique, Rabeea; Li, Zhe; Xue,...
# 134165   2010-09-30                                     Majewski, Jake
# 134369   2020-05-13    Okour, Malek; Al-Kofahi, Mahmoud; Austin, Daren
# 134432   2008-12-11  Dyer, Wayne B; Zaunders, John J; Yuan, Fang Fa...
# 135228   2020-05-06              Knudson, C Michael; Jackson, J Brooks
# 135325   2016-09-01  Nguyen, Diep Ngoc Thi; Mai, Le Quynh; Bryant, ...
# 135726   2020-03-18                                                NaN
# 135827   2009-07-27  Mathisen, Maria; Strand, Tor A; Sharma, Biswa ...
# 137714   2008-12-31                   Weber, Friedemann; Mirazimi, Ali
# 137908   2020-04-18  Vrdoljak, Eduard; Sullivan, Richard; Lawler, Mark
# 138184   2013-02-01           Karpińska, Grażyna; Dobrowolski, Jan Cz.
# 138320         2020  Yousaf, Zohaib; Al-Shokri, Shaikha D; Al-Soub,...
# 139449   2020-03-05                                                NaN
# 140292   2020-05-08  Betton, Louis; Benchetrit, Deborah; Aron-Wisne...
# 140404   2020-04-17  Hamidian Jahromi, Alireza; Mazloom, Samira; Ba...
#
#                                                   journal  mag_id  \
# 1840                                             PLoS One     NaN
# 2271                                        J Immunol Res     NaN
# 2509                                        Int J Mol Sci     NaN
# 2615                                              Sci Rep     NaN
# 2880                                       Ital J Pediatr     NaN
# 3515                                     Turk J Emerg Med     NaN
# 3641                                        Euro Surveill     NaN
# 4377                                      Protein Science     NaN
# 4756                                      Adv J Emerg Med     NaN
# 5456                                        Euro Surveill     NaN
# 5509                                        Euro Surveill     NaN
# 5612                                        Euro Surveill     NaN
# 5656                                   Intensive Care Med     NaN
# 5931                                        Eur J Pediatr     NaN
# 7909                                       Indian Pediatr     NaN
# 9994                             Vet Immunol Immunopathol     NaN
# 10416                   Biochim Biophys Acta Mol Cell Res     NaN
# 10603                               Travel Med Infect Dis     NaN
# 10729                                   Procedia Vaccinol     NaN
# 11670                                              Lancet     NaN
# 11930                              Health Promot Perspect     NaN
# 11984                                                 NaN     NaN
# 12311                                       Euro Surveill     NaN
# 12359                                        Biochem Educ     NaN
# 12605                         Lancet Child Adolesc Health     NaN
# 12625                                         Immunol Rev     NaN
# 12713                             Aust J Exp Biol Med Sci     NaN
# 13021                                         J Med Virol     NaN
# 13286                                       Rev Med Virol     NaN
# 13515                                      Med Hypotheses     NaN
# ...                                                   ...     ...
# 130195           The Lancet Gastroenterology & Hepatology     NaN
# 130401  JPEN. Journal of parenteral and enteral nutrition     NaN
# 130588                                     BMC Infect Dis     NaN
# 131072                                           PLoS One     NaN
# 131089                                Drugs Ther Perspect     NaN
# 131119                        J Matern Fetal Neonatal Med     NaN
# 131361                                   Korean J Pediatr     NaN
# 131479                                  Lancet Infect Dis     NaN
# 131498                              Infect Ecol Epidemiol     NaN
# 132429                                  Lancet Respir Med     NaN
# 132523                                         Int J Surg     NaN
# 132554                           The Lancet Public Health     NaN
# 132677                     The Lancet Infectious Diseases     NaN
# 133152                            Musculoskelet Sci Pract     NaN
# 133667                     Maxillofac Plast Reconstr Surg     NaN
# 134029                Human vaccines & immunotherapeutics     NaN
# 134165       International Journal of Infectious Diseases     NaN
# 134369                        J Pharmacokinet Pharmacodyn     NaN
# 134432                                      Retrovirology     NaN
# 135228                                        Transfusion     NaN
# 135325                                       J Clin Virol     NaN
# 135726                                  Lancet Infect Dis     NaN
# 135827                                            BMC Med     NaN
# 137714                   Cytokine & Growth Factor Reviews     NaN
# 137908                                       Eur J Cancer     NaN
# 138184                                  Comput Theor Chem     NaN
# 138320                  Am. j. physiol. endocrinol. metab     NaN
# 139449                                 Lancet Glob Health     NaN
# 140292                                          Obes Surg     NaN
# 140404                              Travel Med Infect Dis     NaN
#
#        who_covidence_id arxiv_id  \
# 1840                NaN      NaN
# 2271                NaN      NaN
# 2509                NaN      NaN
# 2615                NaN      NaN
# 2880                NaN      NaN
# 3515                NaN      NaN
# 3641                NaN      NaN
# 4377                NaN      NaN
# 4756                NaN      NaN
# 5456                NaN      NaN
# 5509                NaN      NaN
# 5612                NaN      NaN
# 5656                NaN      NaN
# 5931                NaN      NaN
# 7909                NaN      NaN
# 9994                NaN      NaN
# 10416               NaN      NaN
# 10603               NaN      NaN
# 10729               NaN      NaN
# 11670               NaN      NaN
# 11930               NaN      NaN
# 11984               NaN      NaN
# 12311               NaN      NaN
# 12359               NaN      NaN
# 12605               NaN      NaN
# 12625               NaN      NaN
# 12713               NaN      NaN
# 13021               NaN      NaN
# 13286               NaN      NaN
# 13515               NaN      NaN
# ...                 ...      ...
# 130195              NaN      NaN
# 130401          #401495      NaN
# 130588              NaN      NaN
# 131072              NaN      NaN
# 131089          #343685      NaN
# 131119          #324396      NaN
# 131361              NaN      NaN
# 131479           #17924      NaN
# 131498          #142390      NaN
# 132429          #291135      NaN
# 132523          #232554      NaN
# 132554          #197332      NaN
# 132677            #2468      NaN
# 133152          #232509      NaN
# 133667           #19592      NaN
# 134029          #327128      NaN
# 134165              NaN      NaN
# 134369        #32410927      NaN
# 134432              NaN      NaN
# 135228          #197550      NaN
# 135325              NaN      NaN
# 135726              NaN      NaN
# 135827              NaN      NaN
# 137714              NaN      NaN
# 137908           #72278      NaN
# 138184              NaN      NaN
# 138320          #245724      NaN
# 139449            #4643      NaN
# 140292              NaN      NaN
# 140404              NaN      NaN
#
#                                            pdf_json_files  \
# 1840    document_parses/pdf_json/5e0504a1c581c36bbf2c2...
# 2271    document_parses/pdf_json/f4c43e4ae49ca69dbac32...
# 2509    document_parses/pdf_json/d760a0c49650a6c2a3d82...
# 2615    document_parses/pdf_json/f4ac2b1e9b9523671d7c3...
# 2880    document_parses/pdf_json/a7154cf3907686df4aab0...
# 3515    document_parses/pdf_json/7018967c7ebc76e4c6d3d...
# 3641                                                  NaN
# 4377    document_parses/pdf_json/041e50456e5c62980ff8b...
# 4756    document_parses/pdf_json/3061f05203159384dfbb2...
# 5456                                                  NaN
# 5509                                                  NaN
# 5612                                                  NaN
# 5656    document_parses/pdf_json/6cc29c53c7f0a16b790c0...
# 5931    document_parses/pdf_json/7a127771726a4021821b1...
# 7909    document_parses/pdf_json/541f2811c88ee0894e8ef...
# 9994                                                  NaN
# 10416                                                 NaN
# 10603   document_parses/pdf_json/d017f18e6abdd511226d2...
# 10729   document_parses/pdf_json/f275fa315d34905686492...
# 11670                                                 NaN
# 11930   document_parses/pdf_json/00fddd1ce0dae85355b9f...
# 11984                                                 NaN
# 12311                                                 NaN
# 12359                                                 NaN
# 12605                                                 NaN
# 12625   document_parses/pdf_json/7f2863b59185c97f0e948...
# 12713                                                 NaN
# 13021   document_parses/pdf_json/1038b97923cff88c849b9...
# 13286   document_parses/pdf_json/122ed2c3ce7840bf533c0...
# 13515   document_parses/pdf_json/2a1af58bd788fca168913...
# ...                                                   ...
# 130195                                                NaN
# 130401                                                NaN
# 130588  document_parses/pdf_json/05513da119ba8f48c1c46...
# 131072  document_parses/pdf_json/a3bbdeb8416af69d5dd2a...
# 131089  document_parses/pdf_json/2182aebd9ddd3f56f1898...
# 131119                                                NaN
# 131361  document_parses/pdf_json/915bbf3af94c8bb413b49...
# 131479                                                NaN
# 131498  document_parses/pdf_json/a4660be6df902c34e1165...
# 132429                                                NaN
# 132523  document_parses/pdf_json/322c0f442764f80b0ba74...
# 132554                                                NaN
# 132677                                                NaN
# 133152  document_parses/pdf_json/8b49451747e38074c425e...
# 133667  document_parses/pdf_json/8315fb05f84a283b0bdab...
# 134029                                                NaN
# 134165                                                NaN
# 134369  document_parses/pdf_json/73f37594450d368d25b6b...
# 134432  document_parses/pdf_json/27bafe2069fadba9638ec...
# 135228                                                NaN
# 135325  document_parses/pdf_json/1b8770691fe974dfb269a...
# 135726                                                NaN
# 135827  document_parses/pdf_json/ff4fffe02138b0b232334...
# 137714  document_parses/pdf_json/cafe63b787c472f52f88d...
# 137908  document_parses/pdf_json/0c8febdb69cd99fd74bd7...
# 138184  document_parses/pdf_json/811ae9afd7a07d05da065...
# 138320                                                NaN
# 139449                                                NaN
# 140292  document_parses/pdf_json/949089ccf173bf92c5604...
# 140404  document_parses/pdf_json/d7e2a75f1fadfef8bda86...
#
#                                       pmc_json_files  \
# 1840    document_parses/pmc_json/PMC3664578.xml.json
# 2271    document_parses/pmc_json/PMC4129158.xml.json
# 2509    document_parses/pmc_json/PMC4394465.xml.json
# 2615    document_parses/pmc_json/PMC4498435.xml.json
# 2880    document_parses/pmc_json/PMC4772310.xml.json
# 3515    document_parses/pmc_json/PMC5357094.xml.json
# 3641                                             NaN
# 4377                                             NaN
# 4756    document_parses/pmc_json/PMC6548112.xml.json
# 5456                                             NaN
# 5509                                             NaN
# 5612                                             NaN
# 5656    document_parses/pmc_json/PMC7079854.xml.json
# 5931                                             NaN
# 7909                                             NaN
# 9994                                             NaN
# 10416   document_parses/pmc_json/PMC7125594.xml.json
# 10603   document_parses/pmc_json/PMC7128596.xml.json
# 10729                                            NaN
# 11670                                            NaN
# 11930   document_parses/pmc_json/PMC7146036.xml.json
# 11984                                            NaN
# 12311                                            NaN
# 12359                                            NaN
# 12605                                            NaN
# 12625                                            NaN
# 12713                                            NaN
# 13021   document_parses/pmc_json/PMC7167177.xml.json
# 13286                                            NaN
# 13515   document_parses/pmc_json/PMC7173052.xml.json
# ...                                              ...
# 130195                                           NaN
# 130401                                           NaN
# 130588  document_parses/pmc_json/PMC3285078.xml.json
# 131072  document_parses/pmc_json/PMC7202650.xml.json
# 131089  document_parses/pmc_json/PMC7245645.xml.json
# 131119                                           NaN
# 131361  document_parses/pmc_json/PMC3274655.xml.json
# 131479                                           NaN
# 131498  document_parses/pmc_json/PMC7178815.xml.json
# 132429                                           NaN
# 132523  document_parses/pmc_json/PMC7214301.xml.json
# 132554                                           NaN
# 132677                                           NaN
# 133152  document_parses/pmc_json/PMC7214294.xml.json
# 133667  document_parses/pmc_json/PMC7103905.xml.json
# 134029                                           NaN
# 134165                                           NaN
# 134369                                           NaN
# 134432  document_parses/pmc_json/PMC2633348.xml.json
# 135228                                           NaN
# 135325  document_parses/pmc_json/PMC4994428.xml.json
# 135726                                           NaN
# 135827  document_parses/pmc_json/PMC2727531.xml.json
# 137714  document_parses/pmc_json/PMC7153731.xml.json
# 137908  document_parses/pmc_json/PMC7165280.xml.json
# 138184  document_parses/pmc_json/PMC7104208.xml.json
# 138320                                           NaN
# 139449                                           NaN
# 140292  document_parses/pmc_json/PMC7209764.xml.json
# 140404  document_parses/pmc_json/PMC7162786.xml.json
#
#                                                       url        s2_id
# 1840    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...          NaN
# 2271    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...          NaN
# 2509    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...          NaN
# 2615    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...          NaN
# 2880    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...          NaN
# 3515    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...          NaN
# 3641    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...          NaN
# 4377    https://onlinelibrary.wiley.com/doi/pdfdirect/...          NaN
# 4756    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...          NaN
# 5456    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 5509    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 5612    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 5656    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 5931    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 7909    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 9994    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 10416   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 10603   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 10729   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 11670   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 11930   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 11984   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 12311   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 12359   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 12605   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 12625   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 12713   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 13021   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 13286   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# 13515   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...          NaN
# ...                                                   ...          ...
# 130195  https://api.elsevier.com/content/article/pii/S...  218678284.0
# 130401  https://www.ncbi.nlm.nih.gov/pubmed/32463483/;...  218977153.0
# 130588  https://www.ncbi.nlm.nih.gov/pubmed/22280120/;...    8036973.0
# 131072  https://doi.org/10.1371/journal.pone.0232339; ...  218533975.0
# 131089         https://doi.org/10.1007/s40267-020-00745-7  218890047.0
# 131119  https://www.ncbi.nlm.nih.gov/pubmed/32429786/;...  218758930.0
# 131361  https://www.ncbi.nlm.nih.gov/pubmed/22323905/;...   41520761.0
# 131479  https://www.sciencedirect.com/science/article/...  214733818.0
# 131498  https://www.ncbi.nlm.nih.gov/pubmed/32363011/;...  216347307.0
# 132429  https://www.ncbi.nlm.nih.gov/pubmed/32437647/;...  218676014.0
# 132523  https://api.elsevier.com/content/article/pii/S...  218582774.0
# 132554  https://www.sciencedirect.com/science/article/...  218488396.0
# 132677  https://www.sciencedirect.com/science/article/...  211573750.0
# 133152  https://api.elsevier.com/content/article/pii/S...  218582883.0
# 133667  https://www.ncbi.nlm.nih.gov/pubmed/32289035/;...  214729783.0
# 134029  https://doi.org/10.1080/21645515.2020.1759976;...  218832033.0
# 134165  https://api.elsevier.com/content/article/pii/S...   73193655.0
# 134369  https://www.ncbi.nlm.nih.gov/pubmed/32405664/;...  218606047.0
# 134432  https://doi.org/10.1186/1742-4690-5-112; https...   20388015.0
# 135228  https://www.ncbi.nlm.nih.gov/pubmed/32374890/;...  218534054.0
# 135325  https://api.elsevier.com/content/article/pii/S...    3796252.0
# 135726  https://www.sciencedirect.com/science/article/...  214607151.0
# 135827  https://doi.org/10.1186/1741-7015-7-35; https:...    1146242.0
# 137714  https://www.ncbi.nlm.nih.gov/pubmed/19027345/;...   37471795.0
# 137908  https://www.ncbi.nlm.nih.gov/pubmed/32335477/;...  215801117.0
# 138184  https://www.sciencedirect.com/science/article/...   96179559.0
# 138320  https://doi.org/10.1152/ajpendo.00178.2020; ht...  218620186.0
# 139449  https://doi.org/10.1016/s2214-109x(20)30083-8;...  212639150.0
# 140292  https://doi.org/10.1007/s11695-020-04664-4; ht...  218552366.0
# 140404  https://www.ncbi.nlm.nih.gov/pubmed/32305632/;...  215790272.0
#
# [575 rows x 19 columns]

# %% [markdown]
# Lets make these more readable.

# %%
for record in metadataFrame[metadataFrame['title'].str.contains(';').fillna(False)]['title']:
    pp(record)
# Out:
# ('Induction of Interferon-Stimulated Genes on the IL-4 Response Axis by '
#  'Epstein-Barr Virus Infected Human B Cells; Relevance to Cellular '
#  'Transformation')
# ('Exploring the Innate Immunological Response of an Alternative Nonhuman '
#  'Primate Model of Infectious Disease; the Common Marmoset')
# ('Correction: Xie, H.; et al. 3D QSAR Studies, Pharmacophore Modeling and '
#  'Virtual Screening on a Series of Steroidal Aromatase Inhibitors. Int. J. '
#  'Mol. Sci. 2014, 15, 20927–20947')
# ('Meta-genomic analysis of toilet waste from long distance flights; a step '
#  'towards global surveillance of infectious diseases and antimicrobial '
#  'resistance')
# ('Surfactant Protein C-associated interstitial lung disease; three different '
#  'phenotypes of the same SFTPC mutation')
# ('Correlation of central venous pressure with venous blood gas analysis '
#  'parameters; a diagnostic study')
# 'Authors’ correction for Euro Surveill. 2017;22(11)'
# ('Award Winners and Abstracts of the 32nd Annual Symposium of The Protein '
#  'Society; Boston, MA, July 9–12, 2018')
# ('Iranian Emergency Medical Service Response in Disaster; Report of three '
#  'Earthquakes')
# 'Erratum for Euro Surveill. 2020;25(5)'
# 'Author’s correction for Euro Surveill. 2020;25(4)'
# 'Authors’ correction for Euro Surveill. 2020;25(9)'
# ('Virus diseases in ICU patients: a long time underestimated; but be aware of '
#  'overestimation')
# 'Early infantile pertussis; increasingly prevalent and potentially fatal'
# ('Effect of a behaviour-change intervention on hand washing with soap in India '
#  '(SuperAmma): A Cluster-Randomised Trial: Source Citation: Biran A, Schmidt '
#  'W, Varadharajan KS, Rajaraman D, Kumar R, Greenland K, et al. Lancet Glob '
#  'Health 2014;2:E145–54.')
# ('Construction of a bovine-murine heteromyeloma cell line; Production of '
#  'bovine monoclonal antibodies against rotavirus and pregnant mare serum '
#  'gonadotrophin')
# ('The main neutral aminopeptidase activity of human lymphoid tumour cell lines '
#  'does not originate from the aminopeptidase N-(APN; CD13) gene')
# 'Nipah strikes in India; an urgent call for outbreak preparedness in Pakistan'
# ('Alternative Methods to Reduce, Refine, and Replace the Use of Animals In the '
#  'Development and Testing of Veterinary Biologics in The United States; a '
#  'Strategic Priority')
# 'β&rarr;LACTAMASE-PRODUCING ANAEROBES'
# ('COVID-2019 is still rapidly spreading in Iran; isn’t it the time to call for '
#  'international action?')
# ('Alteration of intracellular traffic by monensin; mechanism, specificity and '
#  'relationship to toxicity')
# 'Authors’ correction for Euro Surveill. 2020;25(3)'
# ('Advances in experimental medicine and biology. Volumes 138–142: Published by '
#  'Plenum Press, New York. Vol 138, $49.50; Vol 139, $59.50; Vol 140, $35; Vol '
#  '142, $49.50')
# ('Correction to Lancet Child Adolesc Health 2020; published online April 14. '
#  'https://doi.org/10.1016/S2352-4642(20)30109-7')
# ('Flavivirus‐Induced Up‐regulation of MHC Class I Antigens; Implications for '
#  'the Induction of CD8(+) T‐Cell‐Mediated Autoimmunity')
# '“THE CLASSIFICATION OF VIRUSES; WHY, WHEN, AND HOW”'
# ('Mixed viral infections of the respiratory tract; an epidemiological study '
#  'during consecutive winter seasons')
# ('Loop mediated isothermal amplification (LAMP): a new generation of '
#  'innovative gene amplification technique; perspectives in clinical diagnosis '
#  'of infectious diseases')
# ('Avian flu virus H5N1: No proof for existence, pathogenicity, or pandemic '
#  'potential; non-“H5N1” causation omitted')
# ('Distinctive features of foot-and-mouth disease virus, a member of the '
#  'picornavirus family; aspects of virus protein synthesis, protein processing '
#  'and structure')
# 'Correction to Lancet Glob Health 2020; 8: e452–53'
# ('Correction to Lancet Infect Dis 2020; published online March 30. '
#  'https://doi.org/10.1016/S1473-3099(20)30243-7')
# ('Congenital diaphragmatic hernia presenting with symptoms within the first '
#  'day of life; outcomes from a non-ECMO centre in Denmark')
# ('Correction to Lancet Infect Dis 2020; published online March 27. '
#  'https://doi.org/10.1016/S1473-3099(20)30200-0')
# 'Authors’ correction for Euro Surveill. 2020;25(17)'
# 'The BDA; together'
# ('Gerald L. Mandell, John E. Bennett, Raphael Dolin (eds): Principles and '
#  'Practice of Infectious Diseases, 6th edn: Elsevier, Philadelphia, 2005; two '
#  'volumes + CD-ROM, hardbound, pp 3661 + XXXVIII; €314.90, US$329, GBP 201.13; '
#  'ISBN 0-443-06643-4')
# ('Endoscope decontamination; wearing rings under gloves; effects of Chinese '
#  'herbal medicines; anesthetic adverse events')
# ('Bacteria bound to cloth; glucoprotamin; toluidine blue O; surgical helmets '
#  'versus filtering masks')
# ('Articles selected by Faculty of1000: identifying antigens involved in '
#  'autoimmune response; statistics in genomics; mouse full-length cDNA '
#  'encylopedia; screen for Drosophila neural development genes; proteome of '
#  'SARS-coronavirus')
# ('ESCP 36th European Symposium on Clinical Pharmacy ‘Implementing Clinical '
#  'Pharmacy in Community and Hospital Settings: Sharing the Experience’, '
#  'Istanbul, Turkey 25–27 October 2007; Abstracts')
# ('Managing SARS Amidst Uncertainty Wenzel RP, Edmond MB The New England '
#  'Journal Of Medicine. 2003;348:1947–1948')
# 'Seligman (2007; 195:609)'
# ('Travel Medicine, Check Program of Self Assessment Unit 387, Vol. 2; Bruce '
#  'Short (Ed.), 1st ed.; The Royal Australian College of General Practitioners, '
#  'South Melbourne, May 2004, 33 pages, Paperback, ISSN 0812-9630')
# ('Human adenoidal organ culture: A model to study nontypable haemophilus '
#  'influenzae (NTHI) and other bacterial interactions with nasopharyngeal '
#  'mucosa—implications in otitis media : Bernstein J.M.; Hard R.; Cui Z.D.; '
#  'Nobuo S.; Fisher J.; Ogra P.L.OTolaryngol. Head Neck Surg. (1990) 103/5 I '
#  '(784–791)')
# 'Venues of Counter-Hegemonic Visuality; Days of Contention'
# ('Exotic Viral Diseases: A Global Guide: S.A. Berger, C.H. Calisher and J.S. '
#  'Keystone; BC Decker – Inc, Hamilton and London, 2003, 252 pages, Paperback, '
#  'ISBN 1-55009-205-7 ($29.95)')
# ('New dengue virus Type-1 strain; recombinant DEN1 protein expression; '
#  'potential in recombinant vaccine construction, virus detection and dengue '
#  'fever diagnosis and therapy')
# ('Recombinant DNA encoding hepatitis B virus polypeptide antigen is used in '
#  'detection of infection and in vaccine production; production in prokaryotic '
#  'or eukaryotic host; core antigen, surface antigen DNA sequence')
# ('Isolated specific epitope region of thyroid peroxidase; for use as a '
#  'recombinant vaccine in thyroid tumour or Hashimoto disease immunotherapy')
# ('Feline T-cell lymphotropic lentivirus proteins; cat FIV virus used for the '
#  'specific detection of FIV antibodies, production of antibodies and in '
#  'vaccine; DNA sequence')
# ('Antitumour vaccine containing major histocompatibility complex protein for '
#  'metastase control; application in cancer therapy')
# ('Borrelia burgdorferi gene encoding conserved 79 kDa antigen: DNA probe or '
#  'DNA primer and polymerase chain reaction for Lyme disease diagnosis and '
#  'recombinant vaccine; monoclonal antibody production')
# ('Herpes virus recombinant pox virus recombinant vaccine; recombinant vaccinia '
#  'virus, canary-pox virus, fowl-pox virus construction by insertion of '
#  'glycoprotein gene from foreign herpes virus, pseudorabies virus, '
#  'Epstein-Barr virus or cytomegalovirus')
# ('New protein comprising at least one hepatitis A virus epitope; capsid '
#  'protein expression in vaccinia virus vector for use as recombinant vaccine')
# ('Preparation of a helicase region coded by hepatitis C virus; hepatitis C '
#  'virus recombinant helicase production via gene cloning and expression in '
#  'Spodoptera frugiperda insect cell culture using baculovirus vector : Soyaku '
#  'Eng. Res. Inst. Jpn 06319 583; 22 November 1994')
# ('Production of a vaccine against rotavirus disease; live attenuated strain '
#  'containing the fourth rotavirus gene associated with attenuation')
# ('Vaccine comprising anti-idiotype antibody conjugate; induces production of '
#  'neutralizing antibody (human monoclonal antibody, chimeric antibody or FAb, '
#  'F(Ab′) 2 or Fv fragment) against HIV virus-1')
# ('New glutathione-S-transferase of Schistosoma mansoni; DNA sequence; '
#  'site-directed mutagenesis and expression in Escherichia coli for use as '
#  'recombinant vaccine or in therapy of schistosomiasis')
# ('Nematode protein complex; Haemonchus contortus immunogen and anthelmintic '
#  'agent; protein sequence; recombinant vaccine production')
# ('Peptide capable of binding rubella immunoglobulin useful for rubella '
#  'diagnosis and vaccine production; expression in Escherichia coli')
# ('Antigen composition comprising PEB1 and/or PEB3 antigen from Campylobacter '
#  'jejuni; useful as vaccine and for diagnosis of C. jejuni and Campylobacter '
#  'coli infections')
# ('Vaccine for preventing or treating T-cell mediated pathology; comprises an '
#  'effective amount of a T-lymphocyte receptor and a pharmaceutical medium; '
#  'application in rheumatoid arthritis, multiple sclerosis therapy, diagnosis, '
#  'prevention')
# ('Envelope region nucleic acid fragment of type-C hepatitis virus and its '
#  'detection; diagnosis using hepatitic C virus DNA probe or RNA probe; DNA '
#  'sequence; potential recombinant vaccine preparation')
# ('Synthesis of dimeric Lex or difucosyl Y2 cancer antigen; useful as antitumor '
#  'vaccine and to subside inflammatory processes of rheumatoid arthritis; '
#  'preparation using α 1–3-fucosyltransferase')
# ('Feline infectious-peritonitis virus vaccine; produced by serial passage in '
#  'non-oncogenic e.g. FCWF, CrFK cell culture')
# ('Vaccine comprising live attenuated or inactivated rotavirus strains; HRV '
#  '89-12C2, HRV 408, HRV 248 HRV 456 and/or CJN, for immunization against '
#  'rotavirus illnesses')
# ('Vaccine against transmissible-gastroenteritis virus of pigs; antigen from '
#  'non-pathogenic pig respiratory-corona virus')
# ('Peptide fragments immunoreactive with HTLV-III virus (HIV virus) antibody '
#  'obtained by expressing cloned fragmented HTLV-II provirus nucleotide '
#  'sequences; vaccine production etc.')
# ('Canine corona virus vaccine production by infected cell culture; effective '
#  'against dog corona virus and dog parvo virus infection')
# ('Feline T-lymphotropic lentivirus (FTLV); separated from cell culture and '
#  'useful as vaccine; hybridoma construction and monoclonal antibody '
#  'preparation for use in immunoassay; DNA probe construction; and HIV virus '
#  'model system')
# ('Peptides from merozoite stage of malaria parasite and DNA sequence encoding '
#  'them; Plasmodium falciparum merozoite thrombospondin-related anonymous '
#  'protein expression in Spodoptera frugiperda insect cell transformed with '
#  'nuclear-polyhedrosis virus vector; vaccine')
# ('Ringworm vaccine; containing antigen from e.g. Microsporum canis, '
#  'Microsporum gypsum or Trichophyton mentagrophytes')
# ('New epitope-bearing portions of Entamoeba histolytica; recombinant '
#  'non-glycosylated epitope production and expression in prokaryote host cell, '
#  'for application in a recombinant vaccine : Univ. Virginia Pat. Found. World '
#  '9500 849; 5 January 1995')
# ('Hepatitis C virus asialoglycoprotein-E1 and -E2; useful as vaccine or for '
#  'diagnosis of non-A non-B hepatitis virus infection, or for concentrating or '
#  'reducing HCV proteins in biological samples, and obtained by gene expression '
#  'in yeast')
# ('Recombinant feline corona virus-S protein; expressed as galactokinase fusion '
#  'protein and useful as reconbinant vaccine, therapeutic and diagnostic agents '
#  'for feline-infectious-peritonitis virus')
# ('Recombinant pox virus containing Morbilli virus DNA; expression of e.g. '
#  'measles virus haemagglutinin glycoprotein in host for construction of a '
#  'potential recombinant vaccine against dog distemper virus')
# ('Recombinant Pseudomonas exotoxin produced by cloning of Pseudomonas '
#  'aeruginosa DNA in Escherichia coli having low toxicity to human or mice '
#  'cells but retaining enzymatic activity giving cell-specific immunotoxin; '
#  'vaccine application')
# ('Mengo virus as a vector for expression of foreign polypeptides; hepatitis A '
#  'virus, HIV virus, rabies virus, foot-and-mouth-disease virus, coronat virus, '
#  'Rous sarcoma virus, herpes virus, etc., live attenuated recombinant vaccine '
#  ': Inst. Pasteur Paris World 9429 472; 22 December 1994')
# ('Complex virus promoter; complex pox virus promoter construct; recombinant '
#  'vaccinia virus construction')
# ('New gene fragment encoding rabies virus glycoprotein; DNA sequence '
#  'expression in eukaryote cell culture and application to recombinant vaccine '
#  'construction')
# ('Vaccine containing cattle papilloma virus-2 and/or cattle papilloma virus-4 '
#  'L2 protein; for use as recombinant vaccine or in tumour therapy')
# ('Pathogen strain Borrelia burgdorferi ZS7 (DSM 5527); for the production of '
#  'passive antibodies for the treatment of Lyme disease : Max Planck Soc; '
#  'German Cancer Res. Inst. Eur 633 313; 11 January 1995')
# ('AIDS recombinant vaccine; recombinant HIV virus core protein cloning in '
#  'vaccinia virus vector')
# ('Diphtheria recombinant vaccine; comprises Corynebacterium diphtheriae '
#  'toxin-A fragment mutein, Gly158 DT-A, which is enzymatically inactive; DNA '
#  'sequence')
# ('New recombinant adenovirus used as vaccine; dog adenovirus-2 vector; dog '
#  'parvovirus, cat panleukopenia virus, cat or dog coronavirus, dog distemper '
#  'virus, cat leukemia virus, rabies virus or FIV virus recombinant vaccine '
#  'construction')
# ('Protein homologous to Trypanosoma cruzi heat shock protein; used in vaccine '
#  'and diagnosis of e.g. Mycoplasma or Mycobacterium')
# ('Polypeptide derived from Plasmodium falciparum antigen GLURP; vector plasmid '
#  'pRD15 expression in Escherichia coli or Bacillus subtilis; recombinant '
#  'vaccine construction and malaria therapy; monoclonal antibody and hybridoma '
#  'preparation')
# ('New nucleic acid encoding E2 protein of canine corona virus; dog corona '
#  'virus recombinant E2 protein production; may be used in recombinant vaccine '
#  'production')
# ('Plasmodium Duffy receptor protein; Plasmodium knowlesi or Plasmodium vivax '
#  'gene cloning and expression; potential recombinant vaccine against malaria; '
#  'DNA sequence')
# ('Live or inactivated canine coronavirus vaccine; new antigen dog coronavirus '
#  'isolate')
# ('Nucleic acid constructs, malaria polypeptides and vaccines; recombinant '
#  'malaria serine-repeat antigen production in yeast for the construction of a '
#  'recombinant vaccine')
# ('Immunologically active parvovirus B19 peptide; comprises capsid protein VP1 '
#  'or VP2 fragment; application to recombinant vaccine construction and disease '
#  'diagnosis; protein sequence')
# ('Non-infective structural particle preparation containing flavivirus surface '
#  'antigen protein; Japanese-encephalitis virus cDNA gene cloning in dengue '
#  'virus-2-preinfected cell with a vaccinia virus vector and use of a '
#  'non-infective structural particle as recombinant vaccine')
# ('Universal coronavirus vaccine; spike protein cloning and expression for use '
#  'as a recombinant vaccine')
# ('Antigens of Cysticercus cellulosae; used for antibody production, treatment '
#  'of neurocysticercosis, diagnosis or vaccine production')
# ('Peptide blocking the binding of P. aeruginosa to buccal epithelial cells; '
#  'Pseudomonas aeruginosa recombinant epitope peptide production for use as '
#  'recombinant vaccine and as adjuvant in lung cancer therapy')
# ('Tourism in China: A. Lew, L. Yu, J. Ap and Z. Guangrui (Eds.); The Haworth '
#  'Hospitality Press, New York, 2003, pp. 325, (softback), ISBN: 0789012820')
# ('cDNA clone of non-A non-B hepatitis virus (NANB) post transfusion and its '
#  'use — DNA sequence; potential application as recombinant vaccine; DNA probe '
#  'application in disease diagnosis')
# ('Transgenic plant expressing antigen of pathogenic organism; e.g. using '
#  'Escherichia coli or Streptococcus mutans, used for oral immunization to '
#  'inhibit colonization or invasion by pathogens')
# ('5420253 Method for purifying egg yolk immunoglobulins : Emery Daryll A; '
#  'Straub Darren E Willmar, MN, United States Assigned to Willmar Poultry '
#  'Company Inc')
# ('5424065 Vaccines containing avirulent phop-type microorganisms : Curtiss '
#  'Roy;Galan Jorge St Louis, MO, United States Assigned to Washington '
#  'University')
# ('5419907 Pathogenic porcine respiratory coronavirus : Paul Prem S; Vaughn '
#  'Eric M; Halbur Patrick G Ames, IA, United States Assigned to Iowa State '
#  'University Research Foundation Inc')
# ('Modern approaches to vaccines; molecular and chemical basis of virus '
#  'virulence and immunogenicity: edited by Robert M. Chanock and Richard A. '
#  'Lerner, Cold Spring Harbor Laboratory, 1984. $52.00 ($62.40 outside USA) '
#  '(xxv+457 pages), ISBN 0 87969 165 4')
# ('5417986 Vaccines against diseases caused by enteropathogenic organisms using '
#  'antigens encapsulated within biodegradable-biocompatible microspheres : Reid '
#  'Robert H; Boedeker Edgar; van Hamont John; Setterstrom Jean A Kensington, '
#  'MD, United States Assigned to The United States of America as represented by '
#  'the Secretary of the Army')
# ('5422109 Fluid vaccines and active principle vehicles containing a '
#  'metabolizable oil : Brancq Bernard; Trouve Gerard Le Chesnay, France '
#  "Assigned to Societe d'Exploitation de Produits pour les Industries Chimiques "
#  '(S E P P I C)')
# ('Robotic Process Automation and Consequences for Knowledge Workers; a '
#  'Mixed-Method Study')
# ('Answers linked to Tang JW, Li Y, Eames I, Chan PKS, Ridgway GL. Factors '
#  'involved in the aerosol transmission of infection and control of ventilation '
#  'in healthcare premises. J Hosp Infect 2006;64:100–114.')
# ('4824667 Thymidine kinase deletion mutants of bovine herpesvirus-1, vaccines '
#  'against infectious bovine rhinotracheitis containing same and methods for '
#  'the production and use of same: Malon Kit, Saul Kit assigned to NovaGene '
#  'Inc; Baylor College of Medici')
# ('5418164 Self-supporting carrierfree cell granulates for combating pests and '
#  'treating plants : Andersch Wolfra; Hartwig Jurgen; Homeyer Bernhard; Stenzel '
#  'Klaus Cologne, Germany Assigned to Bayer Aktiengesellschaft')
# ('5418159 Leukaemia inhibitory factor from livestock species and use thereof '
#  'to enhance implantation and development of embryonic cells : Gough Nicholas '
#  'M; Willson Tracey A; Seamark Robert F North Balwyn, Australia Assigned to '
#  'Amrad Corporation Limited')
# ('5422108 Protection of plants against plant pathogens : Mirkov T Erik; '
#  'Fitzmaurice Leona C San Diego, CA, United States Assigned to Smart Plants '
#  'International Inc')
# ('5422106 Method of controlling coleotera using Bacillus thuringiensis strains '
#  'mg P-14025 and LMG P-14026 : Lambert Bart J; Jansens Stefan K; Peferoen '
#  'Marni Beernem, Belgium Assigned to Plant Genetic Systems N V')
# ('5418152 Acidic polycyclic ether antibiotic : Cullen Walter; Dirlam John P; '
#  'Maeda Hiroshi; Tone Junsuke East Lyme, CT, United States Assigned to Pfizer '
#  'Inc')
# ('5419907 Pathogenic porcine respiratory coronavirus : Paul Prem S; Vaughn '
#  'Eric M; Halbur Patrick G Ames, IA, United States Assigned to Iowa State '
#  'University Research Foundation Inc')
# ('5580786 Dual Chamber blood culture bottle with syringe capture and piston '
#  'assembly : Gombrich Peter; Domanik Richard A; Mayer William Chicago, IL, '
#  'United States Assigned to AccuMed Inc')
# ('Respiratory viruses associated with community-acquired pneumonia in '
#  'children: matched case-control study: Rhedin S, Lindstrand A, Hjelmgren A, '
#  'et al. Thorax. 2015;70:847-853')
# ('5420031 Gypsy moth virus with enhanced polyhedra production stability : '
#  'Slavicek James M; Mercer Melissa J Dublin, OH, United States Assigned to The '
#  'United States of America as represented by the Secretary of Agriculture')
# ('5580769 CD8+ cell antiviral factor : Levy Jay A; Mackewicz Carl E San '
#  'Francisco, CA, United States Assigned to The Regents of The University of '
#  'California')
# ('5580785 Field-portable toxicity tester : Stiffey Arthur; Nicolaids Thomas G '
#  'Slidell, LA, United States Assigned to Lumitox Gulf L C')
# 'de-Winter syndrome; ST-T changes equivalent of acute myocardial infarction'
# ('Pneumonia: Classification diagnosis and nursing management: Nursing Standard '
#  '2005;19(42):50–4')
# ('European Respiratory Society: 15th Annual Congress of the European '
#  'Respiratory Society; 17–21 September 2005; Copenhagen, Denmark')
# 'Prostaglandin D(2) (PGD(2)); PGD(2) receptor subtype DP1'
# 'CD14; lymphocyte antigen 96 (LY96; MD2)'
# 'Dipeptidyl peptidase-4 (DPP-4; CD26)'
# ('Gary A. Boorman, Scotl. Eustis, Michael R. Elwell, Charles A. Montgomery, '
#  'Jr. and William F. Mackenzie (eds) Pathology of the Fischer Rat. Reference '
#  'and Atlas Academic Press, New York, 1990; 580 pp., $125')
# ('J. M. Faccini, D. P. Abbott and J. J. Paulus Mouse Histopathology. A '
#  'Glossary for Use in Toxicity and Carcinogenicity Studies Elsevier, '
#  'Amsterdam, 1990; 225 pp., 225 G')
# ("A. K. Armitage (ed.) Other People's Tobacco Smoke Galen Press, Beverly, "
#  '1991; 192 pp., £12.95')
# ('Citrullinated Proteins in Arthritis; their Presence in Joints and Effects on '
#  'Immunogenicity')
# ('DNA Cloning 3: Complex genomes: Edited by D.M. Glover and B.D. Hames. Oxford '
#  'Science, Oxford. ISBN 0-19-963483-1; 0-19-963482-3. Price: £50 (hardback); '
#  '£25 (paperback)')
# ('K.04 Epidemiology and pathogenesis of newly discovered viruses; evaluating '
#  'their threat to human health')
# ('PCR: Protocols for diagnosis of human and animal virus diseases: Edited by '
#  'Y. Becker and G. Darai. Springer-Verlag, Heidelberg, 1995. pp. 596. ISBN '
#  '3-540-58899-X. Price: DM 168,00; SFr 158,00')
# ('Glycyrrhiza glabra L. (Fabaceae/Leguminosae): (Syns.: G. glandulifera '
#  'Waldst. & Kit.; G. hirsuta Pall.; G. pallida Boiss. & Noe; G. violacea '
#  'Boiss. & Noe)')
# ('Correction to Lancet Infectious Diseases 2020; published online April 27. '
#  'https://doi.org/10.1016/S1473-3099(20)30287-5')
# ('Correction to Lancet Infect Dis 2019; published online April 20. '
#  'https://doi.org/10.1016/S1473-3099(20)30160-2')
# ('Correction to Lancet Microbe 2020; published online May 8. https://doi.org/ '
#  '10.1016/S2666-5247(20)30027-6')
# 'Methanex idles Titan & Chile IV plants; evaluating Geismar 3 methanol project'
# ('Correction to Lancet Infect Dis 2020; published online March 27. '
#  'https://doi.org/10.1016/S1473-3099(20)30200-0')
# 'Correction to Lancet Neurol 2020; 19: 481–82'
# ('Response to Comment on Cummings and Cohen. Bariatric/Metabolic Surgery to '
#  'Treat Type 2 Diabetes in Patients With a BMI <35 kg/m2. Diabetes Care '
#  '2016;39:924-933.')
# ('Multiple concurrent bilateral groin hernias in a single patient; a case '
#  'report and a review of uncommon groin hernias: A possible source of '
#  'persistent pain after successful repair.')
# ('Adapting reusable elastomeric respirators to utilise anaesthesia circuit '
#  'filters using a 3D-printed adaptor; a potential alternative to address N95 '
#  'shortages during the COVID-19 pandemic.')
# ('Corrigendum to "N-alkyl-hydroxybenzoyl anilide hydroxamates as dual '
#  'inhibitors of HDAC and HSP90, downregulating IFN-γ induced PD-L1 '
#  'expression"[Eur. J. Med. Chem. 2020 Jan 1;185:111725].')
# ('Increased body mass and depressive symptomatology are associated with '
#  'hypercholesterolemia, among elderly individuals; results from the MEDIS '
#  'study.')
# ('The workday of hospital surgeons: what they do, what makes them satisfied, '
#  'and the role of core tasks and administrative tasks; a diary study.')
# ('A response to "Major complications associated with xenograft biologic mesh '
#  'implantation in abdominal wall reconstruction" (Harth KC, Rosen MJ. Surg '
#  'Innov. 2009;16:324-329) and discussion of the MAUDE (manufacturer and user '
#  'facility device experience) database, FDA regulation of biologic implants, '
#  'an')
# 'Novel bulking agent for faecal incontinence (Br J Surg 2011; 98: 1644-1652).'
# ('Clinical Management of Nonrespiratory Diseases in the COVID-19 Pandemic: '
#  'What Have We Done and What Needs to Be Done? (Re: Telemed J E Health [Epub '
#  'ahead of print]; DOI: 10.1089/tmj.2020.0106).')
# ('Transanal glove port is a safe and cost-effective alternative for transanal '
#  'endoscopic microsurgery (Br J Surg 2012; 99: 1429-1435).')
# ('Role of Social Media and Telemedicine in Diagnosis & Management of COVID-19; '
#  'An Experience of the Iranian Society of Radiology.')
# ('Camera navigation and tissue manipulation; are these laparoscopic skills '
#  'related?')
# 'Air-blocking ablation of osteoid osteoma; a technical note.'
# ('A New Video Tumorial by Young Cancer Patients Dedicated to COVID-19 Pandemic '
#  'and Lockdown (Re: J Adolesc Young Adult Oncol. [Epub ahead of print]; DOI: '
#  '10.1089/jayao.2020.0008).')
# ('Finding the dose for hydroxychloroquine prophylaxis for COVID-19; the '
#  'desperate search for effectiveness.')
# ('The role of laparoscopic sleeve gastrectomy as a treatment for morbid '
#  'obesity; review of outcomes.')
# ('The fate of major dermatology conferences and meetings of 2020; Are '
#  'e-conferences and digital learning the future?')
# ('Temporal Chondroblastoma with a Novel Chromosomal Translocation (2;5) '
#  '(q33;q13).')
# ('Experimental studies investigating the pathophysiology of nephrogenic '
#  'systemic fibrosis; what did we learn so far?')
# ('BiSpectral Index (BIS) monitoring may detect critical hypotension before '
#  'automated non-invasive blood pressure (NIBP) measurement during general '
#  'anaesthesia; a case report.')
# ('Family Member Visits to Critically Ill Patients During COVID-19: A New '
#  'Pathway (Telemed J E Health 2020. [Epub ahead of print]; DOI: '
#  '10.1089/tmj.2020.29040.rb).')
# ("Sniffing out the evidence; It's now time for public health bodies recognize "
#  'the link between COVID-19 and smell and taste disturbance.')
# ('Protocol for treatment of Achilles tendon ruptures; a systematic review with '
#  'network meta-analysis.')
# ('Needlescopic assisted internal ring suturing; a novel application of '
#  'low-cost home-made instruments for pediatric inguinal hernia repair.')
# 'Hybrid approach for left-sided colonic carcinoma obstruction; a case report.'
# ('2019 International Consensus on Cardiopulmonary Resuscitation and Emergency '
#  'Cardiovascular Care Science With Treatment Recommendations: Summary From the '
#  'Basic Life Support; Advanced Life Support; Pediatric Life Support; Neonatal '
#  'Life Support; Education, Implementation, and Teams; and First Aid Task')
# ('aEEG and NIRS during transition and resuscitation after birth: promising '
#  'additional tools; an observational study.')
# ('Caring for people with heart failure and many other medical problems through '
#  'and beyond the COVID-19 pandemic; the advantages of universal-access to home '
#  'telemonitoring.')
# ('Coronavirus disease 2019 (COVID-19) outbreak in Afghanistan; measures and '
#  'challenges.')
# ('Noninvasive hemodynamic monitoring: no high heels on the farm; no clogs to '
#  'the opera.')
# ('Sense-antisense (complementary) peptide interactions and the proteomic code; '
#  'potential opportunities in biology and pharmaceutical science.')
# ('Reorganizing the treatment of cardiovascular disease in response to '
#  'coronavirus disease 2019; time for the polypill?')
# ('PREVENTion of a parastomal hernia with a prosthetic mesh in patients '
#  'undergoing permanent end-colostomy; the PREVENT-trial: study protocol for a '
#  'multicenter randomized controlled trial.')
# ("Comment to: First laparoscopic totally extraperitoneal repair of Laugier's "
#  'hernia: a case report. Ates M, Dirican A, Kose E, Isik B, Yilmaz S. Hernia '
#  '2013; 17:121-123.')
# ('Laparoscopic abdominoperineal resection of the rectum - how is it done; '
#  'initial results.')
# ('Congenital central hypoventilation syndrome; safety of early transition to '
#  'non-invasive ventilation.')
# ('Pertinent roles of African higher institutions in the COVID-19 pandemic '
#  'response: The University of Ilorin, Ilorin, Nigeria; An African Model.')
# ('Re: "Assessing the Detection of Middle East Respiratory Syndrome Coronavirus '
#  'IgG in Suspected and Proven Cases of Middle East Respiratory Syndrome '
#  'Coronavirus Infection" by Alhetheel et al. (Viral Immunol 2017;30:649-653.).')
# ('Single plus one port robotic radical prostatectomy (SPORP); Initial '
#  'experience.')
# ('COVID-19 and Iranian Medical Students; A Survey on Their Related-Knowledge, '
#  'Preventive Behaviors and Risk Perception.')
# ('Re: Antonella Giannantoni, Vittorio Bini, Roger Dmochowski, et al. '
#  'Contemporary management of the painful bladder: a systematic review. Eur '
#  'Urol 2012;61:29-53.')
# ('Repositioning PARP inhibitors for SARS-CoV-2 infection (COVID-19); a new '
#  'multi-pronged therapy for ARDS?')
# 'Fighting COVID-19 in Iran; Economic Challenges Ahead.'
# ('Structure and mechanism of Escherichia coli glutathionylspermidine amidase '
#  'belonging to the family of cysteine; histidine-dependent '
#  'amidohydrolases/peptidases.')
# ('Esmolol reduces anesthetic requirements thereby facilitating early '
#  'extubation; a prospective controlled study in patients undergoing '
#  'intracranial surgery.')
# ('Routinely obtained chest X-rays after elective video-assisted thoracoscopic '
#  'surgery can be omitted in most patients; a retrospective, observational '
#  'study.')
# ('Abstracts from Cardiology 2011, 15th Annual Update on Pediatric and '
#  'Congenital Cardiovascular Disease: Bringing Interdisciplinary Evidence-based '
#  'Practice to the Patient, February 2 - 6, 2011; Scottsdale, Arizona, USA.')
# ('COVID-19 Lung Injury Is Different From High Altitude Pulmonary Edema (Re: '
#  'High Alt Med Biol [Epub ahead of print]; DOI: 10.1089/ham.2020.0055).')
# ("Theopold C, Potter S, Dempsey M, O'Shaughnessy M. A randomised controlled "
#  'trial of absorbable versus non-absorbable sutures for skin closure after '
#  'open carpal tunnel release. J Hand Surg Eur. 2012; 37: 350-3.')
# 'COVID19 Prevention & Care; A Cancer Specific Guideline.'
# 'Hyperspectral enhanced reality (HYPER) for anatomical; liver resection.'
# ('Randomized clinical trial of fibrin sealant versus titanium tacks for mesh '
#  'fixation in laparoscopic umbilical hernia repair (Br J Surg 2011; 98: '
#  '1537-1545).')
# ('Living with complexity; marshalling resources: a systematic review and '
#  'qualitative meta-synthesis of lived experience of mental and physical '
#  'multimorbidity.')
# ('Athletes as community; athletes in community: covid-19, sporting mega-events '
#  'and athlete health protection.')
# 'Lack of dyspnea in Covid-19 patients; another neurological conundrum?'
# 'Robotic vs. Laparoscopic Sleeve Gastrectomy in Adolescents; Reality or Hype.'
# ('Brain uptake and accumulation of new levofloxacin-doxycycline combination '
#  'through the use of solid lipid nanoparticles: Formulation; Optimization and '
#  'in-vivo evaluation.')
# ('Continuous positive airway pressure for bronchiolitis in a general '
#  'paediatric ward; a feasibility study.')
# ('Novel coronavirus: how much of a threat? We know the questions to ask; we '
#  'don’t yet have many answers.')
# ('COVID-19; Systematic and literature review of transmission, case '
#  'definitions, clinical management and clinical trials.')
# ('The first month of the COVID-19 outbreak in 46 sub-Saharan African '
#  'countries; a comparative analysis of growth rates')
# ('Association between rRT-PCR test results upon admission and outcome in '
#  'hospitalized chest CT-Positive COVID-19 patients; a provincial retrospective '
#  'cohort with active follow-up')
# ('Covid-19 nephropathy;an emerging condition caused by novel coronavirus '
#  'infection')
# ('Manifestations of mortality based global data of COVID-19; unifying global '
#  'model through single parameter')
# ('An Outbreak of a New Infectious Disease COVID-19: β-coronaviruses as a '
#  'Threat to Global Healthcare ;Вспышка нового инфекционного заболевания '
#  'COVID-19: β-коронавирусы как угроза глобальному здравоохранению')
# ('1 vol. (15,5×23,5 cm), 429+xvi pages. Prix: $54.00; B.—RNA viruses. 1 vol '
#  '(15,5×23,5 cm), 694+xxii pages. Prix: $79.00 Kurstak E.')
# ('Analysis of the Worldwide Corona Virus (COVID-19) Pandemic Trend;A Modelling '
#  'Study to Predict Its Spread')
# ('Biotechnology Applied to the Diagnosis of Animal Diseases. Revue '
#  'Scientifique et Technique 1993 Office International des Epizooties Paris '
#  'Vol. 12, No. 2. 376 pages, Soft cover, FrF 200,-; US$ 40.-')
# ('Sociological perspectives on the corona crisis: Four sociologists on society '
#  'and COVID-19 ;Sociologiska perspektiv på coronakrisen: Fyra sociologer om '
#  'samhällets reaktion på covid-19')
# ('Capsid integrity quantitative PCR to determine virus infectivity in '
#  'environmental and food applications; a systematic review')
# ('COVIDTrach; the outcomes of mechanically ventilated COVID-19 patients '
#  'undergoing tracheostomy in the UK: Interim Report 22nd May 2020')
# ('COVID-19, SARS-CoV2, Enfeksiyonu: Güncel Epidemiyolojik Analiz ve Hastalık '
#  'Seyrinin Modellemesi ;COVID-19, SARS-CoV2, Infectıon: Current '
#  'Epıdemıologıcal Analysıs and Modelıng of Dısease')
# ('A phased approach to unlocking during the COVID-19 pandemic; Lessons from '
#  'trend analysis')
# ('Serial measurements in COVID-19-induced acute respiratory disease to unravel '
#  'heterogeneity of the disease course: design of the Maastricht Intensive Care '
#  'COVID cohort; MaastrICCht')
# ('Intestinal Health – Key to Maximise Growth Performance in Livestock, Theo '
#  'Niewold (Ed.), Wageningen Academic Publishers, Wageningen, The Netherlands '
#  '(2015). 276 pp., Hardcover, Price: 89 €; 108.49 US$; £ 69.65; Hardback ISBN: '
#  '978-90-76998-91 6; e-book ISBN: 978-90-8686-792-9')
# ('Special COVID-19 Coverage: Death Is an Expected COVID-19 Effect;Covidlateral '
#  'Damage Is Not')
# ('Risk Stratification for Healthcare workers during the CoViD-19 Pandemic; '
#  'using demographics, co-morbid disease and clinical domain in order to assign '
#  'clinical duties')
# ('68 Consecutive patients assessed for COVID-19 infection; experience from a '
#  'UK regional infectious disease unit')
# '“Amantadine disrupts lysosomal gene expression; potential therapy for COVID19”'
# 'COVID-19 Pandemic Prediction for Hungary; a Hybrid Machine Learning Approach'
# ('Predicting the mortality due to Covid-19 by the next month for Italy, Iran '
#  'and South Korea;A simulation study')
# ('Grierson, D. (Ed.): Developmental Regulation of Plant Gene Expression. '
#  'Series: PlantBiotechnology, Vol. 2. 226 S., zahlr. Abb. u. Tab. Blackie, '
#  'Glasgow and London; publishedin the USA by Chapman and Hall, New York. '
#  'Preis: £ 55')
# ('Eddleston M, Davidson R, Wilkinson R, Pierini S, editors. Oxford handbook of '
#  'tropical medicine, 2nd ed. Oxford: Oxford University Press; 2005, 686pp '
#  '[with illus, paper, GBP24.95]. ISBN 0-19-852509-5.')
# ('Avridine-induced arthritis in rats; a T cell-dependent chronic disease '
#  'influenced both by MHC genes and by non-MHC genes.')
# ('Ebola Hemorrhagic Fever as a Public Health Emergency of International '
#  'Concern; a Review Article')
# ("The nucleotide sequence of the extreme 5' end of the avian coronavirus "
#  'genome; implications for the discontinuous mRNA synthesis.')
# 'Information Diet in Covid-19 Crisis; a Commentary'
# 'Potential Treatments for COVID-19; a Narrative Literature Review'
# ('Daily Situation Report on Coronavirus disease (COVID-19) in Iran; March 13, '
#  '2020')
# ('Incidentally Diagnosed COVID-19 Infection in Trauma Patients; a Clinical '
#  'Experience')
# 'Risks of Novel Coronavirus Disease (COVID-19) in Pregnancy; a Narrative Review'
# 'The COVID-19 Intubation and Ventilation Pathway (CiVP); a Commentary'
# ('Daily Situation Report on Coronavirus disease (COVID-19) in Iran; March 16, '
#  '2020')
# ('Daily Situation Report on Coronavirus disease (COVID-19) in Iran; March 15, '
#  '2020')
# 'Metronidazole; a Potential Novel Addition to the COVID-19 Treatment Regimen'
# ('Daily Situation Report on Coronavirus disease (COVID-19) in Iran; March 25, '
#  '2020')
# ('Daily Situation Report on Coronavirus disease (COVID-19) in Iran; March 22, '
#  '2020')
# ('Daily Situation Report on Coronavirus disease (COVID-19) in Iran; March 23, '
#  '2020')
# ('Daily Situation Report on Coronavirus disease (COVID-19) in Iran; March 14, '
#  '2020')
# ('Daily Situation Report on Coronavirus disease (COVID-19) in Iran; March 17, '
#  '2020')
# 'Epidemiological and Clinical Aspects of COVID-19; a Narrative Review'
# ('Laboratory Parameters in Detection of COVID-19 Patients with Positive '
#  'RT-PCR; a Diagnostic Accuracy Study')
# ('Predicting the mortality due to Covid-19 by the next month for Italy, Iran '
#  'and South Korea; a simulation study')
# 'Prone Position in Management of COVID-19 Patients; a Commentary'
# 'COVID-19 Pneumonia in Asymptomatic Trauma Patients; Report of 8 Cases'
# 'Metronidazole; a Potential Novel Addition to the COVID-19 Treatment Regimen.'
# ('The primary structure and expression of the second open reading frame of the '
#  'polymerase gene of the coronavirus MHV-A59; a highly conserved polymerase is '
#  'expressed by an efficient ribosomal frameshifting mechanism.')
# ('Celebrating the past; awakening the future: the NSW Public Health Forum '
#  'highlights public health successes in NSW.')
# ('Commentary: McIntosh K, Chao RK, Krause HE, Wasil R, Mocega HE, Mufson MA. '
#  'Coronavirus infection in acute lower respiratory tract disease of infants. J '
#  'Infect Dis 1974; 130:502-7.')
# ('Daily Situation Report on Coronavirus disease (COVID-19) in Iran; March 16, '
#  '2020.')
# 'Information Typology in Coronavirus (COVID-19) Crisis; a Commentary.'
# ('Regulation of aminopeptidase N (EC 3.4.11.2; APN; CD13) by interferon-gamma '
#  'on the HL-60 cell line.')
# 'West Nile virus core protein; tetramer structure and ribbon formation.'
# ('SARS CTL vaccine candidates; HLA supertype-, genome-wide scanning and '
#  'biochemical validation.')
# 'Coronavirus Pandemic and Worries during Pregnancy; a Letter to Editor.'
# 'Potential Treatments for COVID-19; a Narrative Literature Review.'
# ('Daily Situation Report on Coronavirus disease (COVID-19) in Iran; March 15, '
#  '2020.')
# ('Incidentally Diagnosed COVID-19 Infection in Trauma Patients; a Clinical '
#  'Experience.')
# 'COVID-19 Pneumonia in Asymptomatic Trauma Patients; Report of 8 Cases.'
# ('[No time to waste; plea for scientific validity and against prolific '
#  'authorship].')
# ('Possession, use, and transfer of select agents and toxins; biennial review. '
#  'Final rule.')
# ('Laboratory Parameters in Detection of COVID-19 Patients with Positive '
#  'RT-PCR; a Diagnostic Accuracy Study.')
# ('Hornerin gene was involved in a case of acute myeloid leukemia transformed '
#  'from myelodysplastic syndrome with t(1;2)(q21;q37).')
# 'The COVID-19 Intubation and Ventilation Pathway (CiVP); a Commentary.'
# ('Daily Situation Report on Coronavirus disease (COVID-19) in Iran; March 17, '
#  '2020.')
# 'Current developments in hernia repair; meshes, adhesives, and tacking.'
# ('Liver and Kidney Injuries in COVID-19 and Their Effects on Drug Therapy; a '
#  'Letter to Editor.')
# 'Information Diet in Covid-19 Crisis; a Commentary.'
# ('Opportunistic breast cancer screening in Hong Kong; a revisit of the Kwong '
#  'Wah Hospital experience.')
# 'Prone Position in Management of COVID-19 Patients; a Commentary.'
# ('Different rates of (non-)synonymous mutations in astrovirus genes; '
#  'correlation with gene function.')
# 'Cyclophilin function in Cancer; lessons from virus replication.'
# ("Sequence analysis of the 3' end (8740 nucleotides) of BECV genome; "
#  'comparison with homologous MHV nucleotide sequence.')
# ('Mouse thymic virus (MTLV; murid herpesvirus 3) infection in athymic nude '
#  'mice: evidence for a T lymphocyte requirement.')
# ('Daily Situation Report on Coronavirus disease (COVID-19) in Iran; March 14, '
#  '2020.')
# 'Imaging of Covid-19; an Irish Perspective'
# ('Risks of Novel Coronavirus Disease (COVID-19) in Pregnancy; a Narrative '
#  'Review.')
# ('Re: To KF, Tong JH, Chan PK, et al. Tissue and cellular tropism of the '
#  'coronavirus associated with severe acute respiratory syndrome: an in-situ '
#  'hybridization study of fatal cases. J Pathol 2004; 202: 157-163.')
# ('Daily Situation Report on Coronavirus disease (COVID-19) in Iran; March 22, '
#  '2020.')
# ('Early containment of severe acute respiratory syndrome (SARS); experience '
#  'from Bamrasnaradura Institute, Thailand.')
# ('Sequence and analysis of bovine enteritic coronavirus (F15) genome. I. '
#  'Sequence of the gene coding for the nucleocapsid protein; analysis of the '
#  'predicted protein.')
# ('Laparoscopic vasectomy in African savannah elephant (Loxodonta africana); '
#  'surgical technique and results.')
# 'Epidemiological and Clinical Aspects of COVID-19; a Narrative Review.'
# ('Daily Situation Report on Coronavirus disease (COVID-19) in Iran; March 23, '
#  '2020.')
# ('Canine coronavirus infection in cats; a possible role in feline infectious '
#  'peritonitis.')
# ('A Novel Coronavirus Outbreak from Wuhan City in China, Rapid Need for '
#  'Emergency Departments Preparedness and Response; a Letter to Editor.')
# ('Intraoperative pediatric blood transfusion therapy: a review of common '
#  'issues. Part I: hematologic and physiologic differences from adults; '
#  'metabolic and infectious risks.')
# ('Medicare Program; Hospital Inpatient Prospective Payment Systems for Acute '
#  'Care Hospitals and the Long-Term Care Hospital Prospective Payment System '
#  'Policy Changes and Fiscal Year 2016 Rates; Revisions of Quality Reporting '
#  'Requirements for Specific Providers, Including Changes Related to the '
#  'Electro')
# ('Predicting the mortality due to Covid-19 by the next month for Italy, Iran '
#  'and South Korea; a simulation study.')
# ('Daily Situation Report on Coronavirus disease (COVID-19) in Iran; March 13, '
#  '2020.')
# ('Daily Situation Report on Coronavirus disease (COVID-19) in Iran; March 25, '
#  '2020.')
# 'Respiratory viral infections and host responses; insights from genomics.'
# ('Correction to Lancet Infect Dis 2020; published online March 30. '
#  'https://doi.org/10.1016/S1473-3099(20)30257-7')
# ('‘This beast is moving very fast.’ Will the new coronavirus be contained—or '
#  'go pandemic? ;Science ;AAAS')
# ('Clinical outcome of 55 asymptomatic cases at the time of hospital admission '
#  'infected with SARS-Coronavirus-2 in Shenzhen, China ;The Journal of '
#  'Infectious Diseases ;Oxford Academic')
# ('A case report of neonatal COVID-19 infection in China ;Clinical Infectious '
#  'Diseases ;Oxford Academic')
# 'Metronidazole;a Potential Novel Addition to the COVID-19 Treatment Regimen'
# ('Limiting spread of COVID-19 from cruise ships - lessons to be learnt from '
#  'Japan ;QJM: An International Journal of Medicine ;Oxford Academic')
# ('Epidemiology, virology, and clinical features of severe acute respiratory '
#  'syndrome -coronavirus-2 (SARS-CoV-2; Coronavirus Disease-19)')
# ('Daily Situation Report on Coronavirus disease (COVID-19) in Iran;March 16, '
#  '2020')
# ('Correction to Lancet Oncol 2020; published online April 30. '
#  'https://doi.org/10.1016/S1470-2045(20)30265-5')
# ('Correction to Lancet Infect Dis 2020; Published online March 23. '
#  'https://doi.org/10.1016/S1473-3099(20)30226-7')
# ('Corrigendum to "N-alkyl-hydroxybenzoyl anilide hydroxamates as dual '
#  'inhibitors of HDAC and HSP90, downregulating IFN-Î³ induced PD-L1 '
#  'expression"[Eur. J. Med. Chem. 2020 Jan 1;185:111725]')
# "COVID-19: The time for action is just now; It's still not too late"
# ('Recommendations for the prevention, mitigation and containment of the '
#  'emerging SARS-CoV-2 (COVID-19) pandemic in haemodialysis centres ;Nephrology '
#  'Dialysis Transplantation ;Oxford Academic')
# 'Pharmacotherapy in COVID-19; A narrative review for emergency providers'
# ('Guidance for Cardiac Electrophysiology During the Coronavirus (COVID-19) '
#  'Pandemic from the Heart Rhythm Society COVID-19 Task Force; '
#  'Electrophysiology Section of the American College of Cardiology; and the '
#  'Electrocardiography and Arrhythmias Committee of the Council on Clinical '
#  'Cardiology, American')
# ('New Coronavirus Infection (Covid-19): Clinical and Epidemiological Aspects '
#  ';Новая коронавирусная инфекция (COVID-19): клинико-эпидемиологические '
#  'аспекты')
# ('Letter: Using Continuous Intracranial Electroencephalography Monitoring to '
#  'Manage Epilepsy Patients During COVID-19 ;Neurosurgery ;Oxford Academic')
# 'CT Manifestation of COVID-19 Pneumonia; Role of Multiplanar Imaging'
# ('MIDDLE EAST RESPIRATORY SYNDROME CORONAVIRUS OUTBREAK ;ORTA DOĞU SOLUNUM '
#  'SENDROMU CORONAVÍRÜSÜ SALGINLARI / MIDDLE EAST RESPIRATORY SYNDROME '
#  'CORONAVIRUS OUTBREAK')
# ('Clinical Management of Nonrespiratory Diseases in the COVID-19 Pandemic: '
#  'What Have We Done and What Needs to Be Done? (Re: Telemed J E Health [Epub '
#  'ahead of print]; DOI: 10.1089/tmj.2020.0106)')
# ('Sterilization of disposable face masks by means of standardized dry and '
#  'steam sterilization processes; an alternative in the fight against mask '
#  'shortages due to COVID-19')
# ('Public health measures to slow community spread of COVID-19 ;The Journal of '
#  'Infectious Diseases ;Oxford Academic')
# ('Serial interval in determining the estimation of reproduction number of the '
#  'novel coronavirus disease (COVID-19) during the early outbreak ;Journal of '
#  'Travel Medicine ;Oxford Academic')
# ('The world is upside down; how coronavirus changes the way we care for our '
#  'patients')
# ('Lobar Distribution of COVID-19 Pneumonia Based on Chest Computed Tomography '
#  'Findings;A Retrospective Study')
# ('An invited commentary on "Liu Z, Ding Z, Guan X, Zhag Y, Wang X, Khan JS. '
#  'Optimizing response in surgical systems during and after COVID-19 pandemic: '
#  'Lessons from China and the UK - Perspective. Int J Surg 2020 May '
#  '4;78:156-159.â\x80³')
# ('In bid to rapidly expand coronavirus testing, U.S. agency abruptly changes '
#  'rules ;Science ;AAAS')
# ('Personal protective equipment in the response to the SARS-CoV-2 outbreak - A '
#  'letter to the editor on "World Health Organization declares global '
#  'emergency: A review of the 2019 novel coronavirus (COVID-19)" (Int J Surg '
#  '2020; 76:71-6)')
# ('Time Varying Markov Process with Partially Observed Aggregate Data; An '
#  'Application to Coronavirus')
# ('Role of Social Media and Telemedicine in Diagnosis & Management of COVID-19; '
#  'An Experience of the Iranian Society of Radiology')
# ('Singapore claims first use of antibody test to track coronavirus infections '
#  ';Science ;AAAS')
# ('The History of Investigation and Modern Classification of Coronaviruses '
#  '(nidovirales: Coronaviridae) ;история Изучения И Современная Классификация '
#  'Коронавирусов (nidovirales: Coronaviridae)')
# ('SARS-CoV2: should inhibitors of the renin–angiotensin system be withdrawn in '
#  'patients with COVID-19? ;European Heart Journal ;Oxford Academic')
# ('Neutralizing Antibodies against SARS-CoV-2 and Other Human Coronaviruses: '
#  '(Trends in Immunology 41, 355-359; 2020)')
# ("Scientists are racing to model the next moves of a coronavirus that's still "
#  'hard to predict ;Science ;AAAS')
# 'Correction to Lancet Respir Med 2020; 8: e20'
# ('Scientist decries ‘completely chaotic’ conditions on cruise ship Japan '
#  'quarantined after viral outbreak ;Science ;AAAS')
# ('A New Video Tumorial by Young Cancer Patients Dedicated to COVID-19 Pandemic '
#  'and Lockdown (Re: J Adolesc Young Adult Oncol. [Epub ahead of print]; DOI: '
#  '10.1089/jayao.2020.0008)')
# ('A New Video Tumorial by Young Cancer Patients Dedicated to COVID-19 Pandemic '
#  'and Lockdown (Re: J Adolesc Young Adult Oncol. [Epub ahead of print]; DOI: '
#  '10.1089/jayao.2020.0008)')
# ('Correlation between travellers departing from Wuhan before the Spring '
#  'Festival and subsequent spread of COVID-19 to all provinces in China '
#  ';Journal of Travel Medicine ;Oxford Academic')
# 'Coronavirus Pandemic and Worries during Pregnancy;a Letter to Editor'
# 'Coronavirus Pandemic and Worries during Pregnancy; a Letter to Editor'
# ('Syndromic Surveillance System for MERS-CoV as New Early Warning and '
#  'Identification Approach ;Directory of Open Access Journals')
# ...
# 'Pharmacotherapy in COVID-19; A narrative review for emergency providers'
# 'Visualizing an unseen enemy; mobilizing structural biology to counter COVID-19'
# 'COVID-19 pandemic and economic cost; impact on forcibly displaced people'
# ('Correction to Lancet Infect Dis 2020; published online March 23. '
#  'https://doi.org/10.1016/S1473-3099(20)30162')
# ('Effects of Curcumin and Pentagamavunon-0 Against Dengue-2 Virus Infection in '
#  'Vero Cells; an in Vitro Study')
# ('Respiratory Management in Critical Care Respiratory Management in Critical '
#  'Care. A. J. D. Griffiths and T. W. Evans (editors). Published by BMJ Books, '
#  'London. Pp. 137; indexed; illustrated. Price £27.50. ISBN 0-7279-1729-3.')
# ('Why are vaccines against many human viral diseases still unavailable; an '
#  'historic perspective?')
# ('Errata corrige relativa al lavoro "Nuove acquisizioni sulla gravità del '
#  'danno cardiaco acuto in corso di COVID-19" [G Ital Cardiol '
#  '2020;21(5):328-331]./ [Corrigendum to "New insights into the seriousness of '
#  'acute myocardial injury during COVID-19" [G Ital Cardiol '
#  '2020;21(5):328-331]]')
# ('Change in surgical practice amidst COVID 19; example from a tertiary care '
#  'centre in Pakistan')
# 'Covid-19 and perioperative mortality; where do we stand?'
# ('Effects of Covid-19 Pandemic on Neurological Surgery Care and Education; Our '
#  'Experience from Iran')
# ('COVID-19 associated Multisystem Inflammatory Syndrome in Children (MIS-C) '
#  'guidelines; a Western New York approach')
# ('Methanol Poisoning Emerging as the Result of COVID-19 Outbreak; Radiologic '
#  'Perspective')
# 'Correction to Lancet Respir Med 2020; 8: 420–22'
# ('Covid19 pandemic; A practicing head and neck surgeon’s perspective of an '
#  'institutional model')
# ('Corona virus infection in Syria, Libya and Yemen; an alarming devastating '
#  'threat')
# ('Correction to Lancet Oncol 2020; published online April 30. '
#  'https://doi.org/10.1016/S1470-2045(20)30265-5')
# ('Virus-modified exosomes for targeted RNA delivery; A new approach in '
#  'nanomedicine')
# ('Guidance for Cardiac Electrophysiology During the Coronavirus (COVID-19) '
#  'Pandemic from the Heart Rhythm Society COVID-19 Task Force; '
#  'Electrophysiology Section of the American College of Cardiology; and the '
#  'Electrocardiography and Arrhythmias Committee of the Council on Clinical '
#  'Cardiology, American Heart Association')
# ('Bovine coronavirus in naturally and experimentally exposed calves; viral '
#  'shedding and the potential for transmission')
# ('Outbreak of novel Corona virus (2019-nCoV); implications for travelers to '
#  'Pakistan')
# ("The technological 'exposure' of populations; characterisation and future "
#  'reduction')
# ('Correction to Lancet Infect Dis 2020; published online March 30. '
#  'https://doi.org/10.1016/S1473-3099(20)30243-7')
# ('Persistent Foot-and-Mouth Disease Virus Infection in the Nasopharynx of '
#  'Cattle; Tissue-Specific Distribution and Local Cytokine Expression')
# 'Nigeria responds to COVID-19; first case detected in sub-Saharan Africa.'
# ('Comparative Viral Sampling in the Sinonasal Passages; Different Viruses at '
#  'Different Sites')
# ('Lessons from history: viral surveillance in 1940s East Africa: '
#  'Epidemiological notes on some viruses isolated in Uganda, G. W. A. Dick, '
#  'Transactions of the Royal Society of Tropical Medicine and Hygiene, '
#  '1953;47(1):13–48')
# ('Index to Subjects ∗ ∗ July, pp. 1-98; August, pp. 99-198; September, pp. '
#  '199-294; October, pp. 295-438; November, pp. 439-564; December, pp. 565-736.')
# ('Spinal anaesthesia and COVID-19 transmission to anaesthetists. Response to '
#  'Br J Anaesth 2020; 124: 670–5')
# ('Novel coronavirus transmission to water bodies; risk of COVID-19 pneumonia '
#  'to aquatic mammals')
# ('Overview of Covid-19; its prevention and management in the light of Unani '
#  'medicine')
# ('Thrombocytopenia as an initial manifestation of Covid-19; Case Series and '
#  'Literature review')
# ('Oral Radiology Center as a Potential Source of COVID-19 Transmission; Points '
#  'to Consider')
# ('Clariant extends oxygen scavengers range; agrees sale of masterbatches '
#  'business')
# 'Thrombosis management in times of COVID-19 epidemy; a Dutch perspective'
# ('Correction to Lancet Infect Dis 2020; published online March 11, '
#  'https://doi.org/10.1016/ S1473-3099(20)30144-4')
# ('Bovine respiratory syncytial virus in experimentally exposed and '
#  'rechallenged calves; viral shedding related to clinical signs and the '
#  'potential for transmission')
# ('Clinical role of respiratory virus infection in acute otitis media Arola M.; '
#  'Ruuskanen O.; Ziegler T.; Mertsola J.; Nanto-Salonen K.; Putto-Laurila A.; '
#  'Viljanen M.K.; Halonen P. Pediatrics (1990) 86/6 (848–855)')
# ('Chronic widespread musculoskeletal pain, fatigue, depression and disordered '
#  'sleep in chronic post-SARS syndrome; a case-controlled study')
# ('Non-steroidal anti-inflammatory drugs in management of COVID-19; a '
#  'systematic review on current evidence.')
# ('L’exposition d’un nourrisson à un chien n’augmente pas le risque de '
#  'sensibilisation ; elle semble même diminuer les risques de sensibilisation à '
#  'd’autres pneumallergènes et le risque d’asthme à 4 ans ! C.')
# ('Small-area spatial statistical analysis of malaria clusters and hotspots in '
#  'Cameroon;2000–2015')
# 'Pembina to defer PDH/PP project in Canada; cuts CapEx'
# ('Clinician perceptions of respiratory infection risk; a rationale for '
#  'research into mask use in routine practice')
# ('Neutralizing Antibodies against SARS-CoV-2 and Other Human Coronaviruses '
#  '(Trends in Immunology 41, 355–359; 2020)')
# ('Temporal Variations in the Distribution of West Nile Virus Within the United '
#  'States; 2000–2008')
# 'Authors’ correction for Euro Surveill. 2020;25(17)'
# ('SARS coronavirus 2; how many more examples do we need before the world '
#  'commits to decisive action?')
# ('The COVID-19 pandemic from an acute psychiatric perspective; a London '
#  'Psychiatric Intensive Care Unit experience')
# ('Personal sampler for monitoring of viable viruses; modelling of outdoor '
#  'sampling conditions')
# ('Guidance for Cardiac Electrophysiology During the COVID-19 Pandemic from the '
#  'Heart Rhythm Society COVID-19 Task Force; Electrophysiology Section of the '
#  'American College of Cardiology; and the Electrocardiography and Arrhythmias '
#  'Committee of the Council on Clinical Cardiology, American Heart Association')
# ('Facility-based surveillance for emerging infectious diseases; diagnostic '
#  'practices in rural West African hospital settings: observations from Ghana')
# ('Author index ∗ ∗ February, 1-50; March, 51-94; April, 95-162; May, 163-250; '
#  'June, 251-330; August, 331-400; September, 401-468; October, 469-542; '
#  'November, 543-612; December, 613-698.')
# ('Pan-human coronavirus and human bocavirus SYBR Green and TaqMan PCR assays; '
#  'use in studying influenza A viruses co-infection and risk of hospitalization')
# ('Regulation of Cytokine Production by the Unfolded Protein Response; '
#  'Implications for Infection and Autoimmunity')
# 'CT Manifestation of COVID-19 Pneumonia; Role of Multiplanar Imaging'
# ('The Challenges Of Urgent Radical Sigmoid Colorectal Cancer Resection In A '
#  'COVID-19 Patient; A Case Report')
# ('The world is upside down; how coronavirus changes the way we care for our '
#  'patients')
# 'Lung ultrasound in COVID-19 pneumonia; prospects and limitations'
# ('Correction to Lancet Infect Dis 2020; published online March 12. '
#  'https://doi.org/10.1016/S1473-3099(20)30174-2')
# ('What is the Role of Respiratory Viruses in Community Acquired Pneumonia; '
#  'What is the Best Therapy for Influenza and Other Viral Causes of CAP?')
# ('Factors responsible for the emergence of arboviruses; strategies, challenges '
#  'and limitations for their control')
# ('Truncated human angiotensin converting enzyme 2; a potential inhibitor of '
#  'SARS-CoV-2 spike glycoprotein and potent COVID-19 therapeutic agent')
# ('Chapter 5 John Snow, Cholera, the Broad Street Pump; Waterborne Diseases '
#  'Then and Now')
# 'Correction to Lancet Respir Med 2020; 8: 506–17'
# 'SARS, MERS and COVID-19—new threats; old lessons'
# ('Generating translatable evidence to improve patient care; the contribution '
#  'of human factors.')
# ('Correction to Lancet Respir Med 2020; published online Feb 21. '
#  'https://doi.org/10.1016/S2213-2600(20)30079-5')
# ('Correction to Lancet Public Health 2019; published online April 24. '
#  'https://doi.org/10.1016/S2468-2667(20)30095-5')
# 'Correction to Lancet Psychiatry 2020; 7: 463'
# ('Congenital nasal masses: CT and MR imaging features in 16 cases Barkovich '
#  'A.J.; Vandermarck P.; Edwards M.S.B.; Cogen P.H. Am. J. Neuroradiol. (1991) '
#  '12/1 (105–116)')
# ('Chapter 26 Palaeognathae: Apterygiformes, Casuariiformes, Rheiformes, '
#  'Struthioniformes; Tinamiformes')
# ('Time, distance, shielding and ALARA; drawing similarities between measures '
#  'for radiation protection and Coronavirus disease pandemic response')
# 'Correction to Lancet Respir Med 2020; 8: e20'
# ('Digital epidemiology and global health security; an interdisciplinary '
#  'conversation')
# ('Adults hospitalised with acute respiratory illness rarely have detectable '
#  'bacteria in the absence of COPD or pneumonia; viral infection predominates '
#  'in a large prospective UK sample')
# 'The VIZIER project: Overview; expectations; and achievements'
# 'MERS may not be SARS; but India is still vulnerable'
# ('Bioactive compounds with possible inhibitory activity of '
#  'Angiotensin-Converting Enzyme-II; a gate to manage and prevent COVID-19')
# ('Demographic, clinical, and outcomes of confirmed cases of Middle East '
#  'Respiratory Syndrome coronavirus (MERS-CoV) in Najran, Kingdom of Saudi '
#  'Arabia (KSA); A retrospective record based study')
# ('Correction to Lancet Public Health 2019; published online April 24. '
#  'https://doi.org/10.1016/S2468-2667(20)30099-2')
# ('Correction to Lancet Infect Dis 2020; published online March 30. '
#  'https://doi.org/10.1016/S1473-3099(20)30257-7')
# ('Phosphoramidates of 2′-β-d-arabinouridine (AraU) as phosphate prodrugs; '
#  'design, synthesis, in vitro activity and metabolism')
# ('Bacterial co-infection of the respiratory tract in ventilated children with '
#  'bronchiolitis; a retrospective cohort study')
# ('Covid-19 outbreak in a major radiation oncology department; which lessons '
#  'should be taken?')
# ('Epidemiology, virology, and clinical features of severe acute respiratory '
#  'syndrome -coronavirus-2 (SARS-CoV-2; Coronavirus Disease-19)')
# ('Correction to Lancet Infect Dis 2020; published online March 26. '
#  'https://doi.org/10.1016/S1473-3099(20)30241-3')
# ('The Ocular Manifestations and Transmission of COVID-19; Recommendations for '
#  'Prevention')
# ('“Amantadine disrupts lysosomal gene expression; a hypothesis for COVID19 '
#  'treatment “')
# ('Personal protective equipment in the response to the SARS-CoV-2 outbreak - A '
#  'letter to the editor on “World Health Organization declares global '
#  'emergency: A review of the 2019 novel coronavirus (COVID-19)” (Int J Surg '
#  '2020; 76:71–6)')
# ('Hospital incident command system (HICS) performance in Iran; decision making '
#  'during disasters')
# ('Hypoxemia in COVID-19; Comment on: "The neuroinvasive potential of SARS - '
#  'CoV2 may play a role in the respiratory failure of COVID-19 patients"')
# 'CARES Act to help providers bolster care; supports communities, businesses'
# 'Visualizing an unseen enemy; mobilizing structural biology to counter COVID-19'
# ('Marine pharmacology in 2007–8: Marine compounds with antibacterial, '
#  'anticoagulant, antifungal, anti-inflammatory, antimalarial, antiprotozoal, '
#  'antituberculosis, and antiviral activities; affecting the immune and nervous '
#  'system, and other miscellaneous mechanisms of action')
# ('Transient cortical blindness in COVID-19 pneumonia; a PRES-like syndrome: A '
#  'case report')
# 'Colchicine may not be effective in COVID-19 infection; it may even be harmful?'
# 'Visualizing an unseen enemy; mobilizing structural biology to counter COVID-19'
# 'Correction to Lancet Psychiatry 2020; 7: e15–16'
# ('Public Health Emergency of International Concern (PHEIC) has Declared Twice '
#  'in 2014; Polio and Ebola at the Top')
# ('Viruses as key modulators of the TGF‐β pathway; a double‐edged sword '
#  'involved in cancer')
# ('Linking mechanistic and behavioral responses to sublethal esfenvalerate '
#  'exposure in the endangered delta smelt; Hypomesus transpacificus (Fam. '
#  'Osmeridae)')
# 'Correction to Lancet Gastroenterol Hepatol 2020; 5: 430–31'
# ('Letter to the Editor in relation to Bistrian BR. Parenteral fish oil '
#  'emulsions in critically ill COVID-19 emulsions [published online ahead of '
#  'print, 2020 May 8]. JPEN J Parenter Enteral Nutr. 2020;10.1002/jpen.1871')
# ('The role of facemasks and hand hygiene in the prevention of influenza '
#  'transmission in households: results from a cluster randomised trial; Berlin, '
#  'Germany, 2009-2011')
# ('Seroprevalence of three paramyxoviruses; Hendra virus, Tioman virus, Cedar '
#  'virus and a rhabdovirus, Australian bat lyssavirus, in a range expanding '
#  'fruit bat, the Grey-headed flying fox (Pteropus poliocephalus)')
# ('Current pharmacy practices in low- and middle-income countries; '
#  'recommendations in response to the COVID-19 pandemic')
# 'COVID-19 pneumonia and pregnancy; a systematic review and meta-analysis'
# ('Infectious diseases in children and adolescents in the Republic of Korea; '
#  'Past & recent status')
# ('Correction to Lancet Infect Dis 2020; Published online March 23, 2020 '
#  'https://doi.org/10.1016/S1473-3099(20)30226-7')
# ('Evaluation of a COVID-19 IgM and IgG rapid test; an efficient tool for '
#  'assessment of past exposure to SARS-CoV-2')
# 'Correction to Lancet Respir Med 2020; 8: e21'
# ('Philanthropy and Humanity in the Face of a Pandemic – A letter to the editor '
#  'on “World Health Organization declares global emergency: A review of the '
#  '2019 novel coronavirus (COVID-19)” (Int J Surg 2020; 76:71-6)')
# 'Correction to Lancet Public Health 2020; 5; e261–70'
# 'Correction to Lancet Infect Dis 2019; 20: 275–76'
# 'Safety netting; best practice in the face of uncertainty'
# ('Dysosmia and dysgeusia due to the 2019 Novel Coronavirus; a hypothesis that '
#  'needs further investigation')
# 'COVID-19 pandemic; prevention, treatment, and mental health.'
# ('Zoonoses Second Edition Zoonoses. Martin Shakespeare, Second Edition. '
#  'Pharmaceutical Press; 2009; Hardcover, 289 pages, ISBN: 978-0-85369-753-4.')
# ('Hydroxychloroquine and azithromycin as potential treatments for COVID-19; '
#  'clinical status impacts the outcome')
# ('Mechanisms of HIV non-progression; robust and sustained CD4+ T-cell '
#  'proliferative responses to p24 antigen correlate with control of viraemia '
#  'and lack of disease progression after long-term transfusion-acquired HIV-1 '
#  'infection')
# 'COVID-19 Convalescent Plasma; Phase 2.'
# ('Epidemiology and etiology of influenza-like-illness in households in '
#  'Vietnam; it’s not all about the kids!')
# ('Correction to Lancet Infect Dis 2020; published online March 4. '
#  'https://doi.org/10.1016/S1473-3099(20)30159-6')
# ('RNA viruses in community-acquired childhood pneumonia in semi-urban Nepal; a '
#  'cross-sectional study')
# ('Interferon and cytokine responses to Crimean Congo hemorrhagic fever virus; '
#  'an emerging and neglected viral zonoosis')
# ('Cancer and COVID-19; how do we manage cancer optimally through a public '
#  'health crisis?')
# ('On constitutional isomers and tautomers of oxadiazolones and their mono- and '
#  'disulfur analogues (C(2)H(2)N(2)XY; X, Y = S, O)')
# 'Covid-19 associated SIADH; a clue in the times of pandemic!'
# ('Correction to Lancet Glob Health 2020; published online Feb 28. '
#  'https://doi.org/10.1016/S2214-109X(20)30074-7')
# ('COVID-19 Digestive Symptoms Mimicking Internal Hernia Presentation After '
#  'Roux-en-Y-Gastric Bypass; Comment on “Internal Hernia in the Times of '
#  'COVID-19: to Laparoscope or Not to Laparoscope?”')
# "COVID-19: The time for action is just now; It's still not too late"

# %% [markdown]
# It looks like most of these are cases where a semicolon (';') is in the place of a colon (':').
#
# If course generalizing from checking a small number can be dangerous, but for now just replace ';' with ':'.

# %%
metadataFrame['title'] = metadataFrame['title'].str.replace(';',':')

# %% [markdown]
# Just to check them all again:

# %%
for Column in SingleValued:
    print(Column, metadataFrame[Column].str.contains(';').fillna(False).sum())
# Out:
# title 0
# doi 25
# license 0
# publish_time 0

# %% [markdown]
# This is something we can live with.

# %% [markdown]
# <a id='Setting_up_a_schema'></a>
# # Setting up a schema
#
# Recalling the fields covered above:
#
# __single valued__, __unique__
# * 'cord_uid'
# * 'pmcid'
# * 'pubmed_id'
# * 'mag_id'
# * 'who_covidence_id'
# * 'arxiv_id'
# * 'url'
#
# __single valued__
# * 'source_x'
# * 'title'
# * 'doi'
# * 'license'
# * 'abstract'
# * 'publish_time'
# * 'journal'
# * 's2_id'
#
# __multi-valued__, __unique__
# * 'pdf_json_files'
# * 'pmc_json_files'
#
# __multi-valued__
# * 'sha'
# * 'authors'
#
# The strategy here is to create a main table that stores all the single valued fields, and then build four more that cover the multi-valued fields.
#
# cord_uid will be the primary index across all.

# %%
import sqlite3 # For now just going to populate in sqlite. Will probably put down to disk better later in MySQL.

# %%
conn = sqlite3.connect('CORD_metadata.db')
cur = conn.cursor()

# %% [markdown]
# <a id='Main_table'></a>
# ## Main table

# %%
# Organize the data a bit in a dict
columnData = {}
columnData['cord_uid'] = {'SQLName': 'cord_uid', 'SQLType': 'char(8) NOT NULL UNIQUE', 'PythonType': 'str'}
columnData['pmcid'] = {'SQLName': 'pmcid', 'SQLType': 'char(9) UNIQUE', 'PythonType': 'str'}
columnData['pubmed_id'] = {'SQLName': 'pubmed_id', 'SQLType': 'number(8,0) UNIQUE', 'PythonType': 'int'}
columnData['mag_id'] = {'SQLName': 'mag_id', 'SQLType': 'number(10,0) UNIQUE', 'PythonType': 'int'}
columnData['who_covidence_id'] = {'SQLName': 'who_covidence_id', 'SQLType': 'char(12) UNIQUE', 'PythonType': 'str'}
columnData['arxiv_id'] = {'SQLName': 'arxiv_id', 'SQLType': 'text UNIQUE', 'PythonType': 'str'}
columnData['url'] = {'SQLName': 'url', 'SQLType': 'text UNIQUE', 'PythonType': 'str'}
columnData['source_x'] = {'SQLName': 'source_x', 'SQLType': 'text', 'PythonType': 'str'}
columnData['title'] = {'SQLName': 'title', 'SQLType': 'text', 'PythonType': 'str'}
columnData['doi'] = {'SQLName': 'doi', 'SQLType': 'text', 'PythonType': 'str'}
columnData['license'] = {'SQLName': 'license', 'SQLType': 'text', 'PythonType': 'str'}
columnData['abstract'] = {'SQLName': 'abstract', 'SQLType': 'text', 'PythonType': 'str'}
columnData['publish_time'] = {'SQLName': 'publish_time', 'SQLType': 'DATE', 'PythonType': 'str'}
columnData['journal'] = {'SQLName': 'journal', 'SQLType': 'text', 'PythonType': 'str'}
columnData['s2_id'] = {'SQLName': 's2_id', 'SQLType': 'number(9,0)', 'PythonType': 'int'}

# %% [markdown]
# The SQL types were arrived at by inspection. It is likely that some can be improved but will circle back as necessary.

# %%
TableName = 'main'
cur.execute('DROP TABLE IF EXISTS {}'.format(TableName)) # always start fresh.
CreateTableQuery = 'CREATE TABLE {}('.format(TableName)
for Column in metadataFrame.columns:
    if Column in columnData:
        CreateTableQuery += '{SQLName} {SQLType}, '.format(**columnData[Column])
CreateTableQuery = CreateTableQuery[:-2]+')' # hate this [:-2] construction to eliminate the last ','. Could be impoved with a join on a list.
#print(CreateTableQuery)
cur.execute(CreateTableQuery)

# %%
# This is work around for correctly inserting NULL.
def FormatNULL(Value, pythonType):
    if pd.isnull(Value):
        return('NULL')
    else:
        if pythonType == 'str':
            return('"{}"'.format(Value.replace('"', "'")))
        else:
            return(str(Value))

# %%
# This one can be used for testing. Will exceed IO rate if run.
def INSERT_from_df_Single(_dataframe, _tableName, _columnData, _cursor):
    InsertQueryStub = 'INSERT INTO {} ({}) VALUES '.format(_tableName, ', '.join([col for col in _dataframe.columns if col in _columnData]))
    for Record in _dataframe.to_dict('records'):
        InsertQuery = InsertQueryStub + '({})'.format(', '.join([FormatNULL(Record[col], _columnData[col]['PythonType']) for col in _dataframe.columns if col in _columnData]))
        #print(InsertQuery)
        _cursor.execute(InsertQuery)

# %%
# This should be used to actually do the insert.
# Have updated this to work from a list and print when batchsize is hit.
def INSERT_from_df_Mass(_dataframe, _tableName, _columnData, _cursor, _batchSize):
    MassInsertQueryStub = 'INSERT INTO {} ({}) VALUES '.format(_tableName, ', '.join([col for col in _dataframe.columns if col in _columnData]))

    MassInsertValues = []
    for Record in _dataframe.to_dict('records'):
        MassInsertValues.append('({})'.format(', '.join([FormatNULL(Record[col], _columnData[col]['PythonType']) for col in _dataframe.columns if col in _columnData])))

        if len(MassInsertValues) >= _batchSize:
            MassInsertQuery = MassInsertQueryStub + ', '.join(MassInsertValues[:_batchSize])
            _cursor.execute(MassInsertQuery)
            del MassInsertValues[:_batchSize]

    MassInsertQuery = MassInsertQueryStub + ', '.join(MassInsertValues[:_batchSize])
    _cursor.execute(MassInsertQuery)

# %%
INSERT_from_df_Mass(metadataFrame, TableName, columnData, cur, 500) # Batches of 500
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-05181b2abed2> in <module>
# ----> 1 INSERT_from_df_Mass(metadataFrame, TableName, columnData, cur, 500) # Batches of 500
#
# <ipython-input-32-e76b2211b09a> in INSERT_from_df_Mass(_dataframe, _tableName, _columnData, _cursor, _batchSize)
#       6     MassInsertValues = []
#       7     for Record in _dataframe.to_dict('records'):
# ----> 8         MassInsertValues.append('({})'.format(', '.join([FormatNULL(Record[col], _columnData[col]['PythonType']) for col in _dataframe.columns if col in _columnData])))
#       9
#      10         if len(MassInsertValues) >= _batchSize:
#
# <ipython-input-32-e76b2211b09a> in <listcomp>(.0)
#       6     MassInsertValues = []
#       7     for Record in _dataframe.to_dict('records'):
# ----> 8         MassInsertValues.append('({})'.format(', '.join([FormatNULL(Record[col], _columnData[col]['PythonType']) for col in _dataframe.columns if col in _columnData])))
#       9
#      10         if len(MassInsertValues) >= _batchSize:
#
# <ipython-input-30-77f1dedb734b> in FormatNULL(Value, pythonType)
#       5     else:
#       6         if pythonType == 'str':
# ----> 7             return('"{}"'.format(Value.replace('"', "'")))
#       8         else:
#       9             return(str(Value))
#
# AttributeError: 'float' object has no attribute 'replace'

# %%
cur.execute('SELECT COUNT(*) FROM {}'.format(TableName))
pp(cur.fetchone())

# %% [markdown]
# The right number of records.

# %%
cur.execute('SELECT * FROM {} WHERE publish_time BETWEEN "2001-01-01" AND "2002-01-01"'.format(TableName))
pp(cur.fetchone())

# %% [markdown]
# That all lines up quite nicely.

# %% [markdown]
# <a id='Multivalued_field_tables'></a>
# ## Multivalued field tables

# %% [markdown]
# <a id='pdf_json_files'></a>
# ### pdf_json_files

# %%
columnData = {}
columnData['cord_uid'] = {'SQLName': 'cord_uid', 'SQLType': 'char(8) NOT NULL', 'PythonType': 'str'}
columnData['pdf_json_files'] = {'SQLName': 'pdf_json_files', 'SQLType': 'text', 'PythonType': 'str'}

# %%
MainIndex = 'cord_uid'
MultiValuedVariable = 'pdf_json_files'
TableName = MultiValuedVariable
cur.execute('DROP TABLE IF EXISTS {}'.format(TableName))
CreateTableQuery = 'CREATE TABLE {}({} {}, {} {})'.format(TableName, MainIndex, columnData[MainIndex]['SQLType'], MultiValuedVariable, columnData[MultiValuedVariable]['SQLType'])
#print(CreateTableQuery)
cur.execute(CreateTableQuery)

# %%
# This is work around for correctly inserting NULL.
def FormatNULL(Value, pythonType):
    if pd.isnull(Value):
        return('NULL')
    else:
        if pythonType == 'str':
            return('"{}"'.format(Value.replace('"', "'")))
        else:
            return(str(Value))

# %%
def INSERT_from_df_MultiValue_Mass(_dataframe, _tableName, _mainIndex, _multiValueColumn, _columnData, _cursor, _batchSize):
    MassInsertQueryStub = 'INSERT INTO {} ({}) VALUES '.format(_tableName, ', '.join([_mainIndex, _multiValueColumn]))

    MassInsertValues = []
    for Record in _dataframe.to_dict('records'):

        if pd.isnull(Record[_multiValueColumn]):
            MassInsertValues.append('({})'.format(', '.join([FormatNULL(Record[col], _columnData[col]['PythonType']) for col in [_mainIndex, _multiValueColumn]])))
        else:
            for Value in Record[_multiValueColumn].split(';'):
                MassInsertValues.append('({}, {})'.format(FormatNULL(Record[_mainIndex], _columnData[_mainIndex]['PythonType']), FormatNULL(Value.strip(), _columnData[_multiValueColumn]['PythonType'])))

        if len(MassInsertValues) >= _batchSize:
            MassInsertQuery = MassInsertQueryStub + ', '.join(MassInsertValues[:_batchSize])
            _cursor.execute(MassInsertQuery)
            del MassInsertValues[:_batchSize]

    MassInsertQuery = MassInsertQueryStub + ', '.join(MassInsertValues[:_batchSize])
    _cursor.execute(MassInsertQuery)

# %%
INSERT_from_df_MultiValue_Mass(metadataFrame, TableName, MainIndex, MultiValuedVariable, columnData, cur, 500)

# %% [markdown]
# <a id='pmc_json_files'></a>
# ### pmc_json_files

# %%
columnData = {}
columnData['cord_uid'] = {'SQLName': 'cord_uid', 'SQLType': 'char(8) NOT NULL', 'PythonType': 'str'}
columnData['pmc_json_files'] = {'SQLName': 'pmc_json_files', 'SQLType': 'text', 'PythonType': 'str'}

# %%
MainIndex = 'cord_uid'
MultiValuedVariable = 'pmc_json_files'
TableName = MultiValuedVariable
cur.execute('DROP TABLE IF EXISTS {}'.format(TableName))
CreateTableQuery = 'CREATE TABLE {}({} {}, {} {})'.format(TableName, MainIndex, columnData[MainIndex]['SQLType'], MultiValuedVariable, columnData[MultiValuedVariable]['SQLType'])
#print(CreateTableQuery)
cur.execute(CreateTableQuery)

# %%
INSERT_from_df_MultiValue_Mass(metadataFrame, TableName, MainIndex, MultiValuedVariable, columnData, cur, 500)

# %% [markdown]
# <a id='sha'></a>
# ### sha

# %%
columnData = {}
columnData['cord_uid'] = {'SQLName': 'cord_uid', 'SQLType': 'char(8) NOT NULL', 'PythonType': 'str'}
columnData['sha'] = {'SQLName': 'sha', 'SQLType': 'text', 'PythonType': 'str'}

# %%
MainIndex = 'cord_uid'
MultiValuedVariable = 'sha'
TableName = MultiValuedVariable
cur.execute('DROP TABLE IF EXISTS {}'.format(TableName))
CreateTableQuery = 'CREATE TABLE {}({} {}, {} {})'.format(TableName, MainIndex, columnData[MainIndex]['SQLType'], MultiValuedVariable, columnData[MultiValuedVariable]['SQLType'])
#print(CreateTableQuery)
cur.execute(CreateTableQuery)

# %%
INSERT_from_df_MultiValue_Mass(metadataFrame, TableName, MainIndex, MultiValuedVariable, columnData, cur, 500)

# %% [markdown]
# <a id='authors'></a>
# ### authors

# %%
columnData = {}
columnData['cord_uid'] = {'SQLName': 'cord_uid', 'SQLType': 'char(8) NOT NULL', 'PythonType': 'str'}
columnData['authors'] = {'SQLName': 'authors', 'SQLType': 'text', 'PythonType': 'str'}

# %%
MainIndex = 'cord_uid'
MultiValuedVariable = 'authors'
TableName = MultiValuedVariable
cur.execute('DROP TABLE IF EXISTS {}'.format(TableName))
CreateTableQuery = 'CREATE TABLE {}({} {}, {} {})'.format(TableName, MainIndex, columnData[MainIndex]['SQLType'], MultiValuedVariable, columnData[MultiValuedVariable]['SQLType'])
#print(CreateTableQuery)
cur.execute(CreateTableQuery)

# %%
INSERT_from_df_MultiValue_Mass(metadataFrame, TableName, MainIndex, MultiValuedVariable, columnData, cur, 500)

# %% [markdown]
# Those are all loaded quite well.
#
# If it ends up necessary to go a step further it would be best to streamline this with a tool like SQLAlchemy.

# %% [markdown]
# <a id='Quick_test'></a>
# ## Quick test

# %%
cur.execute('SELECT * FROM {} WHERE publish_time BETWEEN "2010-01-01" AND "2011-01-01"'.format('main'))
Record = cur.fetchone()
pp(Record)

# %%
MultiValued = ['pdf_json_files', 'pmc_json_files', 'sha', 'authors']

for Table in MultiValued:
    cur.execute('SELECT {} FROM {} WHERE cord_uid IS "{}"'.format(Table, Table, Record[0]))
    pp(cur.fetchall())

# %% [markdown]
# So this appears to all be in order.
